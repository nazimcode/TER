# %%
import numpy as np
import matplotlib.pylab as plt
#from scipy.misc import imresize, imread
import itertools
import sklearn
from sklearn import model_selection
from sklearn.model_selection import train_test_split, KFold, cross_val_score, StratifiedKFold, learning_curve, GridSearchCV
from sklearn.metrics import confusion_matrix, make_scorer, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
import keras
from keras import backend as K
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential, model_from_json
from keras.optimizers import SGD, RMSprop, Adam, Adagrad, Adadelta
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPool2D, MaxPooling2D
# %matplotlib inline
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_40m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_40m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]
# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    en va plot un learning curve grace au code de ce lien http://scikit-learn.org/stable/modules/learning_curve.html
    """
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("exemples de test")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="score d'entrainement")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="score du cross validation")
    plt.legend(loc="best")
    return plt

def plotLotsOfLearningCurves(a,b):
    """ en va plot bcp de learning curve http://scikit-learn.org/stable/modules/learning_curve.html"""
    models = []
    models.append(('Support Vector Machine', SVC()))
    for name, model in models:
        plot_learning_curve(model, 'Learning Curve For %s Classifier'% (name), a,b, (0.5,1), 10)
#plotLotsOfLearningCurves(X_trainFlat, Y_train)
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='matrice d econfusion',
                          cmap=plt.cm.Blues):
    """
    en affiche la matrice de confusion
    en peut normalizer les donnees en metant normalize a true
    """
    plt.figure(figsize = (5,5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

#Run SVC w/ Confusion Matrix
def runSVCconfusion(a,b,c,d):
    """methodes qui affiches les matrices de confusiondu model svc (comme exmeple) en normalizer et non normalizer"""
    model = SVC()
    model.fit(a, b)
    prediction = model.predict(c)
    kfold = model_selection.KFold(n_splits=10)
    accuracy = model_selection.cross_val_score(model, c,d, cv=kfold, scoring='accuracy')
    mean = accuracy.mean() 
    stdev = accuracy.std()
    print('\nSupport Vector Machine - Training set accuracy: %s (%s)' % (mean, stdev),"\n")
    cnf_matrix = confusion_matrix(d, prediction)
    np.set_printoptions(precision=2)
    class_names = ["diagnostic" "IDC(-)", "diagnostic" "IDC(+)"]
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names,
                          title='Confusion matrix, sans la normalization')
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                          title=' confusion matrix avec normalization')
    plt.show()
#runSVCconfusion(X_trainFlat, Y_train, X_testFlat, Y_test)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
# Out:
# Using TensorFlow backend.

# %%
#simple model
def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')

def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 100 
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    model.add(Conv2D(32, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=input_shape))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
     # checkpoint
    filepath="weights.traint_40zoom_modelsimple_avec_crop.hdf5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]
    history =model.fit(x_train, y_train,
              batch_size=batch_size,
              verbose=1,
              epochs=epochs,
              validation_data=(x_test, y_test),callbacks=callbacks_list)
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# Train on 1000 samples, validate on 250 samples
# Epoch 1/100
# 1000/1000 [==============================] - 2s 2ms/step - loss: 1.1733 - acc: 0.4800 - val_loss: 0.6981 - val_acc: 0.4760
#
# Epoch 00001: val_acc improved from -inf to 0.47600, saving model to weights.traint_40zoom_modelsimple_avec_crop.hdf5
# Epoch 2/100
# 1000/1000 [==============================] - 1s 648us/step - loss: 0.6931 - acc: 0.4970 - val_loss: 0.6928 - val_acc: 0.4760
#
# Epoch 00002: val_acc did not improve from 0.47600
# Epoch 3/100
# 1000/1000 [==============================] - 1s 628us/step - loss: 0.6886 - acc: 0.5310 - val_loss: 0.6850 - val_acc: 0.4880
#
# Epoch 00003: val_acc improved from 0.47600 to 0.48800, saving model to weights.traint_40zoom_modelsimple_avec_crop.hdf5
# Epoch 4/100
# 1000/1000 [==============================] - 1s 613us/step - loss: 0.6863 - acc: 0.5570 - val_loss: 0.6870 - val_acc: 0.7280
#
# Epoch 00004: val_acc improved from 0.48800 to 0.72800, saving model to weights.traint_40zoom_modelsimple_avec_crop.hdf5
# Epoch 5/100
# 1000/1000 [==============================] - 1s 645us/step - loss: 0.6825 - acc: 0.5560 - val_loss: 0.6926 - val_acc: 0.5400
#
# Epoch 00005: val_acc did not improve from 0.72800
# Epoch 6/100
# 1000/1000 [==============================] - 1s 621us/step - loss: 0.6763 - acc: 0.5840 - val_loss: 0.7060 - val_acc: 0.4760
#
# Epoch 00006: val_acc did not improve from 0.72800
# Epoch 7/100
# 1000/1000 [==============================] - 1s 706us/step - loss: 0.6912 - acc: 0.5190 - val_loss: 0.6857 - val_acc: 0.7520
#
# Epoch 00007: val_acc improved from 0.72800 to 0.75200, saving model to weights.traint_40zoom_modelsimple_avec_crop.hdf5
# Epoch 8/100
# 1000/1000 [==============================] - 1s 612us/step - loss: 0.6875 - acc: 0.5240 - val_loss: 0.6927 - val_acc: 0.5240
#
# Epoch 00008: val_acc did not improve from 0.75200
# Epoch 9/100
# 1000/1000 [==============================] - 1s 566us/step - loss: 0.6891 - acc: 0.5450 - val_loss: 0.7657 - val_acc: 0.4760
#
# Epoch 00009: val_acc did not improve from 0.75200
# Epoch 10/100
# 1000/1000 [==============================] - 1s 573us/step - loss: 0.6818 - acc: 0.6130 - val_loss: 0.6701 - val_acc: 0.5000
#
# Epoch 00010: val_acc did not improve from 0.75200
# Epoch 11/100
# 1000/1000 [==============================] - 1s 577us/step - loss: 0.6710 - acc: 0.5900 - val_loss: 0.6656 - val_acc: 0.5280
#
# Epoch 00011: val_acc did not improve from 0.75200
# Epoch 12/100
# 1000/1000 [==============================] - 1s 566us/step - loss: 0.6723 - acc: 0.5860 - val_loss: 0.6862 - val_acc: 0.5240
#
# Epoch 00012: val_acc did not improve from 0.75200
# Epoch 13/100
# 1000/1000 [==============================] - 1s 607us/step - loss: 0.6809 - acc: 0.5470 - val_loss: 0.6608 - val_acc: 0.6840
#
# Epoch 00013: val_acc did not improve from 0.75200
# Epoch 14/100
# 1000/1000 [==============================] - 1s 563us/step - loss: 0.6912 - acc: 0.5570 - val_loss: 0.6828 - val_acc: 0.5240
#
# Epoch 00014: val_acc did not improve from 0.75200
# Epoch 15/100
# 1000/1000 [==============================] - 1s 561us/step - loss: 0.6786 - acc: 0.5230 - val_loss: 0.6797 - val_acc: 0.4960
#
# Epoch 00015: val_acc did not improve from 0.75200
# Epoch 16/100
# 1000/1000 [==============================] - 1s 568us/step - loss: 0.6626 - acc: 0.5580 - val_loss: 0.6435 - val_acc: 0.7600
#
# Epoch 00016: val_acc improved from 0.75200 to 0.76000, saving model to weights.traint_40zoom_modelsimple_avec_crop.hdf5
# Epoch 17/100
# 1000/1000 [==============================] - 1s 564us/step - loss: 0.7477 - acc: 0.5170 - val_loss: 0.6722 - val_acc: 0.5240
#
# Epoch 00017: val_acc did not improve from 0.76000
# Epoch 18/100
# 1000/1000 [==============================] - 1s 565us/step - loss: 0.6708 - acc: 0.5400 - val_loss: 0.6747 - val_acc: 0.5240
#
# Epoch 00018: val_acc did not improve from 0.76000
# Epoch 19/100
# 1000/1000 [==============================] - 1s 564us/step - loss: 0.6430 - acc: 0.6230 - val_loss: 0.6148 - val_acc: 0.6080
#
# Epoch 00019: val_acc did not improve from 0.76000
# Epoch 20/100
# 1000/1000 [==============================] - 1s 562us/step - loss: 0.6873 - acc: 0.6140 - val_loss: 0.5967 - val_acc: 0.6960
#
# Epoch 00020: val_acc did not improve from 0.76000
# Epoch 21/100
# 1000/1000 [==============================] - 1s 554us/step - loss: 0.6488 - acc: 0.6430 - val_loss: 0.6027 - val_acc: 0.7400
#
# Epoch 00021: val_acc did not improve from 0.76000
# Epoch 22/100
# 1000/1000 [==============================] - 1s 551us/step - loss: 0.6112 - acc: 0.6920 - val_loss: 0.6927 - val_acc: 0.5480
#
# Epoch 00022: val_acc did not improve from 0.76000
# Epoch 23/100
# 1000/1000 [==============================] - 1s 551us/step - loss: 0.6560 - acc: 0.6510 - val_loss: 0.5838 - val_acc: 0.7840
#
# Epoch 00023: val_acc improved from 0.76000 to 0.78400, saving model to weights.traint_40zoom_modelsimple_avec_crop.hdf5
# Epoch 24/100
# 1000/1000 [==============================] - 1s 562us/step - loss: 0.6852 - acc: 0.5630 - val_loss: 0.6663 - val_acc: 0.7480
#
# Epoch 00024: val_acc did not improve from 0.78400
# Epoch 25/100
# 1000/1000 [==============================] - 1s 624us/step - loss: 0.6924 - acc: 0.6360 - val_loss: 0.6427 - val_acc: 0.7440
#
# Epoch 00025: val_acc did not improve from 0.78400
# Epoch 26/100
# 1000/1000 [==============================] - 1s 584us/step - loss: 0.6188 - acc: 0.6920 - val_loss: 0.5505 - val_acc: 0.7880
#
# Epoch 00026: val_acc improved from 0.78400 to 0.78800, saving model to weights.traint_40zoom_modelsimple_avec_crop.hdf5
# Epoch 27/100
# 1000/1000 [==============================] - 1s 581us/step - loss: 0.6225 - acc: 0.7170 - val_loss: 0.7621 - val_acc: 0.5240
#
# Epoch 00027: val_acc did not improve from 0.78800
# Epoch 28/100
# 1000/1000 [==============================] - 1s 592us/step - loss: 0.6552 - acc: 0.6330 - val_loss: 0.6168 - val_acc: 0.6200
#
# Epoch 00028: val_acc did not improve from 0.78800
# Epoch 29/100
# 1000/1000 [==============================] - 1s 617us/step - loss: 0.6075 - acc: 0.6720 - val_loss: 0.5647 - val_acc: 0.7520
#
# Epoch 00029: val_acc did not improve from 0.78800
# Epoch 30/100
# 1000/1000 [==============================] - 1s 602us/step - loss: 0.5512 - acc: 0.7270 - val_loss: 0.4999 - val_acc: 0.7800
#
# Epoch 00030: val_acc did not improve from 0.78800
# Epoch 31/100
# 1000/1000 [==============================] - 1s 635us/step - loss: 0.6795 - acc: 0.6810 - val_loss: 0.5930 - val_acc: 0.6280
#
# Epoch 00031: val_acc did not improve from 0.78800
# Epoch 32/100
# 1000/1000 [==============================] - 1s 580us/step - loss: 0.5772 - acc: 0.6830 - val_loss: 0.5689 - val_acc: 0.7920
#
# Epoch 00032: val_acc improved from 0.78800 to 0.79200, saving model to weights.traint_40zoom_modelsimple_avec_crop.hdf5
# Epoch 33/100
# 1000/1000 [==============================] - 1s 574us/step - loss: 0.6102 - acc: 0.6680 - val_loss: 0.5422 - val_acc: 0.7080
#
# Epoch 00033: val_acc did not improve from 0.79200
# Epoch 34/100
# 1000/1000 [==============================] - 1s 555us/step - loss: 0.5720 - acc: 0.7010 - val_loss: 0.5980 - val_acc: 0.6920
#
# Epoch 00034: val_acc did not improve from 0.79200
# Epoch 35/100
# 1000/1000 [==============================] - 1s 559us/step - loss: 0.6104 - acc: 0.6720 - val_loss: 0.5516 - val_acc: 0.7000
#
# Epoch 00035: val_acc did not improve from 0.79200
# Epoch 36/100
# 1000/1000 [==============================] - 1s 557us/step - loss: 0.5525 - acc: 0.7370 - val_loss: 0.6206 - val_acc: 0.6160
#
# Epoch 00036: val_acc did not improve from 0.79200
# Epoch 37/100
# 1000/1000 [==============================] - 1s 557us/step - loss: 0.5980 - acc: 0.6670 - val_loss: 0.5578 - val_acc: 0.6800
#
# Epoch 00037: val_acc did not improve from 0.79200
# Epoch 38/100
# 1000/1000 [==============================] - 1s 555us/step - loss: 0.5658 - acc: 0.7230 - val_loss: 0.6467 - val_acc: 0.5800
#
# Epoch 00038: val_acc did not improve from 0.79200
# Epoch 39/100
# 1000/1000 [==============================] - 1s 549us/step - loss: 0.5369 - acc: 0.7510 - val_loss: 0.6020 - val_acc: 0.6720
#
# Epoch 00039: val_acc did not improve from 0.79200
# Epoch 40/100
# 1000/1000 [==============================] - 1s 557us/step - loss: 0.5948 - acc: 0.6840 - val_loss: 0.5070 - val_acc: 0.7480s - loss: 0.6089 - acc: 0.666
#
# Epoch 00040: val_acc did not improve from 0.79200
# Epoch 41/100
# 1000/1000 [==============================] - 1s 554us/step - loss: 0.5835 - acc: 0.6970 - val_loss: 0.5344 - val_acc: 0.7920
#
# Epoch 00041: val_acc did not improve from 0.79200
# Epoch 42/100
# 1000/1000 [==============================] - 1s 556us/step - loss: 0.5944 - acc: 0.6610 - val_loss: 0.5482 - val_acc: 0.6880
#
# Epoch 00042: val_acc did not improve from 0.79200
# Epoch 43/100
# 1000/1000 [==============================] - 1s 551us/step - loss: 0.6038 - acc: 0.6620 - val_loss: 0.5947 - val_acc: 0.6560
#
# Epoch 00043: val_acc did not improve from 0.79200
# Epoch 44/100
# 1000/1000 [==============================] - 1s 551us/step - loss: 0.5742 - acc: 0.6910 - val_loss: 0.6643 - val_acc: 0.6200
#
# Epoch 00044: val_acc did not improve from 0.79200
# Epoch 45/100
# 1000/1000 [==============================] - 1s 554us/step - loss: 0.5609 - acc: 0.6920 - val_loss: 0.5055 - val_acc: 0.7480
#
# Epoch 00045: val_acc did not improve from 0.79200
# Epoch 46/100
# 1000/1000 [==============================] - 1s 562us/step - loss: 0.5518 - acc: 0.7090 - val_loss: 0.6123 - val_acc: 0.6720
#
# Epoch 00046: val_acc did not improve from 0.79200
# Epoch 47/100
# 1000/1000 [==============================] - 1s 566us/step - loss: 0.5788 - acc: 0.7050 - val_loss: 0.5069 - val_acc: 0.7640
#
# Epoch 00047: val_acc did not improve from 0.79200
# Epoch 48/100
# 1000/1000 [==============================] - 1s 561us/step - loss: 0.5271 - acc: 0.7330 - val_loss: 0.5302 - val_acc: 0.7880
#
# Epoch 00048: val_acc did not improve from 0.79200
# Epoch 49/100
# 1000/1000 [==============================] - 1s 554us/step - loss: 0.5364 - acc: 0.7510 - val_loss: 0.6461 - val_acc: 0.5680
#
# Epoch 00049: val_acc did not improve from 0.79200
# Epoch 50/100
# 1000/1000 [==============================] - 1s 552us/step - loss: 0.5918 - acc: 0.6780 - val_loss: 0.6062 - val_acc: 0.7480
#
# Epoch 00050: val_acc did not improve from 0.79200
# Epoch 51/100
# 1000/1000 [==============================] - 1s 560us/step - loss: 0.5344 - acc: 0.7560 - val_loss: 0.4823 - val_acc: 0.7800
#
# Epoch 00051: val_acc did not improve from 0.79200
# Epoch 52/100
# 1000/1000 [==============================] - 1s 556us/step - loss: 0.4844 - acc: 0.7860 - val_loss: 0.7376 - val_acc: 0.6200
#
# Epoch 00052: val_acc did not improve from 0.79200
# Epoch 53/100
# 1000/1000 [==============================] - 1s 562us/step - loss: 0.6032 - acc: 0.6820 - val_loss: 0.4828 - val_acc: 0.7960
#
# Epoch 00053: val_acc improved from 0.79200 to 0.79600, saving model to weights.traint_40zoom_modelsimple_avec_crop.hdf5
# Epoch 54/100
# 1000/1000 [==============================] - 1s 565us/step - loss: 0.4944 - acc: 0.7670 - val_loss: 0.4611 - val_acc: 0.7920
#
# Epoch 00054: val_acc did not improve from 0.79600
# Epoch 55/100
# 1000/1000 [==============================] - 1s 553us/step - loss: 0.5766 - acc: 0.6980 - val_loss: 0.6011 - val_acc: 0.6720
#
# Epoch 00055: val_acc did not improve from 0.79600
# Epoch 56/100
# 1000/1000 [==============================] - 1s 557us/step - loss: 0.5648 - acc: 0.7110 - val_loss: 0.4929 - val_acc: 0.7960
#
# Epoch 00056: val_acc did not improve from 0.79600
# Epoch 57/100
# 1000/1000 [==============================] - 1s 559us/step - loss: 0.5182 - acc: 0.7540 - val_loss: 0.5853 - val_acc: 0.6680
#
# Epoch 00057: val_acc did not improve from 0.79600
# Epoch 58/100
# 1000/1000 [==============================] - 1s 553us/step - loss: 0.5272 - acc: 0.7180 - val_loss: 0.4634 - val_acc: 0.7960
#
# Epoch 00058: val_acc did not improve from 0.79600
# Epoch 59/100
# 1000/1000 [==============================] - 1s 554us/step - loss: 0.4759 - acc: 0.7850 - val_loss: 0.6463 - val_acc: 0.6560
#
# Epoch 00059: val_acc did not improve from 0.79600
# Epoch 60/100
# 1000/1000 [==============================] - 1s 564us/step - loss: 0.5684 - acc: 0.7170 - val_loss: 0.5337 - val_acc: 0.8040
#
# Epoch 00060: val_acc improved from 0.79600 to 0.80400, saving model to weights.traint_40zoom_modelsimple_avec_crop.hdf5
# Epoch 61/100
# 1000/1000 [==============================] - 1s 559us/step - loss: 0.5114 - acc: 0.7610 - val_loss: 0.5179 - val_acc: 0.7960
#
# Epoch 00061: val_acc did not improve from 0.80400
# Epoch 62/100
# 1000/1000 [==============================] - 1s 563us/step - loss: 0.4917 - acc: 0.7610 - val_loss: 0.4601 - val_acc: 0.7800
#
# Epoch 00062: val_acc did not improve from 0.80400
# Epoch 63/100
# 1000/1000 [==============================] - 1s 555us/step - loss: 0.4942 - acc: 0.7540 - val_loss: 0.6596 - val_acc: 0.6480
#
# Epoch 00063: val_acc did not improve from 0.80400
# Epoch 64/100
# 1000/1000 [==============================] - 1s 557us/step - loss: 0.4953 - acc: 0.7680 - val_loss: 0.5253 - val_acc: 0.7560
#
# Epoch 00064: val_acc did not improve from 0.80400
# Epoch 65/100
# 1000/1000 [==============================] - 1s 560us/step - loss: 0.4965 - acc: 0.7460 - val_loss: 0.5202 - val_acc: 0.7560
#
# Epoch 00065: val_acc did not improve from 0.80400
# Epoch 66/100
# 1000/1000 [==============================] - 1s 554us/step - loss: 0.5154 - acc: 0.7390 - val_loss: 0.4865 - val_acc: 0.7600
#
# Epoch 00066: val_acc did not improve from 0.80400
# Epoch 67/100
# 1000/1000 [==============================] - 1s 550us/step - loss: 0.5681 - acc: 0.7010 - val_loss: 0.5102 - val_acc: 0.7960
#
# Epoch 00067: val_acc did not improve from 0.80400
# Epoch 68/100
# 1000/1000 [==============================] - 1s 556us/step - loss: 0.5382 - acc: 0.7320 - val_loss: 0.6305 - val_acc: 0.6480
#
# Epoch 00068: val_acc did not improve from 0.80400
# Epoch 69/100
# 1000/1000 [==============================] - 1s 553us/step - loss: 0.4821 - acc: 0.7720 - val_loss: 0.5868 - val_acc: 0.7000
#
# Epoch 00069: val_acc did not improve from 0.80400
# Epoch 70/100
# 1000/1000 [==============================] - 1s 558us/step - loss: 0.4829 - acc: 0.7690 - val_loss: 0.6343 - val_acc: 0.6200
#
# Epoch 00070: val_acc did not improve from 0.80400
# Epoch 71/100
# 1000/1000 [==============================] - 1s 573us/step - loss: 0.4916 - acc: 0.7450 - val_loss: 0.4820 - val_acc: 0.7760
#
# Epoch 00071: val_acc did not improve from 0.80400
# Epoch 72/100
# 1000/1000 [==============================] - 1s 553us/step - loss: 0.4800 - acc: 0.7710 - val_loss: 0.6405 - val_acc: 0.6520
#
# Epoch 00072: val_acc did not improve from 0.80400
# Epoch 73/100
# 1000/1000 [==============================] - 1s 552us/step - loss: 0.4768 - acc: 0.7690 - val_loss: 0.7482 - val_acc: 0.5240
#
# Epoch 00073: val_acc did not improve from 0.80400
# Epoch 74/100
# 1000/1000 [==============================] - 1s 557us/step - loss: 0.5407 - acc: 0.7010 - val_loss: 0.4820 - val_acc: 0.7600
#
# Epoch 00074: val_acc did not improve from 0.80400
# Epoch 75/100
# 1000/1000 [==============================] - 1s 553us/step - loss: 0.5049 - acc: 0.7460 - val_loss: 0.6253 - val_acc: 0.6680
#
# Epoch 00075: val_acc did not improve from 0.80400
# Epoch 76/100
# 1000/1000 [==============================] - 1s 555us/step - loss: 0.4620 - acc: 0.8090 - val_loss: 0.5342 - val_acc: 0.7280
#
# Epoch 00076: val_acc did not improve from 0.80400
# Epoch 77/100
# 1000/1000 [==============================] - 1s 557us/step - loss: 0.5183 - acc: 0.7280 - val_loss: 0.6171 - val_acc: 0.6960
#
# Epoch 00077: val_acc did not improve from 0.80400
# Epoch 78/100
# 1000/1000 [==============================] - 1s 554us/step - loss: 0.4523 - acc: 0.8020 - val_loss: 0.5432 - val_acc: 0.7160
#
# Epoch 00078: val_acc did not improve from 0.80400
# Epoch 79/100
# 1000/1000 [==============================] - 1s 551us/step - loss: 0.4049 - acc: 0.8140 - val_loss: 0.4892 - val_acc: 0.7640
#
# Epoch 00079: val_acc did not improve from 0.80400
# Epoch 80/100
# 1000/1000 [==============================] - 1s 557us/step - loss: 0.4691 - acc: 0.7610 - val_loss: 0.4821 - val_acc: 0.8000
#
# Epoch 00080: val_acc did not improve from 0.80400
# Epoch 81/100
# 1000/1000 [==============================] - 1s 567us/step - loss: 0.4343 - acc: 0.8180 - val_loss: 0.4288 - val_acc: 0.7880
#
# Epoch 00081: val_acc did not improve from 0.80400
# Epoch 82/100
# 1000/1000 [==============================] - 1s 582us/step - loss: 0.4185 - acc: 0.7910 - val_loss: 0.4454 - val_acc: 0.7920
#
# Epoch 00082: val_acc did not improve from 0.80400
# Epoch 83/100
# 1000/1000 [==============================] - 1s 640us/step - loss: 0.4634 - acc: 0.7700 - val_loss: 0.4676 - val_acc: 0.7760
# Epoch 00083: val_acc did not improve from 0.80400
# Epoch 84/100
# 1000/1000 [==============================] - 1s 564us/step - loss: 0.3871 - acc: 0.8460 - val_loss: 0.6106 - val_acc: 0.6680
#
# Epoch 00084: val_acc did not improve from 0.80400
# Epoch 85/100
# 1000/1000 [==============================] - 1s 552us/step - loss: 0.4029 - acc: 0.8360 - val_loss: 1.1118 - val_acc: 0.5840
#
# Epoch 00085: val_acc did not improve from 0.80400
# Epoch 86/100
# 1000/1000 [==============================] - 1s 552us/step - loss: 0.6360 - acc: 0.6860 - val_loss: 0.4280 - val_acc: 0.7920
#
# Epoch 00086: val_acc did not improve from 0.80400
# Epoch 87/100
# 1000/1000 [==============================] - 1s 558us/step - loss: 0.4303 - acc: 0.8040 - val_loss: 0.4147 - val_acc: 0.7920
#
# Epoch 00087: val_acc did not improve from 0.80400
# Epoch 88/100
# 1000/1000 [==============================] - 1s 555us/step - loss: 0.3443 - acc: 0.8460 - val_loss: 0.5688 - val_acc: 0.6680
#
# Epoch 00088: val_acc did not improve from 0.80400
# Epoch 89/100
# 1000/1000 [==============================] - 1s 557us/step - loss: 0.4361 - acc: 0.7860 - val_loss: 0.4937 - val_acc: 0.7640
#
# Epoch 00089: val_acc did not improve from 0.80400
# Epoch 90/100
# 1000/1000 [==============================] - 1s 556us/step - loss: 0.3494 - acc: 0.8750 - val_loss: 0.4793 - val_acc: 0.7760
#
# Epoch 00090: val_acc did not improve from 0.80400
# Epoch 91/100
# 1000/1000 [==============================] - 1s 557us/step - loss: 0.3962 - acc: 0.8170 - val_loss: 0.4198 - val_acc: 0.7960
#
# Epoch 00091: val_acc did not improve from 0.80400
# Epoch 92/100
# 1000/1000 [==============================] - 1s 555us/step - loss: 0.3324 - acc: 0.8850 - val_loss: 0.3956 - val_acc: 0.8120
#
# Epoch 00092: val_acc improved from 0.80400 to 0.81200, saving model to weights.traint_40zoom_modelsimple_avec_crop.hdf5
# Epoch 93/100
# 1000/1000 [==============================] - 1s 557us/step - loss: 0.3840 - acc: 0.8180 - val_loss: 0.4356 - val_acc: 0.8040
#
# Epoch 00093: val_acc did not improve from 0.81200
# Epoch 94/100
# 1000/1000 [==============================] - 1s 543us/step - loss: 0.2982 - acc: 0.9040 - val_loss: 0.4812 - val_acc: 0.7720
#
# Epoch 00094: val_acc did not improve from 0.81200
# Epoch 95/100
# 1000/1000 [==============================] - 1s 632us/step - loss: 0.4084 - acc: 0.8070 - val_loss: 0.4162 - val_acc: 0.7960
#
# Epoch 00095: val_acc did not improve from 0.81200
# Epoch 96/100
# 1000/1000 [==============================] - 1s 554us/step - loss: 0.5123 - acc: 0.7380 - val_loss: 0.4038 - val_acc: 0.8080
#
# Epoch 00096: val_acc did not improve from 0.81200
# Epoch 97/100
# 1000/1000 [==============================] - 1s 552us/step - loss: 0.2869 - acc: 0.8910 - val_loss: 0.6392 - val_acc: 0.7000
#
# Epoch 00097: val_acc did not improve from 0.81200
# Epoch 98/100
# 1000/1000 [==============================] - 1s 552us/step - loss: 0.3811 - acc: 0.8190 - val_loss: 0.3919 - val_acc: 0.8080
#
# Epoch 00098: val_acc did not improve from 0.81200
# Epoch 99/100
# 1000/1000 [==============================] - 1s 555us/step - loss: 0.3368 - acc: 0.8720 - val_loss: 0.4071 - val_acc: 0.8080
#
# Epoch 00099: val_acc did not improve from 0.81200
# Epoch 100/100
# 1000/1000 [==============================] - 1s 555us/step - loss: 0.3682 - acc: 0.8200 - val_loss: 0.4761 - val_acc: 0.7680
#
# Epoch 00100: val_acc did not improve from 0.81200
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 48, 48, 32)        896
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 46, 46, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 23, 23, 64)        0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 33856)             0
# _________________________________________________________________
# dense_15 (Dense)             (None, 128)               4333696
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 4,353,346
# Trainable params: 4,353,346
# Non-trainable params: 0
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.7679999985694885
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.91      0.57      0.70       119
#       IDC(+)       0.71      0.95      0.81       131
#
#    micro avg       0.77      0.77      0.77       250
#    macro avg       0.81      0.76      0.76       250
# weighted avg       0.80      0.77      0.76       250
#
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_40m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_40m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
class MetricsCheckpoint(Callback):
    """apres chaque epoch en sauvegarde metrics"""
    def __init__(self, savepath):
        #constructeur de la class
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')
def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 5
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    #test d'un premier model
    model.add(Conv2D(32, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=input_shape))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    # load weights
    model.load_weights("weights.traint_40zoom_modelsimple_avec_crop.hdf5")
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
     
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 48, 48, 32)        896
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 46, 46, 64)        18496
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 23, 23, 64)        0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 33856)             0
# _________________________________________________________________
# dense_21 (Dense)             (None, 128)               4333696
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 4,353,346
# Trainable params: 4,353,346
# Non-trainable params: 0
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.8880000004768371
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.96      0.82      0.89       132
#       IDC(+)       0.83      0.97      0.89       118
#
#    micro avg       0.89      0.89      0.89       250
#    macro avg       0.90      0.89      0.89       250
# weighted avg       0.90      0.89      0.89       250

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_100m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_100m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
class MetricsCheckpoint(Callback):
    """apres chaque epoch en sauvegarde metrics"""
    def __init__(self, savepath):
        #constructeur de la class
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')
def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 5
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    #test d'un premier model
    model.add(Conv2D(32, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=input_shape))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    # load weights
    model.load_weights("weights.traint_40zoom_modelsimple_avec_crop.hdf5")
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
     
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_29 (Conv2D)           (None, 48, 48, 32)        896
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 46, 46, 64)        18496
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 23, 23, 64)        0
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 33856)             0
# _________________________________________________________________
# dense_29 (Dense)             (None, 128)               4333696
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 4,353,346
# Trainable params: 4,353,346
# Non-trainable params: 0
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.8062015503875969
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.83      0.73      0.77       117
#       IDC(+)       0.79      0.87      0.83       141
#
#    micro avg       0.81      0.81      0.81       258
#    macro avg       0.81      0.80      0.80       258
# weighted avg       0.81      0.81      0.80       258

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_200m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_200m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
class MetricsCheckpoint(Callback):
    """apres chaque epoch en sauvegarde metrics"""
    def __init__(self, savepath):
        #constructeur de la class
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')
def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 5
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    #test d'un premier model
    model.add(Conv2D(32, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=input_shape))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    # load weights
    model.load_weights("weights.traint_40zoom_modelsimple_avec_crop.hdf5")
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
     
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 48, 48, 32)        896
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 46, 46, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 23, 23, 64)        0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 33856)             0
# _________________________________________________________________
# dense_25 (Dense)             (None, 128)               4333696
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 4,353,346
# Trainable params: 4,353,346
# Non-trainable params: 0
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.859999997138977
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.89      0.81      0.85       123
#       IDC(+)       0.83      0.91      0.87       127
#
#    micro avg       0.86      0.86      0.86       250
#    macro avg       0.86      0.86      0.86       250
# weighted avg       0.86      0.86      0.86       250

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_400m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_400m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
class MetricsCheckpoint(Callback):
    """apres chaque epoch en sauvegarde metrics"""
    def __init__(self, savepath):
        #constructeur de la class
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')
def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 5
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    #test d'un premier model
    model.add(Conv2D(32, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=input_shape))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    # load weights
    model.load_weights("weights.traint_40zoom_modelsimple_avec_crop.hdf5")
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
     
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_31 (Conv2D)           (None, 48, 48, 32)        896
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 46, 46, 64)        18496
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 23, 23, 64)        0
# _________________________________________________________________
# flatten_16 (Flatten)         (None, 33856)             0
# _________________________________________________________________
# dense_31 (Dense)             (None, 128)               4333696
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 4,353,346
# Trainable params: 4,353,346
# Non-trainable params: 0
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.8220338972948366
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.84      0.78      0.81       112
#       IDC(+)       0.81      0.86      0.84       124
#
#    micro avg       0.82      0.82      0.82       236
#    macro avg       0.82      0.82      0.82       236
# weighted avg       0.82      0.82      0.82       236

# %%
#simple model
def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')

def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 100 
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu', input_shape = input_shape))
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1024, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(512, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation = "softmax"))
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
     # checkpoint
    filepath="weights.traint_40zoom_modelcomplex_avec_crop.hdf5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]
    history =model.fit(x_train, y_train,
              batch_size=batch_size,
              verbose=1,
              epochs=epochs,
              validation_data=(x_test, y_test),callbacks=callbacks_list)
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# Train on 1000 samples, validate on 250 samples
# Epoch 1/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: 2.2944 - acc: 0.6080 - val_loss: 1.3851 - val_acc: 0.5320
#
# Epoch 00001: val_acc improved from -inf to 0.53200, saving model to weights.traint_40zoom_modelcomplex_avec_crop.hdf5
# Epoch 2/100
# 1000/1000 [==============================] - 1s 804us/step - loss: 0.6437 - acc: 0.7580 - val_loss: 2.4585 - val_acc: 0.5560
#
# Epoch 00002: val_acc improved from 0.53200 to 0.55600, saving model to weights.traint_40zoom_modelcomplex_avec_crop.hdf5
# Epoch 3/100
# 1000/1000 [==============================] - 1s 872us/step - loss: 0.4308 - acc: 0.8300 - val_loss: 0.5836 - val_acc: 0.6440
#
# Epoch 00003: val_acc improved from 0.55600 to 0.64400, saving model to weights.traint_40zoom_modelcomplex_avec_crop.hdf5
# Epoch 4/100
# 1000/1000 [==============================] - 1s 809us/step - loss: 0.4434 - acc: 0.8190 - val_loss: 0.9448 - val_acc: 0.5800
#
# Epoch 00004: val_acc did not improve from 0.64400
# Epoch 5/100
# 1000/1000 [==============================] - 1s 843us/step - loss: 0.3293 - acc: 0.8580 - val_loss: 0.4570 - val_acc: 0.7600
#
# Epoch 00005: val_acc improved from 0.64400 to 0.76000, saving model to weights.traint_40zoom_modelcomplex_avec_crop.hdf5
# Epoch 6/100
# 1000/1000 [==============================] - 1s 840us/step - loss: 0.3091 - acc: 0.8780 - val_loss: 1.0937 - val_acc: 0.6280
#
# Epoch 00006: val_acc did not improve from 0.76000
# Epoch 7/100
# 1000/1000 [==============================] - 1s 817us/step - loss: 0.3803 - acc: 0.8490 - val_loss: 1.1011 - val_acc: 0.4960
#
# Epoch 00007: val_acc did not improve from 0.76000
# Epoch 8/100
# 1000/1000 [==============================] - 1s 820us/step - loss: 0.3055 - acc: 0.8740 - val_loss: 0.6797 - val_acc: 0.5680
#
# Epoch 00008: val_acc did not improve from 0.76000
# Epoch 9/100
# 1000/1000 [==============================] - 1s 812us/step - loss: 0.3810 - acc: 0.8310 - val_loss: 0.8057 - val_acc: 0.6440
#
# Epoch 00009: val_acc did not improve from 0.76000
# Epoch 10/100
# 1000/1000 [==============================] - 1s 867us/step - loss: 0.2249 - acc: 0.9070 - val_loss: 0.4137 - val_acc: 0.8200
#
# Epoch 00010: val_acc improved from 0.76000 to 0.82000, saving model to weights.traint_40zoom_modelcomplex_avec_crop.hdf5
# Epoch 11/100
# 1000/1000 [==============================] - 1s 883us/step - loss: 0.2580 - acc: 0.8990 - val_loss: 0.9076 - val_acc: 0.5920
#
# Epoch 00011: val_acc did not improve from 0.82000
# Epoch 12/100
# 1000/1000 [==============================] - 1s 882us/step - loss: 0.2682 - acc: 0.8890 - val_loss: 1.7099 - val_acc: 0.6200
#
# Epoch 00012: val_acc did not improve from 0.82000
# Epoch 13/100
# 1000/1000 [==============================] - 1s 841us/step - loss: 0.1622 - acc: 0.9420 - val_loss: 3.1472 - val_acc: 0.5440
#
# Epoch 00013: val_acc did not improve from 0.82000
# Epoch 14/100
# 1000/1000 [==============================] - 1s 850us/step - loss: 0.1885 - acc: 0.9240 - val_loss: 1.7780 - val_acc: 0.6400
#
# Epoch 00014: val_acc did not improve from 0.82000
# Epoch 15/100
# 1000/1000 [==============================] - 1s 851us/step - loss: 0.2616 - acc: 0.8920 - val_loss: 2.6146 - val_acc: 0.5680
#
# Epoch 00015: val_acc did not improve from 0.82000
# Epoch 16/100
# 1000/1000 [==============================] - 1s 785us/step - loss: 0.1730 - acc: 0.9290 - val_loss: 0.5115 - val_acc: 0.7720
#
# Epoch 00016: val_acc did not improve from 0.82000
# Epoch 17/100
# 1000/1000 [==============================] - 1s 782us/step - loss: 0.2793 - acc: 0.9030 - val_loss: 4.4775 - val_acc: 0.5800
#
# Epoch 00017: val_acc did not improve from 0.82000
# Epoch 18/100
# 1000/1000 [==============================] - 1s 797us/step - loss: 0.1311 - acc: 0.9530 - val_loss: 4.5621 - val_acc: 0.6440
#
# Epoch 00018: val_acc did not improve from 0.82000
# Epoch 19/100
# 1000/1000 [==============================] - 1s 793us/step - loss: 0.0958 - acc: 0.9570 - val_loss: 4.2294 - val_acc: 0.5960
#
# Epoch 00019: val_acc did not improve from 0.82000
# Epoch 20/100
# 1000/1000 [==============================] - 1s 789us/step - loss: 0.1446 - acc: 0.9460 - val_loss: 3.3722 - val_acc: 0.5760
#
# Epoch 00020: val_acc did not improve from 0.82000
# Epoch 21/100
# 1000/1000 [==============================] - 1s 831us/step - loss: 0.1358 - acc: 0.9520 - val_loss: 1.1920 - val_acc: 0.6600
#
# Epoch 00021: val_acc did not improve from 0.82000
# Epoch 22/100
# 1000/1000 [==============================] - 1s 801us/step - loss: 0.1503 - acc: 0.9530 - val_loss: 1.5823 - val_acc: 0.7120
#
# Epoch 00022: val_acc did not improve from 0.82000
# Epoch 23/100
# 1000/1000 [==============================] - 1s 810us/step - loss: 0.0813 - acc: 0.9660 - val_loss: 3.4898 - val_acc: 0.6120
#
# Epoch 00023: val_acc did not improve from 0.82000
# Epoch 24/100
# 1000/1000 [==============================] - 1s 795us/step - loss: 0.0832 - acc: 0.9670 - val_loss: 0.6762 - val_acc: 0.6680
#
# Epoch 00024: val_acc did not improve from 0.82000
# Epoch 25/100
# 1000/1000 [==============================] - 1s 815us/step - loss: 0.1409 - acc: 0.9500 - val_loss: 2.0887 - val_acc: 0.6960
#
# Epoch 00025: val_acc did not improve from 0.82000
# Epoch 26/100
# 1000/1000 [==============================] - 1s 815us/step - loss: 0.0800 - acc: 0.9710 - val_loss: 1.9081 - val_acc: 0.6800
#
# Epoch 00026: val_acc did not improve from 0.82000
# Epoch 27/100
# 1000/1000 [==============================] - 1s 818us/step - loss: 0.0496 - acc: 0.9830 - val_loss: 4.6721 - val_acc: 0.6240
#
# Epoch 00027: val_acc did not improve from 0.82000
# Epoch 28/100
# 1000/1000 [==============================] - 1s 817us/step - loss: 0.1040 - acc: 0.9670 - val_loss: 5.0559 - val_acc: 0.5960
#
# Epoch 00028: val_acc did not improve from 0.82000
# Epoch 29/100
# 1000/1000 [==============================] - 1s 810us/step - loss: 0.1232 - acc: 0.9670 - val_loss: 2.3136 - val_acc: 0.6480
#
# Epoch 00029: val_acc did not improve from 0.82000
# Epoch 30/100
# 1000/1000 [==============================] - 1s 809us/step - loss: 0.0803 - acc: 0.9770 - val_loss: 1.9697 - val_acc: 0.7160
#
# Epoch 00030: val_acc did not improve from 0.82000
# Epoch 31/100
# 1000/1000 [==============================] - 1s 808us/step - loss: 0.0437 - acc: 0.9870 - val_loss: 1.0925 - val_acc: 0.7040
#
# Epoch 00031: val_acc did not improve from 0.82000
# Epoch 32/100
# 1000/1000 [==============================] - 1s 807us/step - loss: 0.1494 - acc: 0.9510 - val_loss: 4.3932 - val_acc: 0.6320
#
# Epoch 00032: val_acc did not improve from 0.82000
# Epoch 33/100
# 1000/1000 [==============================] - 1s 833us/step - loss: 0.0381 - acc: 0.9810 - val_loss: 0.7314 - val_acc: 0.8320
#
# Epoch 00033: val_acc improved from 0.82000 to 0.83200, saving model to weights.traint_40zoom_modelcomplex_avec_crop.hdf5
# Epoch 34/100
# 1000/1000 [==============================] - 1s 848us/step - loss: 0.0331 - acc: 0.9850 - val_loss: 4.1974 - val_acc: 0.6480
#
# Epoch 00034: val_acc did not improve from 0.83200
# Epoch 35/100
# 1000/1000 [==============================] - 1s 852us/step - loss: 0.0271 - acc: 0.9910 - val_loss: 0.9849 - val_acc: 0.8280
#
# Epoch 00035: val_acc did not improve from 0.83200
# Epoch 36/100
# 1000/1000 [==============================] - 1s 828us/step - loss: 0.0182 - acc: 0.9950 - val_loss: 0.9268 - val_acc: 0.7520
#
# Epoch 00036: val_acc did not improve from 0.83200
# Epoch 37/100
# 1000/1000 [==============================] - 1s 839us/step - loss: 0.0165 - acc: 0.9940 - val_loss: 0.4995 - val_acc: 0.8080
#
# Epoch 00037: val_acc did not improve from 0.83200
# Epoch 38/100
# 1000/1000 [==============================] - 1s 790us/step - loss: 0.0307 - acc: 0.9900 - val_loss: 0.4124 - val_acc: 0.9040
#
# Epoch 00038: val_acc improved from 0.83200 to 0.90400, saving model to weights.traint_40zoom_modelcomplex_avec_crop.hdf5
# Epoch 39/100
# 1000/1000 [==============================] - 1s 781us/step - loss: 0.0910 - acc: 0.9730 - val_loss: 1.6513 - val_acc: 0.8040
#
# Epoch 00039: val_acc did not improve from 0.90400
# Epoch 40/100
# 1000/1000 [==============================] - 1s 796us/step - loss: 0.0739 - acc: 0.9710 - val_loss: 1.0883 - val_acc: 0.7120
#
# Epoch 00040: val_acc did not improve from 0.90400
# Epoch 41/100
# 1000/1000 [==============================] - 1s 792us/step - loss: 0.1159 - acc: 0.9650 - val_loss: 0.8352 - val_acc: 0.7840
# Epoch 00041: val_acc did not improve from 0.90400
# Epoch 42/100
# 1000/1000 [==============================] - 1s 786us/step - loss: 0.0231 - acc: 0.9930 - val_loss: 2.2158 - val_acc: 0.7720
#
# Epoch 00042: val_acc did not improve from 0.90400
# Epoch 43/100
# 1000/1000 [==============================] - 1s 792us/step - loss: 0.0182 - acc: 0.9940 - val_loss: 0.2432 - val_acc: 0.9280
#
# Epoch 00043: val_acc improved from 0.90400 to 0.92800, saving model to weights.traint_40zoom_modelcomplex_avec_crop.hdf5
# Epoch 44/100
# 1000/1000 [==============================] - 1s 781us/step - loss: 0.0463 - acc: 0.9860 - val_loss: 1.6070 - val_acc: 0.8520
#
# Epoch 00044: val_acc did not improve from 0.92800
# Epoch 45/100
# 1000/1000 [==============================] - 1s 791us/step - loss: 0.0109 - acc: 0.9980 - val_loss: 0.5967 - val_acc: 0.8360
#
# Epoch 00045: val_acc did not improve from 0.92800
# Epoch 46/100
# 1000/1000 [==============================] - 1s 807us/step - loss: 0.0274 - acc: 0.9900 - val_loss: 5.0200 - val_acc: 0.4760
#
# Epoch 00046: val_acc did not improve from 0.92800
# Epoch 47/100
# 1000/1000 [==============================] - 1s 801us/step - loss: 0.0726 - acc: 0.9740 - val_loss: 5.6870 - val_acc: 0.6000
#
# Epoch 00047: val_acc did not improve from 0.92800
# Epoch 48/100
# 1000/1000 [==============================] - 1s 801us/step - loss: 0.0399 - acc: 0.9860 - val_loss: 0.6967 - val_acc: 0.8520
#
# Epoch 00048: val_acc did not improve from 0.92800
# Epoch 49/100
# 1000/1000 [==============================] - 1s 778us/step - loss: 0.0216 - acc: 0.9920 - val_loss: 0.5777 - val_acc: 0.8360
#
# Epoch 00049: val_acc did not improve from 0.92800
# Epoch 50/100
# 1000/1000 [==============================] - 1s 789us/step - loss: 0.0329 - acc: 0.9920 - val_loss: 1.9863 - val_acc: 0.7560
#
# Epoch 00050: val_acc did not improve from 0.92800
# Epoch 51/100
# 1000/1000 [==============================] - 1s 790us/step - loss: 0.0224 - acc: 0.9930 - val_loss: 3.1321 - val_acc: 0.6440
#
# Epoch 00051: val_acc did not improve from 0.92800
# Epoch 52/100
# 1000/1000 [==============================] - 1s 787us/step - loss: 0.0111 - acc: 0.9930 - val_loss: 1.1859 - val_acc: 0.7640
#
# Epoch 00052: val_acc did not improve from 0.92800
# Epoch 53/100
# 1000/1000 [==============================] - 1s 803us/step - loss: 0.0167 - acc: 0.9960 - val_loss: 0.1972 - val_acc: 0.9440
#
# Epoch 00053: val_acc improved from 0.92800 to 0.94400, saving model to weights.traint_40zoom_modelcomplex_avec_crop.hdf5
# Epoch 54/100
# 1000/1000 [==============================] - 1s 794us/step - loss: 0.0053 - acc: 0.9990 - val_loss: 0.4053 - val_acc: 0.9160
#
# Epoch 00054: val_acc did not improve from 0.94400
# Epoch 55/100
# 1000/1000 [==============================] - 1s 788us/step - loss: 0.0606 - acc: 0.9830 - val_loss: 5.4011 - val_acc: 0.5080
#
# Epoch 00055: val_acc did not improve from 0.94400
# Epoch 56/100
# 1000/1000 [==============================] - 1s 790us/step - loss: 0.0184 - acc: 0.9930 - val_loss: 0.4051 - val_acc: 0.9240
#
# Epoch 00056: val_acc did not improve from 0.94400
# Epoch 57/100
# 1000/1000 [==============================] - 1s 783us/step - loss: 0.0229 - acc: 0.9910 - val_loss: 3.5267 - val_acc: 0.6400
#
# Epoch 00057: val_acc did not improve from 0.94400
# Epoch 58/100
# 1000/1000 [==============================] - 1s 798us/step - loss: 0.0384 - acc: 0.9900 - val_loss: 1.8004 - val_acc: 0.7080
#
# Epoch 00058: val_acc did not improve from 0.94400
# Epoch 59/100
# 1000/1000 [==============================] - 1s 811us/step - loss: 0.0084 - acc: 0.9970 - val_loss: 1.7873 - val_acc: 0.6960
#
# Epoch 00059: val_acc did not improve from 0.94400
# Epoch 60/100
# 1000/1000 [==============================] - 1s 813us/step - loss: 0.0021 - acc: 0.9990 - val_loss: 2.0241 - val_acc: 0.6760
#
# Epoch 00060: val_acc did not improve from 0.94400
# Epoch 61/100
# 1000/1000 [==============================] - 1s 804us/step - loss: 0.0062 - acc: 0.9970 - val_loss: 1.3018 - val_acc: 0.7560
#
# Epoch 00061: val_acc did not improve from 0.94400
# Epoch 62/100
# 1000/1000 [==============================] - 1s 783us/step - loss: 0.0025 - acc: 1.0000 - val_loss: 0.5331 - val_acc: 0.8800
#
# Epoch 00062: val_acc did not improve from 0.94400
# Epoch 63/100
# 1000/1000 [==============================] - 1s 794us/step - loss: 0.0070 - acc: 0.9990 - val_loss: 0.4744 - val_acc: 0.9160
#
# Epoch 00063: val_acc did not improve from 0.94400
# Epoch 64/100
# 1000/1000 [==============================] - 1s 801us/step - loss: 0.0343 - acc: 0.9890 - val_loss: 1.4163 - val_acc: 0.7800
#
# Epoch 00064: val_acc did not improve from 0.94400
# Epoch 65/100
# 1000/1000 [==============================] - 1s 783us/step - loss: 0.0448 - acc: 0.9900 - val_loss: 0.9213 - val_acc: 0.8600
#
# Epoch 00065: val_acc did not improve from 0.94400
# Epoch 66/100
# 1000/1000 [==============================] - 1s 786us/step - loss: 0.0567 - acc: 0.9800 - val_loss: 0.7565 - val_acc: 0.8360
#
# Epoch 00066: val_acc did not improve from 0.94400
# Epoch 67/100
# 1000/1000 [==============================] - 1s 791us/step - loss: 0.0088 - acc: 0.9960 - val_loss: 2.2717 - val_acc: 0.7200
#
# Epoch 00067: val_acc did not improve from 0.94400
# Epoch 68/100
# 1000/1000 [==============================] - 1s 786us/step - loss: 0.0086 - acc: 0.9960 - val_loss: 1.9254 - val_acc: 0.7360
#
# Epoch 00068: val_acc did not improve from 0.94400
# Epoch 69/100
# 1000/1000 [==============================] - 1s 782us/step - loss: 0.0177 - acc: 0.9930 - val_loss: 2.5266 - val_acc: 0.7560
#
# Epoch 00069: val_acc did not improve from 0.94400
# Epoch 70/100
# 1000/1000 [==============================] - 1s 789us/step - loss: 0.0155 - acc: 0.9920 - val_loss: 3.0644 - val_acc: 0.6800
#
# Epoch 00070: val_acc did not improve from 0.94400
# Epoch 71/100
# 1000/1000 [==============================] - 1s 791us/step - loss: 0.0036 - acc: 0.9990 - val_loss: 1.0648 - val_acc: 0.8160
#
# Epoch 00071: val_acc did not improve from 0.94400
# Epoch 72/100
# 1000/1000 [==============================] - 1s 781us/step - loss: 0.0065 - acc: 0.9990 - val_loss: 1.3580 - val_acc: 0.7000
#
# Epoch 00072: val_acc did not improve from 0.94400
# Epoch 73/100
# 1000/1000 [==============================] - 1s 796us/step - loss: 0.0135 - acc: 0.9930 - val_loss: 3.2595 - val_acc: 0.5840
#
# Epoch 00073: val_acc did not improve from 0.94400
# Epoch 74/100
# 1000/1000 [==============================] - 1s 806us/step - loss: 0.0032 - acc: 0.9990 - val_loss: 2.6239 - val_acc: 0.5720
#
# Epoch 00074: val_acc did not improve from 0.94400
# Epoch 75/100
# 1000/1000 [==============================] - 1s 799us/step - loss: 0.0414 - acc: 0.9880 - val_loss: 4.4518 - val_acc: 0.6240
#
# Epoch 00075: val_acc did not improve from 0.94400
# Epoch 76/100
# 1000/1000 [==============================] - 1s 784us/step - loss: 0.0308 - acc: 0.9880 - val_loss: 2.3047 - val_acc: 0.7400
#
# Epoch 00076: val_acc did not improve from 0.94400
# Epoch 77/100
# 1000/1000 [==============================] - 1s 781us/step - loss: 0.0022 - acc: 1.0000 - val_loss: 0.3568 - val_acc: 0.9360
#
# Epoch 00077: val_acc did not improve from 0.94400
# Epoch 78/100
# 1000/1000 [==============================] - 1s 784us/step - loss: 0.0517 - acc: 0.9900 - val_loss: 6.3061 - val_acc: 0.4600
#
# Epoch 00078: val_acc did not improve from 0.94400
# Epoch 79/100
# 1000/1000 [==============================] - 1s 781us/step - loss: 0.1044 - acc: 0.9820 - val_loss: 6.0106 - val_acc: 0.5760
#
# Epoch 00079: val_acc did not improve from 0.94400
# Epoch 80/100
# 1000/1000 [==============================] - 1s 790us/step - loss: 0.0242 - acc: 0.9940 - val_loss: 5.5133 - val_acc: 0.6040
#
# Epoch 00080: val_acc did not improve from 0.94400
# Epoch 81/100
# 1000/1000 [==============================] - 1s 791us/step - loss: 0.0140 - acc: 0.9930 - val_loss: 5.2009 - val_acc: 0.5800
#
# Epoch 00081: val_acc did not improve from 0.94400
# Epoch 82/100
# 1000/1000 [==============================] - 1s 792us/step - loss: 0.0086 - acc: 0.9970 - val_loss: 3.0533 - val_acc: 0.7160
#
# Epoch 00082: val_acc did not improve from 0.94400
# Epoch 83/100
# 1000/1000 [==============================] - 1s 786us/step - loss: 0.0037 - acc: 0.9980 - val_loss: 0.9568 - val_acc: 0.8720
#
# Epoch 00083: val_acc did not improve from 0.94400
# Epoch 84/100
# 1000/1000 [==============================] - 1s 787us/step - loss: 0.0071 - acc: 0.9980 - val_loss: 1.4577 - val_acc: 0.8320
#
# Epoch 00084: val_acc did not improve from 0.94400
# Epoch 85/100
# 1000/1000 [==============================] - 1s 805us/step - loss: 0.0022 - acc: 1.0000 - val_loss: 1.3085 - val_acc: 0.8560
#
# Epoch 00085: val_acc did not improve from 0.94400
# Epoch 86/100
# 1000/1000 [==============================] - 1s 820us/step - loss: 0.0098 - acc: 0.9970 - val_loss: 3.0783 - val_acc: 0.7320
#
# Epoch 00086: val_acc did not improve from 0.94400
# Epoch 87/100
# 1000/1000 [==============================] - 1s 793us/step - loss: 0.0160 - acc: 0.9950 - val_loss: 0.3206 - val_acc: 0.9400
#
# Epoch 00087: val_acc did not improve from 0.94400
# Epoch 88/100
# 1000/1000 [==============================] - 1s 787us/step - loss: 3.5206e-04 - acc: 1.0000 - val_loss: 0.4132 - val_acc: 0.9200
#
# Epoch 00088: val_acc did not improve from 0.94400
# Epoch 89/100
# 1000/1000 [==============================] - 1s 792us/step - loss: 5.9472e-04 - acc: 1.0000 - val_loss: 0.2976 - val_acc: 0.9480
#
# Epoch 00089: val_acc improved from 0.94400 to 0.94800, saving model to weights.traint_40zoom_modelcomplex_avec_crop.hdf5
# Epoch 90/100
# 1000/1000 [==============================] - 1s 788us/step - loss: 5.0761e-04 - acc: 1.0000 - val_loss: 0.0685 - val_acc: 0.9840
#
# Epoch 00090: val_acc improved from 0.94800 to 0.98400, saving model to weights.traint_40zoom_modelcomplex_avec_crop.hdf5
# Epoch 91/100
# 1000/1000 [==============================] - 1s 795us/step - loss: 5.4614e-04 - acc: 1.0000 - val_loss: 0.2645 - val_acc: 0.9360
#
# Epoch 00091: val_acc did not improve from 0.98400
# Epoch 92/100
# 1000/1000 [==============================] - 1s 782us/step - loss: 9.2277e-04 - acc: 1.0000 - val_loss: 0.1712 - val_acc: 0.9520
#
# Epoch 00092: val_acc did not improve from 0.98400
# Epoch 93/100
# 1000/1000 [==============================] - 1s 799us/step - loss: 0.0011 - acc: 1.0000 - val_loss: 0.7191 - val_acc: 0.8640
#
# Epoch 00093: val_acc did not improve from 0.98400
# Epoch 94/100
# 1000/1000 [==============================] - 1s 784us/step - loss: 0.0021 - acc: 0.9990 - val_loss: 2.2810 - val_acc: 0.7680
#
# Epoch 00094: val_acc did not improve from 0.98400
# Epoch 95/100
# 1000/1000 [==============================] - 1s 788us/step - loss: 0.0049 - acc: 0.9990 - val_loss: 2.0720 - val_acc: 0.8040
#
# Epoch 00095: val_acc did not improve from 0.98400
# Epoch 96/100
# 1000/1000 [==============================] - 1s 790us/step - loss: 0.0098 - acc: 0.9970 - val_loss: 0.8385 - val_acc: 0.8680
#
# Epoch 00096: val_acc did not improve from 0.98400
# Epoch 97/100
# 1000/1000 [==============================] - 1s 782us/step - loss: 0.0196 - acc: 0.9970 - val_loss: 3.6526 - val_acc: 0.68800
#
# Epoch 00097: val_acc did not improve from 0.98400
# Epoch 98/100
# 1000/1000 [==============================] - 1s 800us/step - loss: 0.0267 - acc: 0.9930 - val_loss: 5.9166 - val_acc: 0.5560
#
# Epoch 00098: val_acc did not improve from 0.98400
# Epoch 99/100
# 1000/1000 [==============================] - 1s 811us/step - loss: 0.0159 - acc: 0.9930 - val_loss: 6.2406 - val_acc: 0.5680
#
# Epoch 00099: val_acc did not improve from 0.98400
# Epoch 100/100
# 1000/1000 [==============================] - 1s 813us/step - loss: 0.0465 - acc: 0.9900 - val_loss: 2.2282 - val_acc: 0.7520
#
# Epoch 00100: val_acc did not improve from 0.98400
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_51 (Conv2D)           (None, 50, 50, 32)        896
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 50, 50, 32)        9248
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 25, 25, 32)        0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 25, 25, 32)        128
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 25, 25, 64)        18496
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 12, 12, 64)        256
# _________________________________________________________________
# dropout_49 (Dropout)         (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 12, 12, 86)        49622
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 12, 12, 86)        66650
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 6, 6, 86)          0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 6, 6, 86)          344
# _________________________________________________________________
# dropout_50 (Dropout)         (None, 6, 6, 86)          0
# _________________________________________________________________
# flatten_20 (Flatten)         (None, 3096)              0
# _________________________________________________________________
# dense_42 (Dense)             (None, 1024)              3171328
# _________________________________________________________________
# dropout_51 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_43 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_52 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_44 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 3,879,722
# Trainable params: 3,879,358
# Non-trainable params: 364
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.7519999990463256
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.72      0.85      0.78       130
#       IDC(+)       0.80      0.64      0.71       120
#
#    micro avg       0.75      0.75      0.75       250
#    macro avg       0.76      0.75      0.75       250
# weighted avg       0.76      0.75      0.75       250
#
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_40m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_40m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
class MetricsCheckpoint(Callback):
    """apres chaque epoch en sauvegarde metrics"""
    def __init__(self, savepath):
        #constructeur de la class
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')
def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 5
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    #test d'un premier model
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu', input_shape = input_shape))
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1024, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(512, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation = "softmax"))
    # load weights
    model.load_weights("weights.traint_40zoom_modelcomplex_avec_crop.hdf5")
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
     
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_57 (Conv2D)           (None, 50, 50, 32)        896
# _________________________________________________________________
# conv2d_58 (Conv2D)           (None, 50, 50, 32)        9248
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 25, 25, 32)        0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 25, 25, 32)        128
# _________________________________________________________________
# dropout_53 (Dropout)         (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 25, 25, 64)        18496
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 12, 12, 64)        256
# _________________________________________________________________
# dropout_54 (Dropout)         (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_61 (Conv2D)           (None, 12, 12, 86)        49622
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, 12, 12, 86)        66650
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 6, 6, 86)          0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 6, 6, 86)          344
# _________________________________________________________________
# dropout_55 (Dropout)         (None, 6, 6, 86)          0
# _________________________________________________________________
# flatten_21 (Flatten)         (None, 3096)              0
# _________________________________________________________________
# dense_45 (Dense)             (None, 1024)              3171328
# _________________________________________________________________
# dropout_56 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_46 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_57 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_47 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 3,879,722
# Trainable params: 3,879,358
# Non-trainable params: 364
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.992
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.99      0.99      0.99       113
#       IDC(+)       0.99      0.99      0.99       137
#
#    micro avg       0.99      0.99      0.99       250
#    macro avg       0.99      0.99      0.99       250
# weighted avg       0.99      0.99      0.99       250

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_100m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_100m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
class MetricsCheckpoint(Callback):
    """apres chaque epoch en sauvegarde metrics"""
    def __init__(self, savepath):
        #constructeur de la class
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')
def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 5
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    #test d'un premier model
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu', input_shape = input_shape))
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1024, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(512, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation = "softmax"))
    # load weights
    model.load_weights("weights.traint_40zoom_modelcomplex_avec_crop.hdf5")
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
     
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_49 (Conv2D)           (None, 50, 50, 32)        896
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 50, 50, 32)        9248
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 25, 25, 32)        0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 25, 25, 32)        128
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 25, 25, 64)        18496
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 12, 12, 64)        256
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 12, 12, 86)        49622
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 12, 12, 86)        66650
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 6, 6, 86)          0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 6, 6, 86)          344
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 6, 6, 86)          0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 3096)              0
# _________________________________________________________________
# dense_25 (Dense)             (None, 1024)              3171328
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_26 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 3,879,722
# Trainable params: 3,879,358
# Non-trainable params: 364
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.8875968992248062
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.85      0.94      0.89       126
#       IDC(+)       0.93      0.84      0.88       132
#
#    micro avg       0.89      0.89      0.89       258
#    macro avg       0.89      0.89      0.89       258
# weighted avg       0.89      0.89      0.89       258

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_200m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_200m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
class MetricsCheckpoint(Callback):
    """apres chaque epoch en sauvegarde metrics"""
    def __init__(self, savepath):
        #constructeur de la class
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')
def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 5
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    #test d'un premier model
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu', input_shape = input_shape))
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1024, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(512, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation = "softmax"))
    # load weights
    model.load_weights("weights.traint_40zoom_modelcomplex_avec_crop.hdf5")
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
     
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 50, 50, 32)        896
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 50, 50, 32)        9248
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 25, 25, 32)        0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 25, 25, 32)        128
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 25, 25, 64)        18496
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 12, 12, 64)        256
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 12, 12, 86)        49622
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 12, 12, 86)        66650
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 86)          0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 6, 6, 86)          344
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 6, 6, 86)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 3096)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1024)              3171328
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 3,879,722
# Trainable params: 3,879,358
# Non-trainable params: 364
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.904
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.89      0.93      0.91       129
#       IDC(+)       0.92      0.88      0.90       121
#
#    micro avg       0.90      0.90      0.90       250
#    macro avg       0.91      0.90      0.90       250
# weighted avg       0.90      0.90      0.90       250

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_400m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_400m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
class MetricsCheckpoint(Callback):
    """apres chaque epoch en sauvegarde metrics"""
    def __init__(self, savepath):
        #constructeur de la class
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')
def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 5
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    #test d'un premier model
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu', input_shape = input_shape))
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1024, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(512, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation = "softmax"))
    # load weights
    model.load_weights("weights.traint_40zoom_modelcomplex_avec_crop.hdf5")
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
     
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_75 (Conv2D)           (None, 50, 50, 32)        896
# _________________________________________________________________
# conv2d_76 (Conv2D)           (None, 50, 50, 32)        9248
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 25, 25, 32)        0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 25, 25, 32)        128
# _________________________________________________________________
# dropout_68 (Dropout)         (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_77 (Conv2D)           (None, 25, 25, 64)        18496
# _________________________________________________________________
# conv2d_78 (Conv2D)           (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 12, 12, 64)        256
# _________________________________________________________________
# dropout_69 (Dropout)         (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_79 (Conv2D)           (None, 12, 12, 86)        49622
# _________________________________________________________________
# conv2d_80 (Conv2D)           (None, 12, 12, 86)        66650
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 6, 6, 86)          0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 6, 6, 86)          344
# _________________________________________________________________
# dropout_70 (Dropout)         (None, 6, 6, 86)          0
# _________________________________________________________________
# flatten_24 (Flatten)         (None, 3096)              0
# _________________________________________________________________
# dense_54 (Dense)             (None, 1024)              3171328
# _________________________________________________________________
# dropout_71 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_55 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_72 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_56 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 3,879,722
# Trainable params: 3,879,358
# Non-trainable params: 364
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.8177966111797398
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.75      0.90      0.82       106
#       IDC(+)       0.90      0.75      0.82       130
#
#    micro avg       0.82      0.82      0.82       236
#    macro avg       0.82      0.83      0.82       236
# weighted avg       0.83      0.82      0.82       236

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoo.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
class MetricsCheckpoint(Callback):
    """apres chaque epoch en sauvegarde metrics"""
    def __init__(self, savepath):
        #constructeur de la class
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')
def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 5
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    #test d'un premier model
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu', input_shape = input_shape))
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1024, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(512, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation = "softmax"))
    # load weights
    model.load_weights("weights.traint_40zoom_modelcomplex_avec_crop.hdf5")
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
     
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 50, 50, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 50, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 25, 25, 32)        128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 25, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 12, 12, 64)        256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 86)        49622
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 12, 12, 86)        66650
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 86)          0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 6, 6, 86)          344
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 6, 6, 86)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              3171328
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 3,879,722
# Trainable params: 3,879,358
# Non-trainable params: 364
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.8881048387096774
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.84      0.96      0.90       497
#       IDC(+)       0.95      0.82      0.88       495
#
#    micro avg       0.89      0.89      0.89       992
#    macro avg       0.90      0.89      0.89       992
# weighted avg       0.90      0.89      0.89       992
