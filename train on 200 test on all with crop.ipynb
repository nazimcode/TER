# %%
import numpy as np
import matplotlib.pylab as plt
#from scipy.misc import imresize, imread
import itertools
import sklearn
from sklearn import model_selection
from sklearn.model_selection import train_test_split, KFold, cross_val_score, StratifiedKFold, learning_curve, GridSearchCV
from sklearn.metrics import confusion_matrix, make_scorer, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
import keras
from keras import backend as K
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential, model_from_json
from keras.optimizers import SGD, RMSprop, Adam, Adagrad, Adadelta
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPool2D, MaxPooling2D
# %matplotlib inline
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_200m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_200m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]
# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    en va plot un learning curve grace au code de ce lien http://scikit-learn.org/stable/modules/learning_curve.html
    """
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("exemples de test")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="score d'entrainement")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="score du cross validation")
    plt.legend(loc="best")
    return plt

def plotLotsOfLearningCurves(a,b):
    """ en va plot bcp de learning curve http://scikit-learn.org/stable/modules/learning_curve.html"""
    models = []
    models.append(('Support Vector Machine', SVC()))
    for name, model in models:
        plot_learning_curve(model, 'Learning Curve For %s Classifier'% (name), a,b, (0.5,1), 10)
#plotLotsOfLearningCurves(X_trainFlat, Y_train)
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='matrice d econfusion',
                          cmap=plt.cm.Blues):
    """
    en affiche la matrice de confusion
    en peut normalizer les donnees en metant normalize a true
    """
    plt.figure(figsize = (5,5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

#Run SVC w/ Confusion Matrix
def runSVCconfusion(a,b,c,d):
    """methodes qui affiches les matrices de confusiondu model svc (comme exmeple) en normalizer et non normalizer"""
    model = SVC()
    model.fit(a, b)
    prediction = model.predict(c)
    kfold = model_selection.KFold(n_splits=10)
    accuracy = model_selection.cross_val_score(model, c,d, cv=kfold, scoring='accuracy')
    mean = accuracy.mean() 
    stdev = accuracy.std()
    print('\nSupport Vector Machine - Training set accuracy: %s (%s)' % (mean, stdev),"\n")
    cnf_matrix = confusion_matrix(d, prediction)
    np.set_printoptions(precision=2)
    class_names = ["diagnostic" "IDC(-)", "diagnostic" "IDC(+)"]
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names,
                          title='Confusion matrix, sans la normalization')
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                          title=' confusion matrix avec normalization')
    plt.show()
#runSVCconfusion(X_trainFlat, Y_train, X_testFlat, Y_test)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
# Out:
# Using TensorFlow backend.

# %%
#simple model
def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')

def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 100 
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    model.add(Conv2D(32, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=input_shape))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
     # checkpoint
    filepath="weights.traint_200zoom_modelsimple_avec_crop.hdf5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]
    history =model.fit(x_train, y_train,
              batch_size=batch_size,
              verbose=1,
              epochs=epochs,
              validation_data=(x_test, y_test),callbacks=callbacks_list)
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# Train on 996 samples, validate on 250 samples
# Epoch 1/100
# 996/996 [==============================] - 18s 18ms/step - loss: 1.3903 - acc: 0.5412 - val_loss: 0.6690 - val_acc: 0.7320
#
# Epoch 00001: val_acc improved from -inf to 0.73200, saving model to weights.traint_200zoom_modelsimple_avec_crop.hdf5
# Epoch 2/100
# 996/996 [==============================] - 1s 1ms/step - loss: 0.6418 - acc: 0.6556 - val_loss: 0.7181 - val_acc: 0.5120
#
# Epoch 00002: val_acc did not improve from 0.73200
# Epoch 3/100
# 996/996 [==============================] - 1s 568us/step - loss: 0.6615 - acc: 0.6335 - val_loss: 0.5978 - val_acc: 0.6560
#
# Epoch 00003: val_acc did not improve from 0.73200
# Epoch 4/100
# 996/996 [==============================] - 1s 561us/step - loss: 0.7594 - acc: 0.7189 - val_loss: 0.5699 - val_acc: 0.7480
#
# Epoch 00004: val_acc improved from 0.73200 to 0.74800, saving model to weights.traint_200zoom_modelsimple_avec_crop.hdf5
# Epoch 5/100
# 996/996 [==============================] - 1s 1ms/step - loss: 0.6066 - acc: 0.7058 - val_loss: 0.6336 - val_acc: 0.5800
#
# Epoch 00005: val_acc did not improve from 0.74800
# Epoch 6/100
# 996/996 [==============================] - 1s 658us/step - loss: 0.6145 - acc: 0.6657 - val_loss: 0.5331 - val_acc: 0.7400
#
# Epoch 00006: val_acc did not improve from 0.74800
# Epoch 7/100
# 996/996 [==============================] - 1s 563us/step - loss: 0.5528 - acc: 0.7420 - val_loss: 0.4245 - val_acc: 0.8760
#
# Epoch 00007: val_acc improved from 0.74800 to 0.87600, saving model to weights.traint_200zoom_modelsimple_avec_crop.hdf5
# Epoch 8/100
# 996/996 [==============================] - 1s 575us/step - loss: 0.6115 - acc: 0.7359 - val_loss: 0.7161 - val_acc: 0.5120
#
# Epoch 00008: val_acc did not improve from 0.87600
# Epoch 9/100
# 996/996 [==============================] - 1s 604us/step - loss: 0.5969 - acc: 0.7088 - val_loss: 0.5779 - val_acc: 0.7640
#
# Epoch 00009: val_acc did not improve from 0.87600
# Epoch 10/100
# 996/996 [==============================] - 1s 573us/step - loss: 0.5394 - acc: 0.7400 - val_loss: 0.6325 - val_acc: 0.5600
#
# Epoch 00010: val_acc did not improve from 0.87600
# Epoch 11/100
# 996/996 [==============================] - 1s 568us/step - loss: 0.5414 - acc: 0.7410 - val_loss: 0.6535 - val_acc: 0.5320
#
# Epoch 00011: val_acc did not improve from 0.87600
# Epoch 12/100
# 996/996 [==============================] - 1s 584us/step - loss: 0.5779 - acc: 0.7108 - val_loss: 0.4327 - val_acc: 0.8680
#
# Epoch 00012: val_acc did not improve from 0.87600
# Epoch 13/100
# 996/996 [==============================] - 1s 566us/step - loss: 0.5630 - acc: 0.7189 - val_loss: 0.5177 - val_acc: 0.7240
#
# Epoch 00013: val_acc did not improve from 0.87600
# Epoch 14/100
# 996/996 [==============================] - 1s 554us/step - loss: 0.5468 - acc: 0.7229 - val_loss: 0.4387 - val_acc: 0.8680
#
# Epoch 00014: val_acc did not improve from 0.87600
# Epoch 15/100
# 996/996 [==============================] - 1s 571us/step - loss: 0.5462 - acc: 0.7540 - val_loss: 0.4283 - val_acc: 0.8120
#
# Epoch 00015: val_acc did not improve from 0.87600
# Epoch 16/100
# 996/996 [==============================] - 1s 569us/step - loss: 0.5468 - acc: 0.7440 - val_loss: 0.5248 - val_acc: 0.7600
#
# Epoch 00016: val_acc did not improve from 0.87600
# Epoch 17/100
# 996/996 [==============================] - 1s 582us/step - loss: 0.5461 - acc: 0.7289 - val_loss: 0.4129 - val_acc: 0.8760
#
# Epoch 00017: val_acc improved from 0.87600 to 0.87600, saving model to weights.traint_200zoom_modelsimple_avec_crop.hdf5
# Epoch 18/100
# 996/996 [==============================] - 1s 585us/step - loss: 0.5055 - acc: 0.7550 - val_loss: 0.5088 - val_acc: 0.7600
#
# Epoch 00018: val_acc did not improve from 0.87600
# Epoch 19/100
# 996/996 [==============================] - 1s 575us/step - loss: 0.5555 - acc: 0.7279 - val_loss: 0.4325 - val_acc: 0.7760
#
# Epoch 00019: val_acc did not improve from 0.87600
# Epoch 20/100
# 996/996 [==============================] - 1s 559us/step - loss: 0.5147 - acc: 0.7390 - val_loss: 0.7919 - val_acc: 0.6240
#
# Epoch 00020: val_acc did not improve from 0.87600
# Epoch 21/100
# 996/996 [==============================] - 1s 560us/step - loss: 0.5743 - acc: 0.7008 - val_loss: 0.4133 - val_acc: 0.7960
#
# Epoch 00021: val_acc did not improve from 0.87600
# Epoch 22/100
# 996/996 [==============================] - 1s 561us/step - loss: 0.5217 - acc: 0.7329 - val_loss: 0.4538 - val_acc: 0.8560
#
# Epoch 00022: val_acc did not improve from 0.87600
# Epoch 23/100
# 996/996 [==============================] - 1s 572us/step - loss: 0.4458 - acc: 0.8022 - val_loss: 0.8351 - val_acc: 0.6360
#
# Epoch 00023: val_acc did not improve from 0.87600
# Epoch 24/100
# 996/996 [==============================] - 1s 587us/step - loss: 0.5588 - acc: 0.7299 - val_loss: 0.3879 - val_acc: 0.8760
#
# Epoch 00024: val_acc did not improve from 0.87600
# Epoch 25/100
# 996/996 [==============================] - 1s 562us/step - loss: 0.4495 - acc: 0.7992 - val_loss: 0.5629 - val_acc: 0.6800
#
# Epoch 00025: val_acc did not improve from 0.87600
# Epoch 26/100
# 996/996 [==============================] - 1s 572us/step - loss: 0.4834 - acc: 0.7610 - val_loss: 0.6639 - val_acc: 0.5640
#
# Epoch 00026: val_acc did not improve from 0.87600
# Epoch 27/100
# 996/996 [==============================] - 1s 564us/step - loss: 0.6287 - acc: 0.6205 - val_loss: 0.4934 - val_acc: 0.7160
#
# Epoch 00027: val_acc did not improve from 0.87600
# Epoch 28/100
# 996/996 [==============================] - 1s 556us/step - loss: 0.4337 - acc: 0.8092 - val_loss: 0.3793 - val_acc: 0.8400
#
# Epoch 00028: val_acc did not improve from 0.87600
# Epoch 29/100
# 996/996 [==============================] - 1s 552us/step - loss: 0.4556 - acc: 0.7731 - val_loss: 0.5015 - val_acc: 0.7440
#
# Epoch 00029: val_acc did not improve from 0.87600
# Epoch 30/100
# 996/996 [==============================] - 1s 553us/step - loss: 0.4903 - acc: 0.7400 - val_loss: 0.3853 - val_acc: 0.8680
#
# Epoch 00030: val_acc did not improve from 0.87600
# Epoch 31/100
# 996/996 [==============================] - 1s 558us/step - loss: 0.3990 - acc: 0.8293 - val_loss: 0.9225 - val_acc: 0.5120
#
# Epoch 00031: val_acc did not improve from 0.87600
# Epoch 32/100
# 996/996 [==============================] - 1s 563us/step - loss: 0.5579 - acc: 0.7430 - val_loss: 0.5036 - val_acc: 0.7640
#
# Epoch 00032: val_acc did not improve from 0.87600
# Epoch 33/100
# 996/996 [==============================] - 1s 573us/step - loss: 0.4771 - acc: 0.7681 - val_loss: 0.4241 - val_acc: 0.8280
#
# Epoch 00033: val_acc did not improve from 0.87600
# Epoch 34/100
# 996/996 [==============================] - 1s 559us/step - loss: 0.4476 - acc: 0.8092 - val_loss: 0.5267 - val_acc: 0.7240
#
# Epoch 00034: val_acc did not improve from 0.87600
# Epoch 35/100
# 996/996 [==============================] - 1s 542us/step - loss: 0.5260 - acc: 0.7209 - val_loss: 0.4156 - val_acc: 0.8640
#
# Epoch 00035: val_acc did not improve from 0.87600
# Epoch 36/100
# 996/996 [==============================] - 1s 552us/step - loss: 0.4187 - acc: 0.8203 - val_loss: 0.3738 - val_acc: 0.8600
#
# Epoch 00036: val_acc did not improve from 0.87600
# Epoch 37/100
#
# Epoch 00098: val_acc did not improve from 0.88800
# Epoch 99/100
# 996/996 [==============================] - 1s 574us/step - loss: 0.1208 - acc: 0.9849 - val_loss: 0.3590 - val_acc: 0.8640
#
# Epoch 00099: val_acc did not improve from 0.88800
# Epoch 100/100
# 996/996 [==============================] - 1s 562us/step - loss: 0.0650 - acc: 0.9930 - val_loss: 0.3779 - val_acc: 0.8800
#
# Epoch 00100: val_acc did not improve from 0.88800
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 48, 48, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 46, 46, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 23, 23, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 33856)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               4333696
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 4,353,346
# Trainable params: 4,353,346
# Non-trainable params: 0
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.8800000009536744
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.96      0.79      0.86       122
#       IDC(+)       0.83      0.97      0.89       128
#
#    micro avg       0.88      0.88      0.88       250
#    macro avg       0.89      0.88      0.88       250
# weighted avg       0.89      0.88      0.88       250
#
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_200m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_200m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
#simple model
def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')

def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 100 
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu', input_shape = input_shape))
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1024, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(512, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation = "softmax"))
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
     # checkpoint
    filepath="weights.traint_200zoom_modelcomplex_avec_crop.hdf5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]
    history =model.fit(x_train, y_train,
              batch_size=batch_size,
              verbose=1,
              epochs=epochs,
              validation_data=(x_test, y_test),callbacks=callbacks_list)
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# Train on 996 samples, validate on 250 samples
# Epoch 1/100
# 996/996 [==============================] - 3s 3ms/step - loss: 2.0977 - acc: 0.6647 - val_loss: 4.3081 - val_acc: 0.5080
#
# Epoch 00001: val_acc improved from -inf to 0.50800, saving model to weights.traint_200zoom_modelcomplex_avec_crop.hdf5
# Epoch 2/100
# 996/996 [==============================] - 1s 778us/step - loss: 0.8735 - acc: 0.7992 - val_loss: 1.8220 - val_acc: 0.4120
#
# Epoch 00002: val_acc did not improve from 0.50800
# Epoch 3/100
# 996/996 [==============================] - 1s 783us/step - loss: 0.4932 - acc: 0.8082 - val_loss: 3.4882 - val_acc: 0.4400
#
# Epoch 00003: val_acc did not improve from 0.50800
# Epoch 4/100
# 996/996 [==============================] - 1s 808us/step - loss: 0.3555 - acc: 0.8604 - val_loss: 2.2753 - val_acc: 0.3680
#
# Epoch 00004: val_acc did not improve from 0.50800
# Epoch 5/100
# 996/996 [==============================] - 1s 778us/step - loss: 0.3306 - acc: 0.8564 - val_loss: 1.1493 - val_acc: 0.5280
#
# Epoch 00005: val_acc improved from 0.50800 to 0.52800, saving model to weights.traint_200zoom_modelcomplex_avec_crop.hdf5
# Epoch 6/100
# 996/996 [==============================] - 1s 784us/step - loss: 0.2491 - acc: 0.8956 - val_loss: 1.7655 - val_acc: 0.6120
#
# Epoch 00006: val_acc improved from 0.52800 to 0.61200, saving model to weights.traint_200zoom_modelcomplex_avec_crop.hdf5
# Epoch 7/100
# 996/996 [==============================] - 1s 786us/step - loss: 0.3098 - acc: 0.8785 - val_loss: 1.3935 - val_acc: 0.6240
#
# Epoch 00007: val_acc improved from 0.61200 to 0.62400, saving model to weights.traint_200zoom_modelcomplex_avec_crop.hdf5
# Epoch 8/100
# 996/996 [==============================] - 1s 806us/step - loss: 0.2717 - acc: 0.8896 - val_loss: 0.9206 - val_acc: 0.6840
#
# Epoch 00008: val_acc improved from 0.62400 to 0.68400, saving model to weights.traint_200zoom_modelcomplex_avec_crop.hdf5
# Epoch 9/100
# 996/996 [==============================] - 1s 790us/step - loss: 0.2398 - acc: 0.9046 - val_loss: 3.3731 - val_acc: 0.5160
#
# Epoch 00009: val_acc did not improve from 0.68400
# Epoch 10/100
# 996/996 [==============================] - 1s 787us/step - loss: 0.2492 - acc: 0.8946 - val_loss: 1.4752 - val_acc: 0.5440
#
# Epoch 00010: val_acc did not improve from 0.68400
# Epoch 11/100
# 996/996 [==============================] - 1s 786us/step - loss: 0.1733 - acc: 0.9227 - val_loss: 0.8418 - val_acc: 0.7680
#
# Epoch 00011: val_acc improved from 0.68400 to 0.76800, saving model to weights.traint_200zoom_modelcomplex_avec_crop.hdf5
# Epoch 12/100
# 996/996 [==============================] - 1s 787us/step - loss: 0.1802 - acc: 0.9177 - val_loss: 0.9487 - val_acc: 0.7720
#
# Epoch 00012: val_acc improved from 0.76800 to 0.77200, saving model to weights.traint_200zoom_modelcomplex_avec_crop.hdf5
# Epoch 13/100
# 996/996 [==============================] - 1s 811us/step - loss: 0.2163 - acc: 0.9127 - val_loss: 3.9240 - val_acc: 0.6480
#
# Epoch 00013: val_acc did not improve from 0.77200
# Epoch 14/100
# 996/996 [==============================] - 1s 808us/step - loss: 0.2216 - acc: 0.9036 - val_loss: 2.5454 - val_acc: 0.5680
#
# Epoch 00014: val_acc did not improve from 0.77200
# Epoch 15/100
# 996/996 [==============================] - 1s 787us/step - loss: 0.1757 - acc: 0.9287 - val_loss: 1.9587 - val_acc: 0.6640
#
# Epoch 00015: val_acc did not improve from 0.77200
# Epoch 16/100
# 996/996 [==============================] - 1s 805us/step - loss: 0.1327 - acc: 0.9498 - val_loss: 1.1121 - val_acc: 0.6840
#
# Epoch 00016: val_acc did not improve from 0.77200
# Epoch 17/100
# 996/996 [==============================] - 1s 785us/step - loss: 0.1919 - acc: 0.9277 - val_loss: 1.6431 - val_acc: 0.6520
#
# Epoch 00017: val_acc did not improve from 0.77200
# Epoch 18/100
# 996/996 [==============================] - 1s 786us/step - loss: 0.1221 - acc: 0.9498 - val_loss: 1.6445 - val_acc: 0.7040
#
# Epoch 00018: val_acc did not improve from 0.77200
# Epoch 19/100
# 996/996 [==============================] - 1s 792us/step - loss: 0.1456 - acc: 0.9478 - val_loss: 0.9118 - val_acc: 0.7960
#
# Epoch 00019: val_acc improved from 0.77200 to 0.79600, saving model to weights.traint_200zoom_modelcomplex_avec_crop.hdf5
# Epoch 20/100
# 996/996 [==============================] - 1s 802us/step - loss: 0.1557 - acc: 0.9367 - val_loss: 0.4923 - val_acc: 0.7480
#
# Epoch 00020: val_acc did not improve from 0.79600
# Epoch 21/100
# 996/996 [==============================] - 1s 819us/step - loss: 0.1532 - acc: 0.9408 - val_loss: 6.1899 - val_acc: 0.5720
#
# Epoch 00021: val_acc did not improve from 0.79600
# Epoch 22/100
# 996/996 [==============================] - 1s 788us/step - loss: 0.1364 - acc: 0.9498 - val_loss: 6.2333 - val_acc: 0.5560
#
# Epoch 00022: val_acc did not improve from 0.79600
# Epoch 23/100
# 996/996 [==============================] - 1s 819us/step - loss: 0.0907 - acc: 0.9669 - val_loss: 7.2478 - val_acc: 0.5080
#
# Epoch 00023: val_acc did not improve from 0.79600
# Epoch 24/100
# 996/996 [==============================] - 1s 834us/step - loss: 0.1015 - acc: 0.9629 - val_loss: 5.5642 - val_acc: 0.5760
#
# Epoch 00024: val_acc did not improve from 0.79600
# Epoch 25/100
# 996/996 [==============================] - 1s 805us/step - loss: 0.0822 - acc: 0.9639 - val_loss: 5.4025 - val_acc: 0.5960
#
# Epoch 00025: val_acc did not improve from 0.79600
# Epoch 26/100
# 996/996 [==============================] - 1s 834us/step - loss: 0.0741 - acc: 0.9689 - val_loss: 4.6492 - val_acc: 0.6560
#
# Epoch 00026: val_acc did not improve from 0.79600
# Epoch 27/100
# 996/996 [==============================] - 1s 832us/step - loss: 0.0630 - acc: 0.9759 - val_loss: 4.1523 - val_acc: 0.6240
#
# Epoch 00027: val_acc did not improve from 0.79600
# Epoch 28/100
# 996/996 [==============================] - 1s 795us/step - loss: 0.1582 - acc: 0.9468 - val_loss: 1.7967 - val_acc: 0.6960
#
# Epoch 00028: val_acc did not improve from 0.79600
# Epoch 29/100
# 996/996 [==============================] - 1s 784us/step - loss: 0.0792 - acc: 0.9709 - val_loss: 1.4659 - val_acc: 0.7720
#
# Epoch 00029: val_acc did not improve from 0.79600
# Epoch 30/100
# 996/996 [==============================] - 1s 778us/step - loss: 0.0678 - acc: 0.9739 - val_loss: 3.7951 - val_acc: 0.6720
#
# Epoch 00030: val_acc did not improve from 0.79600
# Epoch 31/100
# 996/996 [==============================] - 1s 782us/step - loss: 0.0608 - acc: 0.9769 - val_loss: 0.3457 - val_acc: 0.9320
#
# Epoch 00031: val_acc improved from 0.79600 to 0.93200, saving model to weights.traint_200zoom_modelcomplex_avec_crop.hdf5
# Epoch 32/100
# 996/996 [==============================] - 1s 776us/step - loss: 0.0469 - acc: 0.9829 - val_loss: 6.3764 - val_acc: 0.5600
#
# Epoch 00032: val_acc did not improve from 0.93200
# Epoch 33/100
# 996/996 [==============================] - 1s 778us/step - loss: 0.1726 - acc: 0.9488 - val_loss: 3.5210 - val_acc: 0.6680
#
# Epoch 00033: val_acc did not improve from 0.93200
# Epoch 34/100
# 996/996 [==============================] - 1s 802us/step - loss: 0.0917 - acc: 0.9588 - val_loss: 7.4770 - val_acc: 0.5200
#
# Epoch 00034: val_acc did not improve from 0.93200
# Epoch 35/100
# 996/996 [==============================] - 1s 797us/step - loss: 0.0505 - acc: 0.9849 - val_loss: 0.9181 - val_acc: 0.9160
#
# Epoch 00035: val_acc did not improve from 0.93200
# Epoch 36/100
# 996/996 [==============================] - 1s 787us/step - loss: 0.0340 - acc: 0.9849 - val_loss: 1.3010 - val_acc: 0.8600
#
# Epoch 00036: val_acc did not improve from 0.93200
# Epoch 37/100
# 996/996 [==============================] - 1s 797us/step - loss: 0.0368 - acc: 0.9869 - val_loss: 1.9684 - val_acc: 0.7560
#
# Epoch 00037: val_acc did not improve from 0.93200
# Epoch 38/100
# 996/996 [==============================] - 1s 848us/step - loss: 0.0581 - acc: 0.9769 - val_loss: 2.1716 - val_acc: 0.8240
#
# Epoch 00038: val_acc did not improve from 0.93200
# Epoch 39/100
# 996/996 [==============================] - 1s 860us/step - loss: 0.0779 - acc: 0.9729 - val_loss: 0.1751 - val_acc: 0.9720
#
# Epoch 00039: val_acc improved from 0.93200 to 0.97200, saving model to weights.traint_200zoom_modelcomplex_avec_crop.hdf5
# Epoch 40/100
# 996/996 [==============================] - 1s 820us/step - loss: 0.0111 - acc: 0.9970 - val_loss: 0.2267 - val_acc: 0.9520
#
# Epoch 00040: val_acc did not improve from 0.97200
# Epoch 41/100
# 996/996 [==============================] - 1s 792us/step - loss: 0.0155 - acc: 0.9940 - val_loss: 0.1932 - val_acc: 0.9640
#
# Epoch 00041: val_acc did not improve from 0.97200
# Epoch 42/100
# 996/996 [==============================] - 1s 802us/step - loss: 0.0218 - acc: 0.9920 - val_loss: 0.9093 - val_acc: 0.8320
#
# Epoch 00042: val_acc did not improve from 0.97200
# Epoch 43/100
# 996/996 [==============================] - 1s 777us/step - loss: 0.0159 - acc: 0.9930 - val_loss: 3.0455 - val_acc: 0.6960
#
# Epoch 00043: val_acc did not improve from 0.97200
# Epoch 44/100
# 996/996 [==============================] - 1s 790us/step - loss: 0.0454 - acc: 0.9849 - val_loss: 4.5166 - val_acc: 0.6120
#
# Epoch 00044: val_acc did not improve from 0.97200
# Epoch 45/100
# 996/996 [==============================] - 1s 791us/step - loss: 0.0572 - acc: 0.9799 - val_loss: 1.8494 - val_acc: 0.8080
#
# Epoch 00045: val_acc did not improve from 0.97200
# Epoch 46/100
# 996/996 [==============================] - 1s 774us/step - loss: 0.0138 - acc: 0.9940 - val_loss: 1.1842 - val_acc: 0.8440
#
# Epoch 00046: val_acc did not improve from 0.97200
# Epoch 47/100
# 996/996 [==============================] - 1s 780us/step - loss: 0.0157 - acc: 0.9950 - val_loss: 1.6237 - val_acc: 0.8280
#
# Epoch 00047: val_acc did not improve from 0.97200
# Epoch 48/100
# 996/996 [==============================] - 1s 787us/step - loss: 0.1869 - acc: 0.9629 - val_loss: 1.8990 - val_acc: 0.8320
#
# Epoch 00048: val_acc did not improve from 0.97200
# Epoch 49/100
# 996/996 [==============================] - 1s 814us/step - loss: 0.0305 - acc: 0.9890 - val_loss: 5.9580 - val_acc: 0.5840
#
# Epoch 00049: val_acc did not improve from 0.97200
# Epoch 50/100
# 996/996 [==============================] - 1s 796us/step - loss: 0.0298 - acc: 0.9910 - val_loss: 5.5812 - val_acc: 0.6320
#
# Epoch 00050: val_acc did not improve from 0.97200
# Epoch 51/100
# 996/996 [==============================] - 1s 783us/step - loss: 0.0439 - acc: 0.9869 - val_loss: 2.0913 - val_acc: 0.7280
#
# Epoch 00051: val_acc did not improve from 0.97200
# Epoch 52/100
# 996/996 [==============================] - 1s 799us/step - loss: 0.0080 - acc: 0.9980 - val_loss: 1.2540 - val_acc: 0.8840
#
# Epoch 00052: val_acc did not improve from 0.97200
# Epoch 53/100
# 996/996 [==============================] - 1s 787us/step - loss: 0.0774 - acc: 0.9769 - val_loss: 1.1178 - val_acc: 0.9040
#
# Epoch 00053: val_acc did not improve from 0.97200
# Epoch 54/100
# 996/996 [==============================] - 1s 800us/step - loss: 0.0387 - acc: 0.9859 - val_loss: 0.7474 - val_acc: 0.8400
#
# Epoch 00054: val_acc did not improve from 0.97200
# Epoch 55/100
# 996/996 [==============================] - 1s 784us/step - loss: 0.0195 - acc: 0.9940 - val_loss: 4.7936 - val_acc: 0.6200
#
# Epoch 00055: val_acc did not improve from 0.97200
# Epoch 56/100
# 996/996 [==============================] - 1s 777us/step - loss: 0.0384 - acc: 0.9829 - val_loss: 2.6686 - val_acc: 0.6760
#
# Epoch 00056: val_acc did not improve from 0.97200
# Epoch 57/100
# 996/996 [==============================] - 1s 779us/step - loss: 0.0142 - acc: 0.9970 - val_loss: 2.7081 - val_acc: 0.7040
#
# Epoch 00057: val_acc did not improve from 0.97200
# Epoch 58/100
# 996/996 [==============================] - 1s 804us/step - loss: 0.0323 - acc: 0.9910 - val_loss: 1.7827 - val_acc: 0.7960
#
# Epoch 00058: val_acc did not improve from 0.97200
# Epoch 59/100
# 996/996 [==============================] - 1s 789us/step - loss: 0.0312 - acc: 0.9890 - val_loss: 0.4645 - val_acc: 0.8760
#
# Epoch 00059: val_acc did not improve from 0.97200
# Epoch 60/100
# 996/996 [==============================] - 1s 798us/step - loss: 0.0103 - acc: 0.9970 - val_loss: 0.6588 - val_acc: 0.8920
#
# Epoch 00060: val_acc did not improve from 0.97200
# Epoch 61/100
# 996/996 [==============================] - 1s 789us/step - loss: 0.0076 - acc: 0.9970 - val_loss: 0.4590 - val_acc: 0.9120
#
# Epoch 00061: val_acc did not improve from 0.97200
# Epoch 62/100
# 996/996 [==============================] - 1s 788us/step - loss: 0.0086 - acc: 0.9950 - val_loss: 4.9261 - val_acc: 0.6360
#
# Epoch 00062: val_acc did not improve from 0.97200
# Epoch 63/100
# 996/996 [==============================] - 1s 785us/step - loss: 0.0027 - acc: 1.0000 - val_loss: 3.9447 - val_acc: 0.6600
#
# Epoch 00063: val_acc did not improve from 0.97200
# Epoch 64/100
# 996/996 [==============================] - 1s 793us/step - loss: 0.0232 - acc: 0.9960 - val_loss: 1.0458 - val_acc: 0.8640
#
# Epoch 00064: val_acc did not improve from 0.97200
# Epoch 65/100
# 996/996 [==============================] - 1s 786us/step - loss: 0.0032 - acc: 0.9990 - val_loss: 3.0744 - val_acc: 0.7000
#
# Epoch 00065: val_acc did not improve from 0.97200
# Epoch 66/100
# 996/996 [==============================] - 1s 791us/step - loss: 0.0055 - acc: 0.9990 - val_loss: 1.5557 - val_acc: 0.8600
#
# Epoch 00066: val_acc did not improve from 0.97200
# Epoch 67/100
# 996/996 [==============================] - 1s 791us/step - loss: 0.0060 - acc: 0.9980 - val_loss: 2.0059 - val_acc: 0.7200
#
# Epoch 00067: val_acc did not improve from 0.97200
# Epoch 68/100
# 996/996 [==============================] - 1s 786us/step - loss: 0.0375 - acc: 0.9900 - val_loss: 1.0377 - val_acc: 0.7600
#
# Epoch 00068: val_acc did not improve from 0.97200
# Epoch 69/100
# 996/996 [==============================] - 1s 789us/step - loss: 0.0325 - acc: 0.9910 - val_loss: 3.9632 - val_acc: 0.6680
#
# Epoch 00069: val_acc did not improve from 0.97200
# Epoch 70/100
# 996/996 [==============================] - 1s 780us/step - loss: 0.0083 - acc: 0.9980 - val_loss: 2.3043 - val_acc: 0.7360
#
# Epoch 00070: val_acc did not improve from 0.97200
# Epoch 71/100
#
# Epoch 00086: val_acc did not improve from 0.97200
# Epoch 87/100
# 996/996 [==============================] - 1s 787us/step - loss: 0.0087 - acc: 0.9970 - val_loss: 4.4082 - val_acc: 0.4200
#
# Epoch 00087: val_acc did not improve from 0.97200
# Epoch 88/100
# 996/996 [==============================] - 1s 785us/step - loss: 0.0030 - acc: 0.9990 - val_loss: 2.6457 - val_acc: 0.5560
#
# Epoch 00088: val_acc did not improve from 0.97200
# Epoch 89/100
# 996/996 [==============================] - 1s 804us/step - loss: 0.0011 - acc: 1.0000 - val_loss: 1.2217 - val_acc: 0.7160
#
# Epoch 00089: val_acc did not improve from 0.97200
# Epoch 90/100
# 996/996 [==============================] - 1s 802us/step - loss: 0.0051 - acc: 0.9980 - val_loss: 3.6504 - val_acc: 0.5320
#
# Epoch 00090: val_acc did not improve from 0.97200
# Epoch 91/100
# 996/996 [==============================] - 1s 802us/step - loss: 0.0138 - acc: 0.9960 - val_loss: 2.1579 - val_acc: 0.7040
#
# Epoch 00091: val_acc did not improve from 0.97200
# Epoch 92/100
# 996/996 [==============================] - 1s 794us/step - loss: 0.0016 - acc: 1.0000 - val_loss: 2.7207 - val_acc: 0.7040
#
# Epoch 00092: val_acc did not improve from 0.97200
# Epoch 93/100
# 996/996 [==============================] - 1s 798us/step - loss: 0.0073 - acc: 0.9970 - val_loss: 0.9109 - val_acc: 0.8400
#
# Epoch 00093: val_acc did not improve from 0.97200
# Epoch 94/100
# 996/996 [==============================] - 1s 798us/step - loss: 7.7464e-04 - acc: 1.0000 - val_loss: 1.0998 - val_acc: 0.8240
#
# Epoch 00094: val_acc did not improve from 0.97200
# Epoch 95/100
# 996/996 [==============================] - 1s 784us/step - loss: 0.0026 - acc: 0.9980 - val_loss: 0.8621 - val_acc: 0.8960
#
# Epoch 00095: val_acc did not improve from 0.97200
# Epoch 96/100
# 996/996 [==============================] - 1s 778us/step - loss: 0.0045 - acc: 0.9980 - val_loss: 1.1429 - val_acc: 0.8600
#
# Epoch 00096: val_acc did not improve from 0.97200
# Epoch 97/100
# 996/996 [==============================] - 1s 775us/step - loss: 0.0240 - acc: 0.9950 - val_loss: 0.4950 - val_acc: 0.9160
#
# Epoch 00097: val_acc did not improve from 0.97200
# Epoch 98/100
# 996/996 [==============================] - 1s 779us/step - loss: 0.0011 - acc: 1.0000 - val_loss: 0.1284 - val_acc: 0.9600
#
# Epoch 00098: val_acc did not improve from 0.97200
# Epoch 99/100
# 996/996 [==============================] - 1s 785us/step - loss: 0.0015 - acc: 1.0000 - val_loss: 0.5448 - val_acc: 0.9400
#
# Epoch 00099: val_acc did not improve from 0.97200
# Epoch 100/100
# 996/996 [==============================] - 1s 793us/step - loss: 0.0145 - acc: 0.9980 - val_loss: 0.6461 - val_acc: 0.9160
#
# Epoch 00100: val_acc did not improve from 0.97200
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 50, 50, 32)        896
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 50, 50, 32)        9248
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 25, 25, 32)        128
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 25, 25, 64)        18496
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 12, 12, 64)        256
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 12, 12, 86)        49622
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 12, 12, 86)        66650
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 86)          0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 6, 6, 86)          344
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 6, 6, 86)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 3096)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              3171328
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 3,879,722
# Trainable params: 3,879,358
# Non-trainable params: 364
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.9159999976158142
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.97      0.86      0.91       128
#       IDC(+)       0.87      0.98      0.92       122
#
#    micro avg       0.92      0.92      0.92       250
#    macro avg       0.92      0.92      0.92       250
# weighted avg       0.92      0.92      0.92       250
#
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_40m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_40m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
class MetricsCheckpoint(Callback):
    """apres chaque epoch en sauvegarde metrics"""
    def __init__(self, savepath):
        #constructeur de la class
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')
def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 5
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    #test d'un premier model
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu', input_shape = input_shape))
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1024, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(512, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation = "softmax"))
    # load weights
    model.load_weights("weights.traint_200zoom_modelcomplex_avec_crop.hdf5")
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
     
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 50, 50, 32)        896
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 50, 50, 32)        9248
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 25, 25, 32)        0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 25, 25, 32)        128
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 25, 25, 64)        18496
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 12, 12, 64)        256
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 12, 12, 86)        49622
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 12, 12, 86)        66650
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 6, 6, 86)          0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 6, 6, 86)          344
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 6, 6, 86)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 3096)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1024)              3171328
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 3,879,722
# Trainable params: 3,879,358
# Non-trainable params: 364
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.8039999985694886
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.74      0.92      0.82       120
#       IDC(+)       0.90      0.70      0.79       130
#
#    micro avg       0.80      0.80      0.80       250
#    macro avg       0.82      0.81      0.80       250
# weighted avg       0.82      0.80      0.80       250

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_100m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_100m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
class MetricsCheckpoint(Callback):
    """apres chaque epoch en sauvegarde metrics"""
    def __init__(self, savepath):
        #constructeur de la class
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')
def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 5
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    #test d'un premier model
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu', input_shape = input_shape))
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1024, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(512, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation = "softmax"))
    # load weights
    model.load_weights("weights.traint_200zoom_modelcomplex_avec_crop.hdf5")
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
     
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_27 (Conv2D)           (None, 50, 50, 32)        896
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 50, 50, 32)        9248
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 25, 25, 32)        0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 25, 25, 32)        128
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 25, 25, 64)        18496
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 12, 12, 64)        256
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 12, 12, 86)        49622
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 12, 12, 86)        66650
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 6, 6, 86)          0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 6, 6, 86)          344
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 6, 6, 86)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 3096)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1024)              3171328
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 3,879,722
# Trainable params: 3,879,358
# Non-trainable params: 364
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.8527131782945736
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.86      0.86      0.86       133
#       IDC(+)       0.85      0.85      0.85       125
#
#    micro avg       0.85      0.85      0.85       258
#    macro avg       0.85      0.85      0.85       258
# weighted avg       0.85      0.85      0.85       258

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_200m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_200m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
class MetricsCheckpoint(Callback):
    """apres chaque epoch en sauvegarde metrics"""
    def __init__(self, savepath):
        #constructeur de la class
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')
def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 5
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    #test d'un premier model
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu', input_shape = input_shape))
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1024, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(512, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation = "softmax"))
    # load weights
    model.load_weights("weights.traint_200zoom_modelcomplex_avec_crop.hdf5")
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
     
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_33 (Conv2D)           (None, 50, 50, 32)        896
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 50, 50, 32)        9248
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 25, 25, 32)        0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 25, 25, 32)        128
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 25, 25, 64)        18496
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 12, 12, 64)        256
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 12, 12, 86)        49622
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 12, 12, 86)        66650
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 86)          0
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 6, 6, 86)          344
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 6, 6, 86)          0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 3096)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1024)              3171328
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 3,879,722
# Trainable params: 3,879,358
# Non-trainable params: 364
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.992
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       1.00      0.99      0.99       139
#       IDC(+)       0.98      1.00      0.99       111
#
#    micro avg       0.99      0.99      0.99       250
#    macro avg       0.99      0.99      0.99       250
# weighted avg       0.99      0.99      0.99       250

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_400m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_400m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
class MetricsCheckpoint(Callback):
    """apres chaque epoch en sauvegarde metrics"""
    def __init__(self, savepath):
        #constructeur de la class
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')
def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 5
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    #test d'un premier model
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu', input_shape = input_shape))
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1024, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(512, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation = "softmax"))
    # load weights
    model.load_weights("weights.traint_200zoom_modelcomplex_avec_crop.hdf5")
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
     
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_39 (Conv2D)           (None, 50, 50, 32)        896
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 50, 50, 32)        9248
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 25, 25, 32)        0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 25, 25, 32)        128
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 25, 25, 64)        18496
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 12, 12, 64)        256
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 12, 12, 86)        49622
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 12, 12, 86)        66650
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 6, 6, 86)          0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 6, 6, 86)          344
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 6, 6, 86)          0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 3096)              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 1024)              3171328
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 3,879,722
# Trainable params: 3,879,358
# Non-trainable params: 364
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.9194915254237288
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.95      0.89      0.92       117
#       IDC(+)       0.90      0.95      0.92       119
#
#    micro avg       0.92      0.92      0.92       236
#    macro avg       0.92      0.92      0.92       236
# weighted avg       0.92      0.92      0.92       236

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoo.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
class MetricsCheckpoint(Callback):
    """apres chaque epoch en sauvegarde metrics"""
    def __init__(self, savepath):
        #constructeur de la class
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')
def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 5
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    #test d'un premier model
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu', input_shape = input_shape))
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1024, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(512, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation = "softmax"))
    # load weights
    model.load_weights("weights.traint_200zoom_modelcomplex_avec_crop.hdf5")
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
     
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_45 (Conv2D)           (None, 50, 50, 32)        896
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 50, 50, 32)        9248
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 25, 25, 32)        0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 25, 25, 32)        128
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 25, 25, 64)        18496
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 12, 12, 64)        256
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 12, 12, 86)        49622
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 12, 12, 86)        66650
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 6, 6, 86)          0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 6, 6, 86)          344
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 6, 6, 86)          0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 3096)              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 1024)              3171328
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_25 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 3,879,722
# Trainable params: 3,879,358
# Non-trainable params: 364
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.8981854838709677
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.88      0.91      0.89       469
#       IDC(+)       0.91      0.89      0.90       523
#
#    micro avg       0.90      0.90      0.90       992
#    macro avg       0.90      0.90      0.90       992
# weighted avg       0.90      0.90      0.90       992
