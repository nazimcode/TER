# %%
import numpy as np
import matplotlib.pylab as plt
#from scipy.misc import imresize, imread
import itertools
import sklearn
from sklearn import model_selection
from sklearn.model_selection import train_test_split, KFold, cross_val_score, StratifiedKFold, learning_curve, GridSearchCV
from sklearn.metrics import confusion_matrix, make_scorer, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
import keras
from keras import backend as K
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential, model_from_json
from keras.optimizers import SGD, RMSprop, Adam, Adagrad, Adadelta
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPool2D, MaxPooling2D
# %matplotlib inline
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_400m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_400m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]
# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    en va plot un learning curve grace au code de ce lien http://scikit-learn.org/stable/modules/learning_curve.html
    """
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("exemples de test")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="score d'entrainement")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="score du cross validation")
    plt.legend(loc="best")
    return plt

def plotLotsOfLearningCurves(a,b):
    """ en va plot bcp de learning curve http://scikit-learn.org/stable/modules/learning_curve.html"""
    models = []
    models.append(('Support Vector Machine', SVC()))
    for name, model in models:
        plot_learning_curve(model, 'Learning Curve For %s Classifier'% (name), a,b, (0.5,1), 10)
#plotLotsOfLearningCurves(X_trainFlat, Y_train)
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='matrice d econfusion',
                          cmap=plt.cm.Blues):
    """
    en affiche la matrice de confusion
    en peut normalizer les donnees en metant normalize a true
    """
    plt.figure(figsize = (5,5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

#Run SVC w/ Confusion Matrix
def runSVCconfusion(a,b,c,d):
    """methodes qui affiches les matrices de confusiondu model svc (comme exmeple) en normalizer et non normalizer"""
    model = SVC()
    model.fit(a, b)
    prediction = model.predict(c)
    kfold = model_selection.KFold(n_splits=10)
    accuracy = model_selection.cross_val_score(model, c,d, cv=kfold, scoring='accuracy')
    mean = accuracy.mean() 
    stdev = accuracy.std()
    print('\nSupport Vector Machine - Training set accuracy: %s (%s)' % (mean, stdev),"\n")
    cnf_matrix = confusion_matrix(d, prediction)
    np.set_printoptions(precision=2)
    class_names = ["diagnostic" "IDC(-)", "diagnostic" "IDC(+)"]
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names,
                          title='Confusion matrix, sans la normalization')
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                          title=' confusion matrix avec normalization')
    plt.show()
#runSVCconfusion(X_trainFlat, Y_train, X_testFlat, Y_test)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
# Out:
# Using TensorFlow backend.

# %%
#simple model
def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')

def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 100 
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    model.add(Conv2D(32, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=input_shape))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
     # checkpoint
    filepath="weights.traint_400zoom_modelsimple_avec_crop.hdf5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]
    history =model.fit(x_train, y_train,
              batch_size=batch_size,
              verbose=1,
              epochs=epochs,
              validation_data=(x_test, y_test),callbacks=callbacks_list)
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# Train on 940 samples, validate on 236 samples
# Epoch 1/100
# 384/940 [===========>..................] - ETA: 25s - loss: 2.3755 - acc: 0.4792
# C:\Users\Nazim\Anaconda3\envs\myenv\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (0.105043). Check your callbacks.
#   % delta_t_median)
# 940/940 [==============================] - 19s 20ms/step - loss: 1.3689 - acc: 0.5213 - val_loss: 0.6472 - val_acc: 0.5085
#
# Epoch 00001: val_acc improved from -inf to 0.50847, saving model to weights.traint_400zoom_modelsimple_avec_crop.hdf5
# Epoch 2/100
# 940/940 [==============================] - 1s 660us/step - loss: 0.6972 - acc: 0.5840 - val_loss: 0.6567 - val_acc: 0.7246
#
# Epoch 00002: val_acc improved from 0.50847 to 0.72458, saving model to weights.traint_400zoom_modelsimple_avec_crop.hdf5
# Epoch 3/100
# 940/940 [==============================] - 1s 617us/step - loss: 0.6819 - acc: 0.6117 - val_loss: 0.6423 - val_acc: 0.7246
#
# Epoch 00003: val_acc improved from 0.72458 to 0.72458, saving model to weights.traint_400zoom_modelsimple_avec_crop.hdf5
# Epoch 4/100
# 940/940 [==============================] - 1s 574us/step - loss: 0.6356 - acc: 0.6468 - val_loss: 0.6888 - val_acc: 0.5678
#
# Epoch 00004: val_acc did not improve from 0.72458
# Epoch 5/100
# 940/940 [==============================] - 1s 578us/step - loss: 0.7009 - acc: 0.6138 - val_loss: 0.6279 - val_acc: 0.6059
#
# Epoch 00005: val_acc did not improve from 0.72458
# Epoch 6/100
# 940/940 [==============================] - 1s 621us/step - loss: 0.6370 - acc: 0.6511 - val_loss: 0.5752 - val_acc: 0.7924
#
# Epoch 00006: val_acc improved from 0.72458 to 0.79237, saving model to weights.traint_400zoom_modelsimple_avec_crop.hdf5
# Epoch 7/100
# 940/940 [==============================] - 1s 627us/step - loss: 0.6607 - acc: 0.6383 - val_loss: 0.5747 - val_acc: 0.7966
#
# Epoch 00007: val_acc improved from 0.79237 to 0.79661, saving model to weights.traint_400zoom_modelsimple_avec_crop.hdf5
# Epoch 8/100
# 940/940 [==============================] - 1s 611us/step - loss: 0.6331 - acc: 0.6372 - val_loss: 0.6351 - val_acc: 0.8263
#
# Epoch 00008: val_acc improved from 0.79661 to 0.82627, saving model to weights.traint_400zoom_modelsimple_avec_crop.hdf5
# Epoch 9/100
# 940/940 [==============================] - 1s 581us/step - loss: 0.6378 - acc: 0.6798 - val_loss: 0.5891 - val_acc: 0.8305
#
# Epoch 00009: val_acc improved from 0.82627 to 0.83051, saving model to weights.traint_400zoom_modelsimple_avec_crop.hdf5
# Epoch 10/100
# 940/940 [==============================] - 1s 617us/step - loss: 0.6288 - acc: 0.6691 - val_loss: 0.5635 - val_acc: 0.7458
#
# Epoch 00010: val_acc did not improve from 0.83051
# Epoch 11/100
# 940/940 [==============================] - 1s 628us/step - loss: 0.5967 - acc: 0.6989 - val_loss: 0.5534 - val_acc: 0.7415
#
# Epoch 00011: val_acc did not improve from 0.83051
# Epoch 12/100
# 940/940 [==============================] - 1s 591us/step - loss: 0.6459 - acc: 0.6915 - val_loss: 0.6286 - val_acc: 0.5127
#
# Epoch 00012: val_acc did not improve from 0.83051
# Epoch 13/100
# 940/940 [==============================] - 1s 617us/step - loss: 0.6222 - acc: 0.6404 - val_loss: 0.5286 - val_acc: 0.7458
#
# Epoch 00013: val_acc did not improve from 0.83051
# Epoch 14/100
# 940/940 [==============================] - 1s 574us/step - loss: 0.6009 - acc: 0.6979 - val_loss: 0.5636 - val_acc: 0.7415
#
# Epoch 00014: val_acc did not improve from 0.83051
# Epoch 15/100
# 940/940 [==============================] - 1s 586us/step - loss: 0.5907 - acc: 0.6936 - val_loss: 0.5173 - val_acc: 0.8305
#
# Epoch 00015: val_acc did not improve from 0.83051
# Epoch 16/100
# 940/940 [==============================] - 1s 574us/step - loss: 0.6296 - acc: 0.6851 - val_loss: 0.6070 - val_acc: 0.6992
#
# Epoch 00016: val_acc did not improve from 0.83051
# Epoch 17/100
# 940/940 [==============================] - 1s 574us/step - loss: 0.6044 - acc: 0.6713 - val_loss: 0.5581 - val_acc: 0.8136
#
# Epoch 00017: val_acc did not improve from 0.83051
# Epoch 18/100
# 940/940 [==============================] - 1s 607us/step - loss: 0.6126 - acc: 0.6979 - val_loss: 0.5085 - val_acc: 0.8220
#
# Epoch 00018: val_acc did not improve from 0.83051
# Epoch 19/100
# 940/940 [==============================] - 1s 599us/step - loss: 0.6087 - acc: 0.6840 - val_loss: 0.4946 - val_acc: 0.8517
#
# Epoch 00019: val_acc improved from 0.83051 to 0.85169, saving model to weights.traint_400zoom_modelsimple_avec_crop.hdf5
# Epoch 20/100
# 940/940 [==============================] - 1s 600us/step - loss: 0.5781 - acc: 0.7170 - val_loss: 0.5664 - val_acc: 0.6907
#
# Epoch 00020: val_acc did not improve from 0.85169
# Epoch 21/100
# 940/940 [==============================] - 1s 581us/step - loss: 0.5626 - acc: 0.7223 - val_loss: 0.6362 - val_acc: 0.5085
#
# Epoch 00021: val_acc did not improve from 0.85169
# Epoch 22/100
# 940/940 [==============================] - 1s 579us/step - loss: 0.6029 - acc: 0.6713 - val_loss: 0.6200 - val_acc: 0.5127
#
# Epoch 00022: val_acc did not improve from 0.85169
# Epoch 23/100
# 940/940 [==============================] - 1s 574us/step - loss: 0.6046 - acc: 0.6755 - val_loss: 0.4523 - val_acc: 0.8136
#
# Epoch 00023: val_acc did not improve from 0.85169
# Epoch 24/100
# 940/940 [==============================] - 1s 574us/step - loss: 0.5531 - acc: 0.7011 - val_loss: 0.5963 - val_acc: 0.8178
#
# Epoch 00024: val_acc did not improve from 0.85169
# Epoch 25/100
# 940/940 [==============================] - 1s 575us/step - loss: 0.6141 - acc: 0.6755 - val_loss: 0.6268 - val_acc: 0.5169
#
# Epoch 00025: val_acc did not improve from 0.85169
# Epoch 26/100
# 940/940 [==============================] - 1s 588us/step - loss: 0.5733 - acc: 0.7170 - val_loss: 0.5908 - val_acc: 0.6059
#
# Epoch 00026: val_acc did not improve from 0.85169
# Epoch 27/100
# 940/940 [==============================] - 1s 582us/step - loss: 0.6081 - acc: 0.6862 - val_loss: 0.4701 - val_acc: 0.8475
#
# Epoch 00027: val_acc did not improve from 0.85169
# Epoch 28/100
# 940/940 [==============================] - 1s 564us/step - loss: 0.5405 - acc: 0.7404 - val_loss: 0.6099 - val_acc: 0.5212
#
# Epoch 00028: val_acc did not improve from 0.85169
# Epoch 29/100
# 940/940 [==============================] - 1s 585us/step - loss: 0.5672 - acc: 0.7404 - val_loss: 0.5319 - val_acc: 0.8305
#
# Epoch 00029: val_acc did not improve from 0.85169
# Epoch 30/100
# 940/940 [==============================] - 1s 589us/step - loss: 0.5536 - acc: 0.7372 - val_loss: 0.5575 - val_acc: 0.7839
#
# Epoch 00030: val_acc did not improve from 0.85169
# Epoch 31/100
# 940/940 [==============================] - 1s 570us/step - loss: 0.5329 - acc: 0.7479 - val_loss: 0.7108 - val_acc: 0.5085
#
# Epoch 00031: val_acc did not improve from 0.85169
# Epoch 32/100
# 940/940 [==============================] - 1s 585us/step - loss: 0.5755 - acc: 0.6851 - val_loss: 0.4638 - val_acc: 0.8475
#
# Epoch 00032: val_acc did not improve from 0.85169
# Epoch 33/100
# 940/940 [==============================] - 1s 564us/step - loss: 0.5526 - acc: 0.7457 - val_loss: 0.4937 - val_acc: 0.7542
#
# Epoch 00033: val_acc did not improve from 0.85169
# Epoch 34/100
# 940/940 [==============================] - 1s 585us/step - loss: 0.5598 - acc: 0.6926 - val_loss: 0.5603 - val_acc: 0.7415
#
# Epoch 00034: val_acc did not improve from 0.85169
# Epoch 35/100
# 940/940 [==============================] - 1s 601us/step - loss: 0.5550 - acc: 0.7362 - val_loss: 0.5229 - val_acc: 0.8390
#
# Epoch 00035: val_acc did not improve from 0.85169
# Epoch 36/100
# 940/940 [==============================] - 1s 575us/step - loss: 0.5020 - acc: 0.7681 - val_loss: 0.5729 - val_acc: 0.6653
#
# Epoch 00036: val_acc did not improve from 0.85169
# Epoch 37/100
# 940/940 [==============================] - 1s 596us/step - loss: 0.5692 - acc: 0.7096 - val_loss: 0.5208 - val_acc: 0.7458
#
# Epoch 00037: val_acc did not improve from 0.85169
# Epoch 38/100
# 940/940 [==============================] - 1s 596us/step - loss: 0.5516 - acc: 0.7032 - val_loss: 0.3952 - val_acc: 0.8644
#
# Epoch 00038: val_acc improved from 0.85169 to 0.86441, saving model to weights.traint_400zoom_modelsimple_avec_crop.hdf5
# Epoch 39/100
# 940/940 [==============================] - 1s 584us/step - loss: 0.5307 - acc: 0.7574 - val_loss: 0.4707 - val_acc: 0.8051
#
# Epoch 00039: val_acc did not improve from 0.86441
# Epoch 40/100
# 940/940 [==============================] - 1s 586us/step - loss: 0.5327 - acc: 0.7426 - val_loss: 0.5339 - val_acc: 0.7966
#
# Epoch 00040: val_acc did not improve from 0.86441
# Epoch 41/100
# 940/940 [==============================] - 1s 575us/step - loss: 0.5508 - acc: 0.7277 - val_loss: 0.5047 - val_acc: 0.8559
# Epoch 00041: val_acc did not improve from 0.86441
# Epoch 42/100
# 940/940 [==============================] - 1s 574us/step - loss: 0.4834 - acc: 0.7926 - val_loss: 0.5583 - val_acc: 0.7034
#
# Epoch 00042: val_acc did not improve from 0.86441
# Epoch 43/100
# 940/940 [==============================] - 1s 574us/step - loss: 0.4854 - acc: 0.7660 - val_loss: 0.3844 - val_acc: 0.8686
#
# Epoch 00043: val_acc improved from 0.86441 to 0.86864, saving model to weights.traint_400zoom_modelsimple_avec_crop.hdf5
# Epoch 44/100
# 940/940 [==============================] - 1s 564us/step - loss: 0.5078 - acc: 0.7479 - val_loss: 0.4163 - val_acc: 0.8347
#
# Epoch 00044: val_acc did not improve from 0.86864
# Epoch 45/100
# 940/940 [==============================] - 1s 573us/step - loss: 0.5055 - acc: 0.7532 - val_loss: 0.4139 - val_acc: 0.8093
#
# Epoch 00045: val_acc did not improve from 0.86864
# Epoch 46/100
# 940/940 [==============================] - 1s 575us/step - loss: 0.4749 - acc: 0.7723 - val_loss: 0.9882 - val_acc: 0.5085
#
# Epoch 00046: val_acc did not improve from 0.86864
# Epoch 47/100
# 940/940 [==============================] - 1s 575us/step - loss: 0.6100 - acc: 0.7319 - val_loss: 0.5371 - val_acc: 0.7415
#
# Epoch 00047: val_acc did not improve from 0.86864
# Epoch 48/100
# 940/940 [==============================] - 1s 585us/step - loss: 0.5196 - acc: 0.7404 - val_loss: 0.3966 - val_acc: 0.8178
#
# Epoch 00048: val_acc did not improve from 0.86864
# Epoch 49/100
# 940/940 [==============================] - 1s 568us/step - loss: 0.4780 - acc: 0.7755 - val_loss: 0.4510 - val_acc: 0.7839
#
# Epoch 00049: val_acc did not improve from 0.86864
# Epoch 50/100
# 940/940 [==============================] - 1s 596us/step - loss: 0.4215 - acc: 0.8255 - val_loss: 0.5768 - val_acc: 0.6780
#
# Epoch 00050: val_acc did not improve from 0.86864
# Epoch 51/100
# 940/940 [==============================] - 1s 628us/step - loss: 0.5566 - acc: 0.7106 - val_loss: 0.3935 - val_acc: 0.8136
#
# Epoch 00051: val_acc did not improve from 0.86864
# Epoch 52/100
# 940/940 [==============================] - 1s 590us/step - loss: 0.3951 - acc: 0.8202 - val_loss: 0.8303 - val_acc: 0.5085
#
# Epoch 00052: val_acc did not improve from 0.86864
# Epoch 53/100
# 940/940 [==============================] - 1s 580us/step - loss: 0.5335 - acc: 0.7340 - val_loss: 0.3300 - val_acc: 0.8771
#
# Epoch 00053: val_acc improved from 0.86864 to 0.87712, saving model to weights.traint_400zoom_modelsimple_avec_crop.hdf5
# Epoch 54/100
# 940/940 [==============================] - 1s 606us/step - loss: 0.5021 - acc: 0.7479 - val_loss: 0.4337 - val_acc: 0.7839
#
# Epoch 00054: val_acc did not improve from 0.87712
# Epoch 55/100
# 940/940 [==============================] - 1s 617us/step - loss: 0.3970 - acc: 0.8234 - val_loss: 0.6349 - val_acc: 0.7076
#
# Epoch 00055: val_acc did not improve from 0.87712
# Epoch 56/100
# 940/940 [==============================] - 1s 588us/step - loss: 0.4471 - acc: 0.8053 - val_loss: 0.3593 - val_acc: 0.8644
#
# Epoch 00056: val_acc did not improve from 0.87712
# Epoch 57/100
# 940/940 [==============================] - 1s 582us/step - loss: 0.4193 - acc: 0.8096 - val_loss: 0.4534 - val_acc: 0.7669
#
# Epoch 00057: val_acc did not improve from 0.87712
# Epoch 58/100
# 940/940 [==============================] - 1s 586us/step - loss: 0.4508 - acc: 0.7798 - val_loss: 0.3800 - val_acc: 0.8898
#
# Epoch 00058: val_acc improved from 0.87712 to 0.88983, saving model to weights.traint_400zoom_modelsimple_avec_crop.hdf5
# Epoch 59/100
# 940/940 [==============================] - 1s 588us/step - loss: 0.3754 - acc: 0.8266 - val_loss: 0.6048 - val_acc: 0.7246
#
# Epoch 00059: val_acc did not improve from 0.88983
# Epoch 60/100
# 940/940 [==============================] - 1s 575us/step - loss: 0.4990 - acc: 0.7117 - val_loss: 0.3837 - val_acc: 0.8136
#
# Epoch 00060: val_acc did not improve from 0.88983
# Epoch 61/100
# 940/940 [==============================] - 1s 579us/step - loss: 0.4599 - acc: 0.7787 - val_loss: 0.5617 - val_acc: 0.7034
#
# Epoch 00061: val_acc did not improve from 0.88983
# Epoch 62/100
# 940/940 [==============================] - 1s 578us/step - loss: 0.4981 - acc: 0.7585 - val_loss: 0.6831 - val_acc: 0.4915
#
# Epoch 00062: val_acc did not improve from 0.88983
# Epoch 63/100
# 940/940 [==============================] - 1s 585us/step - loss: 0.6140 - acc: 0.6383 - val_loss: 0.4376 - val_acc: 0.8051
#
# Epoch 00063: val_acc did not improve from 0.88983
# Epoch 64/100
# 940/940 [==============================] - 1s 596us/step - loss: 0.4189 - acc: 0.8351 - val_loss: 0.8087 - val_acc: 0.7161
#
# Epoch 00064: val_acc did not improve from 0.88983
# Epoch 65/100
# 940/940 [==============================] - 1s 585us/step - loss: 0.5021 - acc: 0.7606 - val_loss: 0.3315 - val_acc: 0.8856
#
# Epoch 00065: val_acc did not improve from 0.88983
# Epoch 66/100
# 940/940 [==============================] - 1s 664us/step - loss: 0.3269 - acc: 0.8574 - val_loss: 0.4085 - val_acc: 0.8390
#
# Epoch 00066: val_acc did not improve from 0.88983
# Epoch 67/100
# 940/940 [==============================] - 1s 615us/step - loss: 0.4140 - acc: 0.7904 - val_loss: 0.3290 - val_acc: 0.8814
#
# Epoch 00067: val_acc did not improve from 0.88983
# Epoch 68/100
# 940/940 [==============================] - 1s 662us/step - loss: 0.3796 - acc: 0.8032 - val_loss: 0.3092 - val_acc: 0.8771
#
# Epoch 00068: val_acc did not improve from 0.88983
# Epoch 69/100
# 940/940 [==============================] - 1s 628us/step - loss: 0.2994 - acc: 0.8596 - val_loss: 0.3794 - val_acc: 0.7924
#
# Epoch 00069: val_acc did not improve from 0.88983
# Epoch 70/100
# 940/940 [==============================] - 1s 642us/step - loss: 0.5122 - acc: 0.7245 - val_loss: 0.4231 - val_acc: 0.7754
#
# Epoch 00070: val_acc did not improve from 0.88983
# Epoch 71/100
# 940/940 [==============================] - 1s 606us/step - loss: 0.3101 - acc: 0.8638 - val_loss: 0.7103 - val_acc: 0.5339
#
# Epoch 00071: val_acc did not improve from 0.88983
# Epoch 72/100
# 940/940 [==============================] - 1s 568us/step - loss: 0.3772 - acc: 0.8202 - val_loss: 0.3062 - val_acc: 0.8941
#
# Epoch 00072: val_acc improved from 0.88983 to 0.89407, saving model to weights.traint_400zoom_modelsimple_avec_crop.hdf5
# Epoch 73/100
# 940/940 [==============================] - 1s 627us/step - loss: 0.3680 - acc: 0.8106 - val_loss: 0.3724 - val_acc: 0.8517
#
# Epoch 00073: val_acc did not improve from 0.89407
# Epoch 74/100
# 940/940 [==============================] - 1s 606us/step - loss: 0.2817 - acc: 0.8894 - val_loss: 0.3484 - val_acc: 0.8559
#
# Epoch 00074: val_acc did not improve from 0.89407
# Epoch 75/100
# 940/940 [==============================] - 1s 606us/step - loss: 0.3743 - acc: 0.8053 - val_loss: 0.3170 - val_acc: 0.8686
#
# Epoch 00075: val_acc did not improve from 0.89407
# Epoch 76/100
# 940/940 [==============================] - 1s 634us/step - loss: 0.3933 - acc: 0.8032 - val_loss: 0.3211 - val_acc: 0.8814
#
# Epoch 00076: val_acc did not improve from 0.89407
# Epoch 77/100
# 940/940 [==============================] - 1s 648us/step - loss: 0.2544 - acc: 0.8830 - val_loss: 0.3961 - val_acc: 0.8178
#
# Epoch 00077: val_acc did not improve from 0.89407
# Epoch 78/100
# 940/940 [==============================] - 1s 581us/step - loss: 0.3303 - acc: 0.8287 - val_loss: 0.8276 - val_acc: 0.5254
#
# Epoch 00078: val_acc did not improve from 0.89407
# Epoch 79/100
# 940/940 [==============================] - 1s 578us/step - loss: 0.3174 - acc: 0.8394 - val_loss: 0.3209 - val_acc: 0.8814
#
# Epoch 00079: val_acc did not improve from 0.89407
# Epoch 80/100
# 940/940 [==============================] - 1s 575us/step - loss: 0.2963 - acc: 0.8553 - val_loss: 0.3553 - val_acc: 0.8814
#
# Epoch 00080: val_acc did not improve from 0.89407
# Epoch 81/100
# 940/940 [==============================] - 1s 573us/step - loss: 0.2201 - acc: 0.9000 - val_loss: 0.5437 - val_acc: 0.7924
#
# Epoch 00081: val_acc did not improve from 0.89407
# Epoch 82/100
# 940/940 [==============================] - 1s 576us/step - loss: 0.3776 - acc: 0.7957 - val_loss: 0.3184 - val_acc: 0.8856
#
# Epoch 00082: val_acc did not improve from 0.89407
# Epoch 83/100
# 940/940 [==============================] - 1s 585us/step - loss: 0.2087 - acc: 0.9021 - val_loss: 0.3720 - val_acc: 0.8178
#
# Epoch 00083: val_acc did not improve from 0.89407
# Epoch 84/100
# 940/940 [==============================] - 1s 575us/step - loss: 0.3418 - acc: 0.8266 - val_loss: 0.3382 - val_acc: 0.8517
#
# Epoch 00084: val_acc did not improve from 0.89407
# Epoch 85/100
# 940/940 [==============================] - 1s 574us/step - loss: 0.2679 - acc: 0.8819 - val_loss: 0.4280 - val_acc: 0.7797
#
# Epoch 00085: val_acc did not improve from 0.89407
# Epoch 86/100
# 940/940 [==============================] - 1s 565us/step - loss: 0.2218 - acc: 0.8915 - val_loss: 0.5575 - val_acc: 0.7627
#
# Epoch 00086: val_acc did not improve from 0.89407
# Epoch 87/100
# 940/940 [==============================] - 1s 577us/step - loss: 0.2608 - acc: 0.8681 - val_loss: 0.3186 - val_acc: 0.8941
#
# Epoch 00087: val_acc improved from 0.89407 to 0.89407, saving model to weights.traint_400zoom_modelsimple_avec_crop.hdf5
# Epoch 88/100
# 940/940 [==============================] - 1s 575us/step - loss: 0.1631 - acc: 0.9149 - val_loss: 0.5024 - val_acc: 0.7458
#
# Epoch 00088: val_acc did not improve from 0.89407
# Epoch 89/100
# 940/940 [==============================] - 1s 573us/step - loss: 0.2937 - acc: 0.8234 - val_loss: 0.3176 - val_acc: 0.8856
#
# Epoch 00089: val_acc did not improve from 0.89407
# Epoch 90/100
# 940/940 [==============================] - 1s 565us/step - loss: 0.2093 - acc: 0.8883 - val_loss: 0.4696 - val_acc: 0.7966
#
# Epoch 00090: val_acc did not improve from 0.89407
# Epoch 91/100
# 940/940 [==============================] - 1s 575us/step - loss: 0.1799 - acc: 0.9128 - val_loss: 0.3720 - val_acc: 0.8686
#
# Epoch 00091: val_acc did not improve from 0.89407
# Epoch 92/100
# 940/940 [==============================] - 1s 562us/step - loss: 0.1661 - acc: 0.9128 - val_loss: 0.6697 - val_acc: 0.7712
#
# Epoch 00092: val_acc did not improve from 0.89407
# Epoch 93/100
# 940/940 [==============================] - 1s 618us/step - loss: 0.2893 - acc: 0.8553 - val_loss: 0.3111 - val_acc: 0.9025
#
# Epoch 00093: val_acc improved from 0.89407 to 0.90254, saving model to weights.traint_400zoom_modelsimple_avec_crop.hdf5
# Epoch 94/100
# 940/940 [==============================] - 1s 596us/step - loss: 0.1405 - acc: 0.9191 - val_loss: 0.4395 - val_acc: 0.8602
#
# Epoch 00094: val_acc did not improve from 0.90254
# Epoch 95/100
# 940/940 [==============================] - 1s 596us/step - loss: 0.3543 - acc: 0.8309 - val_loss: 0.3493 - val_acc: 0.8729
#
# Epoch 00095: val_acc did not improve from 0.90254
# Epoch 96/100
# 940/940 [==============================] - 1s 574us/step - loss: 0.2479 - acc: 0.8840 - val_loss: 0.3233 - val_acc: 0.8856
#
# Epoch 00096: val_acc did not improve from 0.90254
# Epoch 97/100
# 940/940 [==============================] - 1s 592us/step - loss: 0.1283 - acc: 0.9298 - val_loss: 0.3440 - val_acc: 0.8729
#
# Epoch 00097: val_acc did not improve from 0.90254
# Epoch 98/100
# 940/940 [==============================] - 1s 620us/step - loss: 0.1115 - acc: 0.9298 - val_loss: 0.3591 - val_acc: 0.8729
#
# Epoch 00098: val_acc did not improve from 0.90254
# Epoch 99/100
# 940/940 [==============================] - 1s 665us/step - loss: 0.1118 - acc: 0.9319 - val_loss: 0.3546 - val_acc: 0.8517
#
# Epoch 00099: val_acc did not improve from 0.90254
# Epoch 100/100
# 940/940 [==============================] - 1s 616us/step - loss: 0.1081 - acc: 0.9287 - val_loss: 0.5190 - val_acc: 0.8432
#
# Epoch 00100: val_acc did not improve from 0.90254
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 48, 48, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 46, 46, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 23, 23, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 33856)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               4333696
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 4,353,346
# Trainable params: 4,353,346
# Non-trainable params: 0
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.8432203379728026
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.98      0.70      0.81       116
#       IDC(+)       0.77      0.98      0.86       120
#
#    micro avg       0.84      0.84      0.84       236
#    macro avg       0.87      0.84      0.84       236
# weighted avg       0.87      0.84      0.84       236
#
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_400m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_400m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
#simple model
def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')

def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 100 
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu', input_shape = input_shape))
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1024, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(512, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation = "softmax"))
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
     # checkpoint
    filepath="weights.traint_400zoom_modelcomplex_avec_crop.hdf5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]
    history =model.fit(x_train, y_train,
              batch_size=batch_size,
              verbose=1,
              epochs=epochs,
              validation_data=(x_test, y_test),callbacks=callbacks_list)
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# Train on 940 samples, validate on 236 samples
# Epoch 1/100
# 940/940 [==============================] - 4s 4ms/step - loss: 2.1034 - acc: 0.5798 - val_loss: 0.5485 - val_acc: 0.8517
#
# Epoch 00001: val_acc improved from -inf to 0.85169, saving model to weights.traint_400zoom_modelcomplex_avec_crop.hdf5
# Epoch 2/100
# 940/940 [==============================] - 1s 830us/step - loss: 0.5714 - acc: 0.7947 - val_loss: 5.2864 - val_acc: 0.4576
#
# Epoch 00002: val_acc did not improve from 0.85169
# Epoch 3/100
# 940/940 [==============================] - 1s 797us/step - loss: 0.4241 - acc: 0.8234 - val_loss: 0.8035 - val_acc: 0.6864
#
# Epoch 00003: val_acc did not improve from 0.85169
# Epoch 4/100
# 940/940 [==============================] - 1s 863us/step - loss: 0.3745 - acc: 0.8298 - val_loss: 0.5174 - val_acc: 0.7203
#
# Epoch 00004: val_acc did not improve from 0.85169
# Epoch 5/100
# 940/940 [==============================] - 1s 840us/step - loss: 0.2956 - acc: 0.8670 - val_loss: 6.3366 - val_acc: 0.4619
#
# Epoch 00005: val_acc did not improve from 0.85169
# Epoch 6/100
# 940/940 [==============================] - 1s 883us/step - loss: 0.3889 - acc: 0.8383 - val_loss: 2.3638 - val_acc: 0.5127
#
# Epoch 00006: val_acc did not improve from 0.85169
# Epoch 7/100
# 940/940 [==============================] - 1s 840us/step - loss: 0.2578 - acc: 0.8830 - val_loss: 1.3017 - val_acc: 0.7373
#
# Epoch 00007: val_acc did not improve from 0.85169
# Epoch 8/100
# 940/940 [==============================] - 1s 830us/step - loss: 0.4154 - acc: 0.8160 - val_loss: 0.9071 - val_acc: 0.5720
#
# Epoch 00008: val_acc did not improve from 0.85169
# Epoch 9/100
# 940/940 [==============================] - 1s 798us/step - loss: 0.2226 - acc: 0.8926 - val_loss: 0.9119 - val_acc: 0.5932
#
# Epoch 00009: val_acc did not improve from 0.85169
# Epoch 10/100
# 940/940 [==============================] - 1s 798us/step - loss: 0.2288 - acc: 0.8894 - val_loss: 1.4313 - val_acc: 0.6780
#
# Epoch 00010: val_acc did not improve from 0.85169
# Epoch 11/100
# 940/940 [==============================] - 1s 798us/step - loss: 0.2918 - acc: 0.8745 - val_loss: 2.6985 - val_acc: 0.4915
#
# Epoch 00011: val_acc did not improve from 0.85169
# Epoch 12/100
# 940/940 [==============================] - 1s 808us/step - loss: 0.2308 - acc: 0.8947 - val_loss: 1.0326 - val_acc: 0.5085
#
# Epoch 00012: val_acc did not improve from 0.85169
# Epoch 13/100
# 940/940 [==============================] - 1s 799us/step - loss: 0.1794 - acc: 0.9160 - val_loss: 0.5881 - val_acc: 0.7119
#
# Epoch 00013: val_acc did not improve from 0.85169
# Epoch 14/100
# 940/940 [==============================] - 1s 787us/step - loss: 0.2161 - acc: 0.9043 - val_loss: 0.5497 - val_acc: 0.7797
#
# Epoch 00014: val_acc did not improve from 0.85169
# Epoch 15/100
# 940/940 [==============================] - 1s 791us/step - loss: 0.1674 - acc: 0.9234 - val_loss: 1.8632 - val_acc: 0.5339
#
# Epoch 00015: val_acc did not improve from 0.85169
# Epoch 16/100
# 940/940 [==============================] - 1s 798us/step - loss: 0.2287 - acc: 0.8968 - val_loss: 0.6251 - val_acc: 0.7373
#
# Epoch 00016: val_acc did not improve from 0.85169
# Epoch 17/100
# 940/940 [==============================] - 1s 799us/step - loss: 0.2130 - acc: 0.9053 - val_loss: 3.6258 - val_acc: 0.6356
#
# Epoch 00017: val_acc did not improve from 0.85169
# Epoch 18/100
# 940/940 [==============================] - 1s 797us/step - loss: 0.3331 - acc: 0.8798 - val_loss: 0.4905 - val_acc: 0.7288
#
# Epoch 00018: val_acc did not improve from 0.85169
# Epoch 19/100
# 940/940 [==============================] - 1s 798us/step - loss: 0.1809 - acc: 0.9191 - val_loss: 0.5918 - val_acc: 0.7331
#
# Epoch 00019: val_acc did not improve from 0.85169
# Epoch 20/100
# 940/940 [==============================] - 1s 797us/step - loss: 0.1650 - acc: 0.9351 - val_loss: 0.3238 - val_acc: 0.8898
#
# Epoch 00020: val_acc improved from 0.85169 to 0.88983, saving model to weights.traint_400zoom_modelcomplex_avec_crop.hdf5
# Epoch 21/100
# 940/940 [==============================] - 1s 808us/step - loss: 0.1257 - acc: 0.9436 - val_loss: 2.1276 - val_acc: 0.5000
#
# Epoch 00021: val_acc did not improve from 0.88983
# Epoch 22/100
# 940/940 [==============================] - 1s 809us/step - loss: 0.1210 - acc: 0.9500 - val_loss: 2.4424 - val_acc: 0.5763
#
# Epoch 00022: val_acc did not improve from 0.88983
# Epoch 23/100
# 940/940 [==============================] - 1s 808us/step - loss: 0.1315 - acc: 0.9394 - val_loss: 4.8136 - val_acc: 0.4619
#
# Epoch 00023: val_acc did not improve from 0.88983
# Epoch 24/100
# 940/940 [==============================] - 1s 882us/step - loss: 0.1589 - acc: 0.9319 - val_loss: 1.7799 - val_acc: 0.7627
#
# Epoch 00024: val_acc did not improve from 0.88983
# Epoch 25/100
# 940/940 [==============================] - 1s 831us/step - loss: 0.1346 - acc: 0.9436 - val_loss: 1.1709 - val_acc: 0.6229
#
# Epoch 00025: val_acc did not improve from 0.88983
# Epoch 26/100
# 940/940 [==============================] - 1s 830us/step - loss: 0.2769 - acc: 0.9085 - val_loss: 7.4441 - val_acc: 0.4746
#
# Epoch 00026: val_acc did not improve from 0.88983
# Epoch 27/100
# 940/940 [==============================] - 1s 867us/step - loss: 0.1358 - acc: 0.9394 - val_loss: 1.3525 - val_acc: 0.6441
#
# Epoch 00027: val_acc did not improve from 0.88983
# Epoch 28/100
# 940/940 [==============================] - 1s 846us/step - loss: 0.1255 - acc: 0.9489 - val_loss: 0.4744 - val_acc: 0.8093
#
# Epoch 00028: val_acc did not improve from 0.88983
# Epoch 29/100
# 940/940 [==============================] - 1s 809us/step - loss: 0.0945 - acc: 0.9574 - val_loss: 1.6796 - val_acc: 0.5932
#
# Epoch 00029: val_acc did not improve from 0.88983
# Epoch 30/100
# 940/940 [==============================] - 1s 851us/step - loss: 0.1535 - acc: 0.9330 - val_loss: 1.2196 - val_acc: 0.6441
#
# Epoch 00030: val_acc did not improve from 0.88983
# Epoch 31/100
# 940/940 [==============================] - 1s 819us/step - loss: 0.0924 - acc: 0.9649 - val_loss: 1.5546 - val_acc: 0.7119
#
# Epoch 00031: val_acc did not improve from 0.88983
# Epoch 32/100
# 940/940 [==============================] - 1s 820us/step - loss: 0.0935 - acc: 0.9617 - val_loss: 0.3063 - val_acc: 0.8814
#
# Epoch 00032: val_acc did not improve from 0.88983
# Epoch 33/100
# 940/940 [==============================] - 1s 818us/step - loss: 0.0754 - acc: 0.9713 - val_loss: 1.1629 - val_acc: 0.6610
#
# Epoch 00033: val_acc did not improve from 0.88983
# Epoch 34/100
# 940/940 [==============================] - 1s 819us/step - loss: 0.1395 - acc: 0.9426 - val_loss: 5.3294 - val_acc: 0.5169
#
# Epoch 00034: val_acc did not improve from 0.88983
# Epoch 35/100
# 940/940 [==============================] - 1s 798us/step - loss: 0.1885 - acc: 0.9383 - val_loss: 1.7294 - val_acc: 0.6059
#
# Epoch 00035: val_acc did not improve from 0.88983
# Epoch 36/100
# 940/940 [==============================] - 1s 798us/step - loss: 0.0820 - acc: 0.9681 - val_loss: 0.6654 - val_acc: 0.7839
#
# Epoch 00036: val_acc did not improve from 0.88983
# Epoch 37/100
# 940/940 [==============================] - 1s 791us/step - loss: 0.0414 - acc: 0.9851 - val_loss: 0.6354 - val_acc: 0.8390
#
# Epoch 00037: val_acc did not improve from 0.88983
# Epoch 38/100
# 940/940 [==============================] - 1s 794us/step - loss: 0.0457 - acc: 0.9798 - val_loss: 2.1013 - val_acc: 0.6949
#
# Epoch 00038: val_acc did not improve from 0.88983
# Epoch 39/100
# 940/940 [==============================] - 1s 808us/step - loss: 0.0946 - acc: 0.9660 - val_loss: 1.5930 - val_acc: 0.7881
#
# Epoch 00039: val_acc did not improve from 0.88983
# Epoch 40/100
# 940/940 [==============================] - 1s 798us/step - loss: 0.0638 - acc: 0.9777 - val_loss: 4.6385 - val_acc: 0.5975
#
# Epoch 00040: val_acc did not improve from 0.88983
# Epoch 41/100
# 940/940 [==============================] - 1s 791us/step - loss: 0.0552 - acc: 0.9777 - val_loss: 0.6967 - val_acc: 0.8856
#
# Epoch 00041: val_acc did not improve from 0.88983
# Epoch 42/100
# 940/940 [==============================] - 1s 794us/step - loss: 0.0412 - acc: 0.9872 - val_loss: 0.8617 - val_acc: 0.8390
#
# Epoch 00042: val_acc did not improve from 0.88983
# Epoch 43/100
# 940/940 [==============================] - 1s 801us/step - loss: 0.0967 - acc: 0.9723 - val_loss: 0.9778 - val_acc: 0.6822
#
# Epoch 00043: val_acc did not improve from 0.88983
# Epoch 44/100
# 940/940 [==============================] - 1s 794us/step - loss: 0.0917 - acc: 0.9670 - val_loss: 2.0343 - val_acc: 0.7669
#
# Epoch 00044: val_acc did not improve from 0.88983
# Epoch 45/100
# 940/940 [==============================] - 1s 809us/step - loss: 0.0488 - acc: 0.9798 - val_loss: 5.2078 - val_acc: 0.4958
#
# Epoch 00045: val_acc did not improve from 0.88983
# Epoch 46/100
# 940/940 [==============================] - 1s 798us/step - loss: 0.5896 - acc: 0.8851 - val_loss: 3.3957 - val_acc: 0.3941
#
# Epoch 00046: val_acc did not improve from 0.88983
# Epoch 47/100
# 940/940 [==============================] - 1s 798us/step - loss: 0.0482 - acc: 0.9840 - val_loss: 1.2670 - val_acc: 0.7288
#
# Epoch 00047: val_acc did not improve from 0.88983
# Epoch 48/100
# 940/940 [==============================] - 1s 830us/step - loss: 0.0507 - acc: 0.9809 - val_loss: 3.1651 - val_acc: 0.5000
#
# Epoch 00048: val_acc did not improve from 0.88983
# Epoch 49/100
# 940/940 [==============================] - 1s 866us/step - loss: 0.0453 - acc: 0.9809 - val_loss: 2.6076 - val_acc: 0.6441
#
# Epoch 00049: val_acc did not improve from 0.88983
# Epoch 50/100
# 940/940 [==============================] - 1s 794us/step - loss: 0.0118 - acc: 0.9989 - val_loss: 1.3902 - val_acc: 0.7712
#
# Epoch 00050: val_acc did not improve from 0.88983
# Epoch 51/100
# 940/940 [==============================] - 1s 830us/step - loss: 0.0234 - acc: 0.9904 - val_loss: 2.8146 - val_acc: 0.6271
#
# Epoch 00051: val_acc did not improve from 0.88983
# Epoch 52/100
# 940/940 [==============================] - 1s 830us/step - loss: 0.0283 - acc: 0.9862 - val_loss: 0.7187 - val_acc: 0.8263
#
# Epoch 00052: val_acc did not improve from 0.88983
# Epoch 53/100
# 940/940 [==============================] - 1s 851us/step - loss: 0.0152 - acc: 0.9968 - val_loss: 1.0076 - val_acc: 0.8559
#
# Epoch 00053: val_acc did not improve from 0.88983
# Epoch 54/100
# 940/940 [==============================] - 1s 834us/step - loss: 0.0122 - acc: 0.9947 - val_loss: 0.5961 - val_acc: 0.9025
#
# Epoch 00054: val_acc improved from 0.88983 to 0.90254, saving model to weights.traint_400zoom_modelcomplex_avec_crop.hdf5
# Epoch 55/100
# 940/940 [==============================] - 1s 826us/step - loss: 0.0098 - acc: 0.9957 - val_loss: 0.4703 - val_acc: 0.9153
#
# Epoch 00055: val_acc improved from 0.90254 to 0.91525, saving model to weights.traint_400zoom_modelcomplex_avec_crop.hdf5
# Epoch 56/100
# 940/940 [==============================] - 1s 840us/step - loss: 0.0796 - acc: 0.9830 - val_loss: 0.2526 - val_acc: 0.9364
#
# Epoch 00056: val_acc improved from 0.91525 to 0.93644, saving model to weights.traint_400zoom_modelcomplex_avec_crop.hdf5
# Epoch 57/100
# 940/940 [==============================] - 1s 851us/step - loss: 0.0334 - acc: 0.9915 - val_loss: 0.7034 - val_acc: 0.8729
#
# Epoch 00057: val_acc did not improve from 0.93644
# Epoch 58/100
# 940/940 [==============================] - 1s 830us/step - loss: 0.0230 - acc: 0.9915 - val_loss: 0.6961 - val_acc: 0.8263
#
# Epoch 00058: val_acc did not improve from 0.93644
# Epoch 59/100
# 940/940 [==============================] - 1s 862us/step - loss: 0.0072 - acc: 0.9989 - val_loss: 0.3133 - val_acc: 0.9068
#
# Epoch 00059: val_acc did not improve from 0.93644
# Epoch 60/100
# 940/940 [==============================] - 1s 819us/step - loss: 0.0035 - acc: 0.9989 - val_loss: 0.3734 - val_acc: 0.9025
#
# Epoch 00060: val_acc did not improve from 0.93644
# Epoch 61/100
# 940/940 [==============================] - 1s 830us/step - loss: 0.0370 - acc: 0.9851 - val_loss: 5.9019 - val_acc: 0.4661
#
# Epoch 00061: val_acc did not improve from 0.93644
# Epoch 62/100
# 940/940 [==============================] - 1s 829us/step - loss: 0.1296 - acc: 0.9702 - val_loss: 1.2073 - val_acc: 0.7500
#
# Epoch 00062: val_acc did not improve from 0.93644
# Epoch 63/100
# 940/940 [==============================] - 1s 809us/step - loss: 0.0502 - acc: 0.9819 - val_loss: 2.5053 - val_acc: 0.6398
#
# Epoch 00063: val_acc did not improve from 0.93644
# Epoch 64/100
# 940/940 [==============================] - 1s 797us/step - loss: 0.0255 - acc: 0.9915 - val_loss: 1.7367 - val_acc: 0.6525
#
# Epoch 00064: val_acc did not improve from 0.93644
# Epoch 65/100
# 940/940 [==============================] - 1s 820us/step - loss: 0.0494 - acc: 0.9798 - val_loss: 1.3246 - val_acc: 0.7797
#
# Epoch 00065: val_acc did not improve from 0.93644
# Epoch 66/100
# 940/940 [==============================] - 1s 798us/step - loss: 0.0246 - acc: 0.9915 - val_loss: 2.8041 - val_acc: 0.7288
#
# Epoch 00066: val_acc did not improve from 0.93644
# Epoch 67/100
# 940/940 [==============================] - 1s 798us/step - loss: 0.0115 - acc: 0.9968 - val_loss: 1.3962 - val_acc: 0.7246
#
# Epoch 00067: val_acc did not improve from 0.93644
# Epoch 68/100
# 940/940 [==============================] - 1s 798us/step - loss: 0.0295 - acc: 0.9894 - val_loss: 5.0393 - val_acc: 0.6483
#
# Epoch 00068: val_acc did not improve from 0.93644
# Epoch 69/100
# 940/940 [==============================] - 1s 798us/step - loss: 0.0067 - acc: 0.9979 - val_loss: 1.5686 - val_acc: 0.7881
#
# Epoch 00069: val_acc did not improve from 0.93644
# Epoch 70/100
# 940/940 [==============================] - 1s 787us/step - loss: 0.0198 - acc: 0.9915 - val_loss: 0.2226 - val_acc: 0.9364
#
# Epoch 00070: val_acc improved from 0.93644 to 0.93644, saving model to weights.traint_400zoom_modelcomplex_avec_crop.hdf5
# Epoch 71/100
# 940/940 [==============================] - 1s 799us/step - loss: 0.0179 - acc: 0.9947 - val_loss: 0.5811 - val_acc: 0.8983
#
# Epoch 00071: val_acc did not improve from 0.93644
# Epoch 72/100
# 940/940 [==============================] - 1s 797us/step - loss: 0.0018 - acc: 1.0000 - val_loss: 0.4764 - val_acc: 0.9237
#
# Epoch 00072: val_acc did not improve from 0.93644
# Epoch 73/100
# 940/940 [==============================] - 1s 788us/step - loss: 0.0019 - acc: 1.0000 - val_loss: 0.7776 - val_acc: 0.8856
#
# Epoch 00073: val_acc did not improve from 0.93644
# Epoch 74/100
# 940/940 [==============================] - 1s 798us/step - loss: 0.0154 - acc: 0.9957 - val_loss: 1.7930 - val_acc: 0.7924
#
# Epoch 00074: val_acc did not improve from 0.93644
# Epoch 75/100
# 940/940 [==============================] - 1s 809us/step - loss: 0.0402 - acc: 0.9883 - val_loss: 1.5955 - val_acc: 0.8263
#
# Epoch 00075: val_acc did not improve from 0.93644
# Epoch 76/100
# 940/940 [==============================] - 1s 814us/step - loss: 0.0186 - acc: 0.9947 - val_loss: 1.1314 - val_acc: 0.8220
#
# Epoch 00076: val_acc did not improve from 0.93644
# Epoch 77/100
# 940/940 [==============================] - 1s 843us/step - loss: 0.1134 - acc: 0.9755 - val_loss: 2.0756 - val_acc: 0.5254
#
# Epoch 00077: val_acc did not improve from 0.93644
# Epoch 78/100
# 940/940 [==============================] - 1s 806us/step - loss: 0.1840 - acc: 0.9511 - val_loss: 5.1478 - val_acc: 0.6356
#
# Epoch 00078: val_acc did not improve from 0.93644
# Epoch 79/100
# 940/940 [==============================] - 1s 851us/step - loss: 0.0187 - acc: 0.9957 - val_loss: 3.6086 - val_acc: 0.6907
#
# Epoch 00079: val_acc did not improve from 0.93644
# Epoch 80/100
# 940/940 [==============================] - 1s 819us/step - loss: 0.0245 - acc: 0.9926 - val_loss: 2.3777 - val_acc: 0.5593
#
# Epoch 00080: val_acc did not improve from 0.93644
# Epoch 81/100
# 940/940 [==============================] - 1s 829us/step - loss: 0.0379 - acc: 0.9915 - val_loss: 0.6921 - val_acc: 0.8602
#
# Epoch 00081: val_acc did not improve from 0.93644
# Epoch 82/100
# 940/940 [==============================] - 1s 809us/step - loss: 0.0097 - acc: 0.9979 - val_loss: 1.2766 - val_acc: 0.6780
#
# Epoch 00082: val_acc did not improve from 0.93644
# Epoch 83/100
# 940/940 [==============================] - 1s 808us/step - loss: 0.0239 - acc: 0.9894 - val_loss: 1.0521 - val_acc: 0.7754
#
# Epoch 00083: val_acc did not improve from 0.93644
# Epoch 84/100
# 940/940 [==============================] - 1s 818us/step - loss: 0.0059 - acc: 0.9989 - val_loss: 0.4524 - val_acc: 0.8856
#
# Epoch 00084: val_acc did not improve from 0.93644
# Epoch 85/100
# 940/940 [==============================] - 1s 834us/step - loss: 0.0139 - acc: 0.9947 - val_loss: 0.3553 - val_acc: 0.9322
#
# Epoch 00085: val_acc did not improve from 0.93644
# Epoch 86/100
# 940/940 [==============================] - 1s 827us/step - loss: 0.0067 - acc: 0.9989 - val_loss: 0.3513 - val_acc: 0.9364
#
# Epoch 00086: val_acc did not improve from 0.93644
# Epoch 87/100
# 940/940 [==============================] - 1s 819us/step - loss: 0.0021 - acc: 0.9989 - val_loss: 0.3094 - val_acc: 0.9449
#
# Epoch 00087: val_acc improved from 0.93644 to 0.94492, saving model to weights.traint_400zoom_modelcomplex_avec_crop.hdf5
# Epoch 88/100
# 940/940 [==============================] - 1s 809us/step - loss: 0.0110 - acc: 0.9936 - val_loss: 1.6653 - val_acc: 0.7754
#
# Epoch 00088: val_acc did not improve from 0.94492
# Epoch 89/100
# 940/940 [==============================] - 1s 809us/step - loss: 0.0295 - acc: 0.9894 - val_loss: 1.6242 - val_acc: 0.8263
#
# Epoch 00089: val_acc did not improve from 0.94492
# Epoch 90/100
# 940/940 [==============================] - 1s 807us/step - loss: 0.0180 - acc: 0.9968 - val_loss: 2.1058 - val_acc: 0.6271
#
# Epoch 00090: val_acc did not improve from 0.94492
# Epoch 91/100
# 940/940 [==============================] - 1s 799us/step - loss: 0.0103 - acc: 0.9979 - val_loss: 0.7820 - val_acc: 0.8263
#
# Epoch 00091: val_acc did not improve from 0.94492
# Epoch 92/100
# 940/940 [==============================] - 1s 808us/step - loss: 0.0016 - acc: 1.0000 - val_loss: 0.5491 - val_acc: 0.8729
#
# Epoch 00092: val_acc did not improve from 0.94492
# Epoch 93/100
# 940/940 [==============================] - 1s 800us/step - loss: 0.0027 - acc: 0.9989 - val_loss: 0.4107 - val_acc: 0.9195A: 0s - loss: 0.0024 - acc: 0.998
#
# Epoch 00093: val_acc did not improve from 0.94492
# Epoch 94/100
# 940/940 [==============================] - 1s 794us/step - loss: 0.0012 - acc: 1.0000 - val_loss: 0.3470 - val_acc: 0.9364
#
# Epoch 00094: val_acc did not improve from 0.94492
# Epoch 95/100
# 940/940 [==============================] - 1s 820us/step - loss: 0.0099 - acc: 0.9947 - val_loss: 1.7408 - val_acc: 0.8093
#
# Epoch 00095: val_acc did not improve from 0.94492
# Epoch 96/100
# 940/940 [==============================] - 1s 819us/step - loss: 0.0014 - acc: 1.0000 - val_loss: 0.7713 - val_acc: 0.8856
#
# Epoch 00096: val_acc did not improve from 0.94492
# Epoch 97/100
# 940/940 [==============================] - 1s 819us/step - loss: 5.3546e-04 - acc: 1.0000 - val_loss: 0.6013 - val_acc: 0.9068
#
# Epoch 00097: val_acc did not improve from 0.94492
# Epoch 98/100
# 940/940 [==============================] - 1s 819us/step - loss: 0.0011 - acc: 1.0000 - val_loss: 0.4977 - val_acc: 0.9068
#
# Epoch 00098: val_acc did not improve from 0.94492
# Epoch 99/100
# 940/940 [==============================] - 1s 819us/step - loss: 0.0010 - acc: 1.0000 - val_loss: 0.3742 - val_acc: 0.9322
#
# Epoch 00099: val_acc did not improve from 0.94492
# Epoch 100/100
# 940/940 [==============================] - 1s 819us/step - loss: 0.0046 - acc: 0.9979 - val_loss: 0.2208 - val_acc: 0.9364
#
# Epoch 00100: val_acc did not improve from 0.94492
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_93 (Conv2D)           (None, 50, 50, 32)        896
# _________________________________________________________________
# conv2d_94 (Conv2D)           (None, 50, 50, 32)        9248
# _________________________________________________________________
# max_pooling2d_47 (MaxPooling (None, 25, 25, 32)        0
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 25, 25, 32)        128
# _________________________________________________________________
# dropout_78 (Dropout)         (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_95 (Conv2D)           (None, 25, 25, 64)        18496
# _________________________________________________________________
# conv2d_96 (Conv2D)           (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d_48 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 12, 12, 64)        256
# _________________________________________________________________
# dropout_79 (Dropout)         (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_97 (Conv2D)           (None, 12, 12, 86)        49622
# _________________________________________________________________
# conv2d_98 (Conv2D)           (None, 12, 12, 86)        66650
# _________________________________________________________________
# max_pooling2d_49 (MaxPooling (None, 6, 6, 86)          0
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 6, 6, 86)          344
# _________________________________________________________________
# dropout_80 (Dropout)         (None, 6, 6, 86)          0
# _________________________________________________________________
# flatten_17 (Flatten)         (None, 3096)              0
# _________________________________________________________________
# dense_48 (Dense)             (None, 1024)              3171328
# _________________________________________________________________
# dropout_81 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_49 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_82 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_50 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 3,879,722
# Trainable params: 3,879,358
# Non-trainable params: 364
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.9364406779661016
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.94      0.95      0.94       128
#       IDC(+)       0.93      0.93      0.93       108
#
#    micro avg       0.94      0.94      0.94       236
#    macro avg       0.94      0.94      0.94       236
# weighted avg       0.94      0.94      0.94       236
#
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_40m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_40m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
class MetricsCheckpoint(Callback):
    """apres chaque epoch en sauvegarde metrics"""
    def __init__(self, savepath):
        #constructeur de la class
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')
def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 5
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    #test d'un premier model
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu', input_shape = input_shape))
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1024, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(512, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation = "softmax"))
    # load weights
    model.load_weights("weights.traint_400zoom_modelcomplex_avec_crop.hdf5")
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
     
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_99 (Conv2D)           (None, 50, 50, 32)        896
# _________________________________________________________________
# conv2d_100 (Conv2D)          (None, 50, 50, 32)        9248
# _________________________________________________________________
# max_pooling2d_50 (MaxPooling (None, 25, 25, 32)        0
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 25, 25, 32)        128
# _________________________________________________________________
# dropout_83 (Dropout)         (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_101 (Conv2D)          (None, 25, 25, 64)        18496
# _________________________________________________________________
# conv2d_102 (Conv2D)          (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d_51 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# batch_normalization_50 (Batc (None, 12, 12, 64)        256
# _________________________________________________________________
# dropout_84 (Dropout)         (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_103 (Conv2D)          (None, 12, 12, 86)        49622
# _________________________________________________________________
# conv2d_104 (Conv2D)          (None, 12, 12, 86)        66650
# _________________________________________________________________
# max_pooling2d_52 (MaxPooling (None, 6, 6, 86)          0
# _________________________________________________________________
# batch_normalization_51 (Batc (None, 6, 6, 86)          344
# _________________________________________________________________
# dropout_85 (Dropout)         (None, 6, 6, 86)          0
# _________________________________________________________________
# flatten_18 (Flatten)         (None, 3096)              0
# _________________________________________________________________
# dense_51 (Dense)             (None, 1024)              3171328
# _________________________________________________________________
# dropout_86 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_52 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_87 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_53 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 3,879,722
# Trainable params: 3,879,358
# Non-trainable params: 364
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.8039999995231628
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.76      0.91      0.83       129
#       IDC(+)       0.88      0.69      0.77       121
#
#    micro avg       0.80      0.80      0.80       250
#    macro avg       0.82      0.80      0.80       250
# weighted avg       0.82      0.80      0.80       250

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_100m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_100m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
class MetricsCheckpoint(Callback):
    """apres chaque epoch en sauvegarde metrics"""
    def __init__(self, savepath):
        #constructeur de la class
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')
def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 5
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    #test d'un premier model
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu', input_shape = input_shape))
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1024, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(512, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation = "softmax"))
    # load weights
    model.load_weights("weights.traint_400zoom_modelcomplex_avec_crop.hdf5")
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
     
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_129 (Conv2D)          (None, 50, 50, 32)        896
# _________________________________________________________________
# conv2d_130 (Conv2D)          (None, 50, 50, 32)        9248
# _________________________________________________________________
# max_pooling2d_65 (MaxPooling (None, 25, 25, 32)        0
# _________________________________________________________________
# batch_normalization_64 (Batc (None, 25, 25, 32)        128
# _________________________________________________________________
# dropout_108 (Dropout)        (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_131 (Conv2D)          (None, 25, 25, 64)        18496
# _________________________________________________________________
# conv2d_132 (Conv2D)          (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d_66 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# batch_normalization_65 (Batc (None, 12, 12, 64)        256
# _________________________________________________________________
# dropout_109 (Dropout)        (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_133 (Conv2D)          (None, 12, 12, 86)        49622
# _________________________________________________________________
# conv2d_134 (Conv2D)          (None, 12, 12, 86)        66650
# _________________________________________________________________
# max_pooling2d_67 (MaxPooling (None, 6, 6, 86)          0
# _________________________________________________________________
# batch_normalization_66 (Batc (None, 6, 6, 86)          344
# _________________________________________________________________
# dropout_110 (Dropout)        (None, 6, 6, 86)          0
# _________________________________________________________________
# flatten_23 (Flatten)         (None, 3096)              0
# _________________________________________________________________
# dense_66 (Dense)             (None, 1024)              3171328
# _________________________________________________________________
# dropout_111 (Dropout)        (None, 1024)              0
# _________________________________________________________________
# dense_67 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_112 (Dropout)        (None, 512)               0
# _________________________________________________________________
# dense_68 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 3,879,722
# Trainable params: 3,879,358
# Non-trainable params: 364
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.8294573643410853
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.82      0.83      0.82       124
#       IDC(+)       0.84      0.83      0.83       134
#
#    micro avg       0.83      0.83      0.83       258
#    macro avg       0.83      0.83      0.83       258
# weighted avg       0.83      0.83      0.83       258

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_200m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_200m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
class MetricsCheckpoint(Callback):
    """apres chaque epoch en sauvegarde metrics"""
    def __init__(self, savepath):
        #constructeur de la class
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')
def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 5
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    #test d'un premier model
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu', input_shape = input_shape))
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1024, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(512, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation = "softmax"))
    # load weights
    model.load_weights("weights.traint_400zoom_modelcomplex_avec_crop.hdf5")
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
     
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_117 (Conv2D)          (None, 50, 50, 32)        896
# _________________________________________________________________
# conv2d_118 (Conv2D)          (None, 50, 50, 32)        9248
# _________________________________________________________________
# max_pooling2d_59 (MaxPooling (None, 25, 25, 32)        0
# _________________________________________________________________
# batch_normalization_58 (Batc (None, 25, 25, 32)        128
# _________________________________________________________________
# dropout_98 (Dropout)         (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_119 (Conv2D)          (None, 25, 25, 64)        18496
# _________________________________________________________________
# conv2d_120 (Conv2D)          (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d_60 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# batch_normalization_59 (Batc (None, 12, 12, 64)        256
# _________________________________________________________________
# dropout_99 (Dropout)         (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_121 (Conv2D)          (None, 12, 12, 86)        49622
# _________________________________________________________________
# conv2d_122 (Conv2D)          (None, 12, 12, 86)        66650
# _________________________________________________________________
# max_pooling2d_61 (MaxPooling (None, 6, 6, 86)          0
# _________________________________________________________________
# batch_normalization_60 (Batc (None, 6, 6, 86)          344
# _________________________________________________________________
# dropout_100 (Dropout)        (None, 6, 6, 86)          0
# _________________________________________________________________
# flatten_21 (Flatten)         (None, 3096)              0
# _________________________________________________________________
# dense_60 (Dense)             (None, 1024)              3171328
# _________________________________________________________________
# dropout_101 (Dropout)        (None, 1024)              0
# _________________________________________________________________
# dense_61 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_102 (Dropout)        (None, 512)               0
# _________________________________________________________________
# dense_62 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 3,879,722
# Trainable params: 3,879,358
# Non-trainable params: 364
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.9240000004768372
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.91      0.93      0.92       120
#       IDC(+)       0.94      0.92      0.93       130
#
#    micro avg       0.92      0.92      0.92       250
#    macro avg       0.92      0.92      0.92       250
# weighted avg       0.92      0.92      0.92       250

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_400m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_400m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
class MetricsCheckpoint(Callback):
    """apres chaque epoch en sauvegarde metrics"""
    def __init__(self, savepath):
        #constructeur de la class
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')
def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 5
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    #test d'un premier model
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu', input_shape = input_shape))
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1024, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(512, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation = "softmax"))
    # load weights
    model.load_weights("weights.traint_400zoom_modelcomplex_avec_crop.hdf5")
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
     
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_135 (Conv2D)          (None, 50, 50, 32)        896
# _________________________________________________________________
# conv2d_136 (Conv2D)          (None, 50, 50, 32)        9248
# _________________________________________________________________
# max_pooling2d_68 (MaxPooling (None, 25, 25, 32)        0
# _________________________________________________________________
# batch_normalization_67 (Batc (None, 25, 25, 32)        128
# _________________________________________________________________
# dropout_113 (Dropout)        (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_137 (Conv2D)          (None, 25, 25, 64)        18496
# _________________________________________________________________
# conv2d_138 (Conv2D)          (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d_69 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# batch_normalization_68 (Batc (None, 12, 12, 64)        256
# _________________________________________________________________
# dropout_114 (Dropout)        (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_139 (Conv2D)          (None, 12, 12, 86)        49622
# _________________________________________________________________
# conv2d_140 (Conv2D)          (None, 12, 12, 86)        66650
# _________________________________________________________________
# max_pooling2d_70 (MaxPooling (None, 6, 6, 86)          0
# _________________________________________________________________
# batch_normalization_69 (Batc (None, 6, 6, 86)          344
# _________________________________________________________________
# dropout_115 (Dropout)        (None, 6, 6, 86)          0
# _________________________________________________________________
# flatten_24 (Flatten)         (None, 3096)              0
# _________________________________________________________________
# dense_69 (Dense)             (None, 1024)              3171328
# _________________________________________________________________
# dropout_116 (Dropout)        (None, 1024)              0
# _________________________________________________________________
# dense_70 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_117 (Dropout)        (None, 512)               0
# _________________________________________________________________
# dense_71 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 3,879,722
# Trainable params: 3,879,358
# Non-trainable params: 364
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.9957627118644068
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.99      1.00      1.00       119
#       IDC(+)       1.00      0.99      1.00       117
#
#    micro avg       1.00      1.00      1.00       236
#    macro avg       1.00      1.00      1.00       236
# weighted avg       1.00      1.00      1.00       236

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoo.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
class MetricsCheckpoint(Callback):
    """apres chaque epoch en sauvegarde metrics"""
    def __init__(self, savepath):
        #constructeur de la class
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')
def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 5
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    #test d'un premier model
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu', input_shape = input_shape))
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1024, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(512, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation = "softmax"))
    # load weights
    model.load_weights("weights.traint_400zoom_modelcomplex_avec_crop.hdf5")
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
     
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_141 (Conv2D)          (None, 50, 50, 32)        896
# _________________________________________________________________
# conv2d_142 (Conv2D)          (None, 50, 50, 32)        9248
# _________________________________________________________________
# max_pooling2d_71 (MaxPooling (None, 25, 25, 32)        0
# _________________________________________________________________
# batch_normalization_70 (Batc (None, 25, 25, 32)        128
# _________________________________________________________________
# dropout_118 (Dropout)        (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_143 (Conv2D)          (None, 25, 25, 64)        18496
# _________________________________________________________________
# conv2d_144 (Conv2D)          (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d_72 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# batch_normalization_71 (Batc (None, 12, 12, 64)        256
# _________________________________________________________________
# dropout_119 (Dropout)        (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_145 (Conv2D)          (None, 12, 12, 86)        49622
# _________________________________________________________________
# conv2d_146 (Conv2D)          (None, 12, 12, 86)        66650
# _________________________________________________________________
# max_pooling2d_73 (MaxPooling (None, 6, 6, 86)          0
# _________________________________________________________________
# batch_normalization_72 (Batc (None, 6, 6, 86)          344
# _________________________________________________________________
# dropout_120 (Dropout)        (None, 6, 6, 86)          0
# _________________________________________________________________
# flatten_25 (Flatten)         (None, 3096)              0
# _________________________________________________________________
# dense_72 (Dense)             (None, 1024)              3171328
# _________________________________________________________________
# dropout_121 (Dropout)        (None, 1024)              0
# _________________________________________________________________
# dense_73 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_122 (Dropout)        (None, 512)               0
# _________________________________________________________________
# dense_74 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 3,879,722
# Trainable params: 3,879,358
# Non-trainable params: 364
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.8538306451612904
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.80      0.90      0.85       455
#       IDC(+)       0.91      0.81      0.86       537
#
#    micro avg       0.85      0.85      0.85       992
#    macro avg       0.86      0.86      0.85       992
# weighted avg       0.86      0.85      0.85       992

# %%
# charger des images formes (5547, 50, 50, 3)
X = np.load('D:/test cancer rbreast/crop/zoom_400m.npy')  

# charger des images  (5547,1); (0 = no cancer, 1 = cancer)
Y = np.load('D:/test cancer rbreast/crop/zoom_400m_label.npy')   
perm_array = np.arange(len(X))
#arrange genere tous toute les val jusqua la longuer de x_images
np.random.shuffle(perm_array)
#il melange les images
X = X[perm_array]
Y = Y[perm_array]
#en split notre dataset 80 % 20 %
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
# en redduit la taille de l'echantillon au cas ou en avais trop d'images 
#pour pas que ca prend trop de temps pour le pc 
#mais ici c'est pas le cas donc en commente ce code
#X_train = X_train[0:30000] 
#Y_train = Y_train[0:30000]
#X_test = X_test[0:30000] 
#Y_test = Y_test[0:30000]

# normalizer nos donnees 
#en pourrais utiliser d'autre methodes aussi mais celle la c'est bien 
X_train = X_train / 256.0
X_test = X_test / 256.0
#methode qu'on a trouver sur internet et qu'on a utiliser 
X_trainShape = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]
X_testShape = X_test.shape[1]*X_test.shape[2]*X_test.shape[3]
#en applatit les donnees en gros en les transfrome en une matrice 1 seul dimmenssion nbr elem*(width*height*channel)
X_trainFlat = X_train.reshape(X_train.shape[0], X_trainShape)
X_testFlat = X_test.reshape(X_test.shape[0], X_testShape)
Y_train = to_categorical(Y_train, num_classes = 2)
Y_test = to_categorical(Y_test, num_classes = 2)
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
#simple model
def plotKerasLearningCurve():
    #en affiche juste la courbe de notre model
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('nombre d epoques')

def runKerasCNN(a,b,c,d):
    """
    en a utiliser ce lien
    https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
    en a utilise run model qui marche bien sur MNIST sur notre dataset
    """
    batch_size = 128
    num_classes = 2
    epochs = 100 
    img_rows, img_cols = X_train.shape[1],X_train.shape[2]
    input_shape = (img_rows, img_cols, 3)
    x_train = a
    y_train = b
    x_test = c
    y_test = d   
    model = Sequential()
    #test d'un premier model
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu', input_shape = input_shape))
    model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1024, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(512, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation = "softmax"))
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
     # checkpoint
    filepath="weights.traint_400zoom_modelcomplex_avec_crop.hdf5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]
    history =model.fit(x_train, y_train,
              batch_size=batch_size,
              verbose=1,
              epochs=epochs,
              validation_data=(x_test, y_test),callbacks=callbacks_list)
    model.summary()
    score = model.evaluate(x_test, y_test, verbose=0)
    print('\nKeras CNN 1 - accuracy:', score[1],'\n')
    y_pred = model.predict(c) 
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    print('\n', sklearn.metrics.classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')
    Y_pred_classes = np.argmax(y_pred,axis = 1) 
    Y_true = np.argmax(Y_test,axis = 1) 
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    plot_confusion_matrix(confusion_mtx, classes = list(map_characters.values()))
runKerasCNN(X_train, Y_train,  X_test, Y_test)
#plotKerasLearningCurve()
# Out:
# Train on 940 samples, validate on 236 samples
# Epoch 1/100
# 940/940 [==============================] - 7s 7ms/step - loss: 1.8769 - acc: 0.6436 - val_loss: 7.1597 - val_acc: 0.4873
#
# Epoch 00001: val_acc improved from -inf to 0.48729, saving model to weights.traint_400zoom_modelcomplex_avec_crop.hdf5
# Epoch 2/100
# 940/940 [==============================] - 1s 826us/step - loss: 0.7826 - acc: 0.7532 - val_loss: 1.1259 - val_acc: 0.6017
#
# Epoch 00002: val_acc improved from 0.48729 to 0.60169, saving model to weights.traint_400zoom_modelcomplex_avec_crop.hdf5
# Epoch 3/100
# 940/940 [==============================] - 1s 819us/step - loss: 0.5302 - acc: 0.8043 - val_loss: 5.8080 - val_acc: 0.5381
#
# Epoch 00003: val_acc did not improve from 0.60169
# Epoch 4/100
# 940/940 [==============================] - 1s 818us/step - loss: 0.3579 - acc: 0.8447 - val_loss: 5.3471 - val_acc: 0.5381
#
# Epoch 00004: val_acc did not improve from 0.60169
# Epoch 5/100
# 940/940 [==============================] - 1s 833us/step - loss: 0.2699 - acc: 0.8787 - val_loss: 2.3173 - val_acc: 0.5424
#
# Epoch 00005: val_acc did not improve from 0.60169
# Epoch 6/100
# 940/940 [==============================] - 1s 841us/step - loss: 0.2810 - acc: 0.8681 - val_loss: 0.9487 - val_acc: 0.5593
#
# Epoch 00006: val_acc did not improve from 0.60169
# Epoch 7/100
# 940/940 [==============================] - 1s 780us/step - loss: 0.2874 - acc: 0.8734 - val_loss: 0.4500 - val_acc: 0.7966
#
# Epoch 00007: val_acc improved from 0.60169 to 0.79661, saving model to weights.traint_400zoom_modelcomplex_avec_crop.hdf5
# Epoch 8/100
# 940/940 [==============================] - 1s 849us/step - loss: 0.3245 - acc: 0.8649 - val_loss: 1.0704 - val_acc: 0.6144
#
# Epoch 00008: val_acc did not improve from 0.79661
# Epoch 9/100
# 940/940 [==============================] - 1s 795us/step - loss: 0.2583 - acc: 0.8872 - val_loss: 0.6001 - val_acc: 0.6992
#
# Epoch 00009: val_acc did not improve from 0.79661
# Epoch 10/100
# 940/940 [==============================] - 1s 790us/step - loss: 0.2479 - acc: 0.8883 - val_loss: 6.9673 - val_acc: 0.5339
#
# Epoch 00010: val_acc did not improve from 0.79661
# Epoch 11/100
# 940/940 [==============================] - 1s 788us/step - loss: 0.5524 - acc: 0.8064 - val_loss: 0.2586 - val_acc: 0.8686
#
# Epoch 00011: val_acc improved from 0.79661 to 0.86864, saving model to weights.traint_400zoom_modelcomplex_avec_crop.hdf5
# Epoch 12/100
# 940/940 [==============================] - 1s 786us/step - loss: 0.2066 - acc: 0.9106 - val_loss: 0.4857 - val_acc: 0.7246
#
# Epoch 00012: val_acc did not improve from 0.86864
# Epoch 13/100
# 940/940 [==============================] - 1s 785us/step - loss: 0.1957 - acc: 0.9053 - val_loss: 1.1729 - val_acc: 0.6568
#
# Epoch 00013: val_acc did not improve from 0.86864
# Epoch 14/100
# 940/940 [==============================] - 1s 784us/step - loss: 0.1655 - acc: 0.9223 - val_loss: 1.7586 - val_acc: 0.5212
#
# Epoch 00014: val_acc did not improve from 0.86864
# Epoch 15/100
# 940/940 [==============================] - 1s 785us/step - loss: 0.2161 - acc: 0.9064 - val_loss: 0.3511 - val_acc: 0.8178
#
# Epoch 00015: val_acc did not improve from 0.86864
# Epoch 16/100
# 940/940 [==============================] - 1s 785us/step - loss: 0.1423 - acc: 0.9340 - val_loss: 0.7556 - val_acc: 0.6483
#
# Epoch 00016: val_acc did not improve from 0.86864
# Epoch 17/100
# 940/940 [==============================] - 1s 790us/step - loss: 0.2097 - acc: 0.9106 - val_loss: 2.2471 - val_acc: 0.5975
#
# Epoch 00017: val_acc did not improve from 0.86864
# Epoch 18/100
# 940/940 [==============================] - 1s 793us/step - loss: 0.1532 - acc: 0.9309 - val_loss: 5.0099 - val_acc: 0.5508
#
# Epoch 00018: val_acc did not improve from 0.86864
# Epoch 19/100
# 940/940 [==============================] - 1s 782us/step - loss: 0.1258 - acc: 0.9415 - val_loss: 3.8093 - val_acc: 0.5678
#
# Epoch 00019: val_acc did not improve from 0.86864
# Epoch 20/100
# 940/940 [==============================] - 1s 837us/step - loss: 0.1352 - acc: 0.9511 - val_loss: 1.0573 - val_acc: 0.6568
#
# Epoch 00020: val_acc did not improve from 0.86864
# Epoch 21/100
# 940/940 [==============================] - 1s 898us/step - loss: 0.1766 - acc: 0.9181 - val_loss: 2.0852 - val_acc: 0.5508
#
# Epoch 00021: val_acc did not improve from 0.86864
# Epoch 22/100
# 940/940 [==============================] - 1s 872us/step - loss: 0.1860 - acc: 0.9362 - val_loss: 0.6346 - val_acc: 0.7161
#
# Epoch 00022: val_acc did not improve from 0.86864
# Epoch 23/100
# 940/940 [==============================] - 1s 869us/step - loss: 0.1789 - acc: 0.9287 - val_loss: 0.4245 - val_acc: 0.8136
#
# Epoch 00023: val_acc did not improve from 0.86864
# Epoch 24/100
# 940/940 [==============================] - 1s 816us/step - loss: 0.1094 - acc: 0.9543 - val_loss: 1.3430 - val_acc: 0.6822
#
# Epoch 00024: val_acc did not improve from 0.86864
# Epoch 25/100
# 940/940 [==============================] - 1s 830us/step - loss: 0.1408 - acc: 0.9553 - val_loss: 4.8387 - val_acc: 0.5720
#
# Epoch 00025: val_acc did not improve from 0.86864
# Epoch 26/100
# 940/940 [==============================] - 1s 814us/step - loss: 0.1569 - acc: 0.9479 - val_loss: 4.5570 - val_acc: 0.5424
#
# Epoch 00026: val_acc did not improve from 0.86864
# Epoch 27/100
# 940/940 [==============================] - 1s 816us/step - loss: 0.1230 - acc: 0.9468 - val_loss: 2.1505 - val_acc: 0.6102
#
# Epoch 00027: val_acc did not improve from 0.86864
# Epoch 28/100
# 940/940 [==============================] - 1s 816us/step - loss: 0.0938 - acc: 0.9553 - val_loss: 0.8987 - val_acc: 0.6695
#
# Epoch 00028: val_acc did not improve from 0.86864
# Epoch 29/100
# 940/940 [==============================] - 1s 814us/step - loss: 0.0718 - acc: 0.9734 - val_loss: 1.4987 - val_acc: 0.6992
#
# Epoch 00029: val_acc did not improve from 0.86864
# Epoch 30/100
# 940/940 [==============================] - 1s 811us/step - loss: 0.0800 - acc: 0.9691 - val_loss: 5.1452 - val_acc: 0.5805
#
# Epoch 00030: val_acc did not improve from 0.86864
# Epoch 31/100
# 940/940 [==============================] - 1s 824us/step - loss: 0.0916 - acc: 0.9660 - val_loss: 1.3975 - val_acc: 0.6864
#
# Epoch 00031: val_acc did not improve from 0.86864
# Epoch 32/100
# 940/940 [==============================] - 1s 807us/step - loss: 0.0494 - acc: 0.9819 - val_loss: 1.2549 - val_acc: 0.6525
#
# Epoch 00032: val_acc did not improve from 0.86864
# Epoch 33/100
# 940/940 [==============================] - 1s 821us/step - loss: 0.0931 - acc: 0.9734 - val_loss: 1.2461 - val_acc: 0.5466
#
# Epoch 00033: val_acc did not improve from 0.86864
# Epoch 34/100
# 940/940 [==============================] - 1s 818us/step - loss: 0.7831 - acc: 0.8543 - val_loss: 5.4729 - val_acc: 0.5636
#
# Epoch 00034: val_acc did not improve from 0.86864
# Epoch 35/100
# 940/940 [==============================] - 1s 812us/step - loss: 0.0771 - acc: 0.9670 - val_loss: 0.3626 - val_acc: 0.8347
#
# Epoch 00035: val_acc did not improve from 0.86864
# Epoch 36/100
# 940/940 [==============================] - 1s 816us/step - loss: 0.0471 - acc: 0.9798 - val_loss: 0.9007 - val_acc: 0.7797
#
# Epoch 00036: val_acc did not improve from 0.86864
# Epoch 37/100
# 940/940 [==============================] - 1s 838us/step - loss: 0.0428 - acc: 0.9883 - val_loss: 0.4289 - val_acc: 0.8390
#
# Epoch 00037: val_acc did not improve from 0.86864
# Epoch 38/100
# 940/940 [==============================] - 1s 813us/step - loss: 0.0412 - acc: 0.9862 - val_loss: 1.2570 - val_acc: 0.7712
#
# Epoch 00038: val_acc did not improve from 0.86864
# Epoch 39/100
# 940/940 [==============================] - 1s 814us/step - loss: 0.0380 - acc: 0.9862 - val_loss: 0.5392 - val_acc: 0.8644
#
# Epoch 00039: val_acc did not improve from 0.86864
# Epoch 40/100
# 940/940 [==============================] - 1s 817us/step - loss: 0.0369 - acc: 0.9883 - val_loss: 0.5750 - val_acc: 0.8686
#
# Epoch 00040: val_acc did not improve from 0.86864
# Epoch 41/100
# 940/940 [==============================] - 1s 814us/step - loss: 0.0652 - acc: 0.9723 - val_loss: 0.7196 - val_acc: 0.8729
#
# Epoch 00041: val_acc improved from 0.86864 to 0.87288, saving model to weights.traint_400zoom_modelcomplex_avec_crop.hdf5
# Epoch 42/100
# 940/940 [==============================] - 1s 811us/step - loss: 0.0190 - acc: 0.9968 - val_loss: 0.3438 - val_acc: 0.8814
# Epoch 00042: val_acc improved from 0.87288 to 0.88136, saving model to weights.traint_400zoom_modelcomplex_avec_crop.hdf5
# Epoch 43/100
# 940/940 [==============================] - 1s 817us/step - loss: 0.0165 - acc: 0.9957 - val_loss: 1.0557 - val_acc: 0.8220
#
# Epoch 00043: val_acc did not improve from 0.88136
# Epoch 44/100
# 940/940 [==============================] - 1s 816us/step - loss: 0.0190 - acc: 0.9936 - val_loss: 1.4901 - val_acc: 0.6864
#
# Epoch 00044: val_acc did not improve from 0.88136
# Epoch 45/100
# 940/940 [==============================] - 1s 814us/step - loss: 0.0555 - acc: 0.9787 - val_loss: 2.0233 - val_acc: 0.7203
#
# Epoch 00045: val_acc did not improve from 0.88136
# Epoch 46/100
# 940/940 [==============================] - 1s 810us/step - loss: 0.0512 - acc: 0.9830 - val_loss: 1.7878 - val_acc: 0.7203
#
# Epoch 00046: val_acc did not improve from 0.88136
# Epoch 47/100
# 940/940 [==============================] - 1s 816us/step - loss: 0.0724 - acc: 0.9830 - val_loss: 2.5387 - val_acc: 0.7076
#
# Epoch 00047: val_acc did not improve from 0.88136
# Epoch 48/100
# 940/940 [==============================] - 1s 813us/step - loss: 0.0325 - acc: 0.9904 - val_loss: 0.6025 - val_acc: 0.8856
#
# Epoch 00048: val_acc improved from 0.88136 to 0.88559, saving model to weights.traint_400zoom_modelcomplex_avec_crop.hdf5
# Epoch 49/100
# 940/940 [==============================] - 1s 814us/step - loss: 0.0291 - acc: 0.9840 - val_loss: 3.8366 - val_acc: 0.6568
#
# Epoch 00049: val_acc did not improve from 0.88559
# Epoch 50/100
# 940/940 [==============================] - 1s 817us/step - loss: 0.0146 - acc: 0.9957 - val_loss: 0.6692 - val_acc: 0.8729
#
# Epoch 00050: val_acc did not improve from 0.88559
# Epoch 51/100
# 940/940 [==============================] - 1s 830us/step - loss: 0.0328 - acc: 0.9904 - val_loss: 7.1657 - val_acc: 0.5254
#
# Epoch 00051: val_acc did not improve from 0.88559
# Epoch 52/100
# 940/940 [==============================] - 1s 806us/step - loss: 0.0774 - acc: 0.9745 - val_loss: 2.8952 - val_acc: 0.6907
#
# Epoch 00052: val_acc did not improve from 0.88559
# Epoch 53/100
# 940/940 [==============================] - 1s 811us/step - loss: 0.0490 - acc: 0.9862 - val_loss: 0.8197 - val_acc: 0.8263
#
# Epoch 00053: val_acc did not improve from 0.88559
# Epoch 54/100
# 940/940 [==============================] - 1s 818us/step - loss: 0.0463 - acc: 0.9840 - val_loss: 1.5757 - val_acc: 0.7119
#
# Epoch 00054: val_acc did not improve from 0.88559
# Epoch 55/100
# 940/940 [==============================] - 1s 817us/step - loss: 0.0331 - acc: 0.9926 - val_loss: 1.5822 - val_acc: 0.6483
#
# Epoch 00055: val_acc did not improve from 0.88559
# Epoch 56/100
# 940/940 [==============================] - 1s 808us/step - loss: 0.0954 - acc: 0.9809 - val_loss: 1.2646 - val_acc: 0.7669
#
# Epoch 00056: val_acc did not improve from 0.88559
# Epoch 57/100
# 940/940 [==============================] - 1s 805us/step - loss: 0.0307 - acc: 0.9904 - val_loss: 1.5115 - val_acc: 0.8305
#
# Epoch 00057: val_acc did not improve from 0.88559
# Epoch 58/100
# 940/940 [==============================] - 1s 821us/step - loss: 0.0408 - acc: 0.9830 - val_loss: 1.0570 - val_acc: 0.8686
#
# Epoch 00058: val_acc did not improve from 0.88559
# Epoch 59/100
# 940/940 [==============================] - 1s 822us/step - loss: 0.0090 - acc: 0.9979 - val_loss: 0.9064 - val_acc: 0.8729
#
# Epoch 00059: val_acc did not improve from 0.88559
# Epoch 60/100
# 940/940 [==============================] - 1s 839us/step - loss: 0.0108 - acc: 0.9968 - val_loss: 0.7567 - val_acc: 0.8814
#
# Epoch 00060: val_acc did not improve from 0.88559
# Epoch 61/100
# 940/940 [==============================] - 1s 806us/step - loss: 0.0404 - acc: 0.9915 - val_loss: 2.7306 - val_acc: 0.6907
#
# Epoch 00061: val_acc did not improve from 0.88559
# Epoch 62/100
# 940/940 [==============================] - 1s 816us/step - loss: 0.0160 - acc: 0.9947 - val_loss: 1.3710 - val_acc: 0.7712
#
# Epoch 00062: val_acc did not improve from 0.88559
# Epoch 63/100
# 940/940 [==============================] - 1s 810us/step - loss: 0.0195 - acc: 0.9915 - val_loss: 0.8262 - val_acc: 0.8051
#
# Epoch 00063: val_acc did not improve from 0.88559
# Epoch 64/100
# 940/940 [==============================] - 1s 834us/step - loss: 0.0048 - acc: 0.9989 - val_loss: 1.0263 - val_acc: 0.8136
#
# Epoch 00064: val_acc did not improve from 0.88559
# Epoch 65/100
# 940/940 [==============================] - 1s 822us/step - loss: 0.0055 - acc: 0.9989 - val_loss: 0.7446 - val_acc: 0.8602
#
# Epoch 00065: val_acc did not improve from 0.88559
# Epoch 66/100
# 940/940 [==============================] - 1s 821us/step - loss: 0.0024 - acc: 1.0000 - val_loss: 0.7297 - val_acc: 0.8814
#
# Epoch 00066: val_acc did not improve from 0.88559
# Epoch 67/100
# 940/940 [==============================] - 1s 820us/step - loss: 0.0047 - acc: 0.9989 - val_loss: 1.2349 - val_acc: 0.8347
#
# Epoch 00067: val_acc did not improve from 0.88559
# Epoch 68/100
# 940/940 [==============================] - 1s 815us/step - loss: 0.0029 - acc: 1.0000 - val_loss: 1.8503 - val_acc: 0.7839
#
# Epoch 00068: val_acc did not improve from 0.88559
# Epoch 69/100
# 940/940 [==============================] - 1s 820us/step - loss: 0.0052 - acc: 0.9968 - val_loss: 3.5968 - val_acc: 0.6822
#
# Epoch 00069: val_acc did not improve from 0.88559
# Epoch 70/100
# 940/940 [==============================] - 1s 807us/step - loss: 0.0301 - acc: 0.9915 - val_loss: 1.4679 - val_acc: 0.7585
#
# Epoch 00070: val_acc did not improve from 0.88559
# Epoch 71/100
# 940/940 [==============================] - 1s 807us/step - loss: 0.0789 - acc: 0.9734 - val_loss: 6.6746 - val_acc: 0.5127
#
# Epoch 00071: val_acc did not improve from 0.88559
# Epoch 72/100
# 940/940 [==============================] - 1s 820us/step - loss: 0.1062 - acc: 0.9777 - val_loss: 1.0156 - val_acc: 0.7627
#
# Epoch 00072: val_acc did not improve from 0.88559
# Epoch 73/100
# 940/940 [==============================] - 1s 828us/step - loss: 0.0232 - acc: 0.9926 - val_loss: 0.8596 - val_acc: 0.7924
#
# Epoch 00073: val_acc did not improve from 0.88559
# Epoch 74/100
# 940/940 [==============================] - 1s 812us/step - loss: 0.0055 - acc: 0.9979 - val_loss: 0.9503 - val_acc: 0.8008
#
# Epoch 00074: val_acc did not improve from 0.88559
# Epoch 75/100
# 940/940 [==============================] - 1s 811us/step - loss: 0.0057 - acc: 0.9989 - val_loss: 0.7385 - val_acc: 0.8136
#
# Epoch 00075: val_acc did not improve from 0.88559
# Epoch 76/100
# 940/940 [==============================] - 1s 814us/step - loss: 0.0155 - acc: 0.9957 - val_loss: 1.4897 - val_acc: 0.6907
#
# Epoch 00076: val_acc did not improve from 0.88559
# Epoch 77/100
# 940/940 [==============================] - 1s 816us/step - loss: 0.0167 - acc: 0.9947 - val_loss: 7.2346 - val_acc: 0.5254
#
# Epoch 00077: val_acc did not improve from 0.88559
# Epoch 78/100
# 940/940 [==============================] - 1s 848us/step - loss: 0.1244 - acc: 0.9606 - val_loss: 1.2802 - val_acc: 0.8305
#
# Epoch 00078: val_acc did not improve from 0.88559
# Epoch 79/100
# 940/940 [==============================] - 1s 812us/step - loss: 0.0167 - acc: 0.9915 - val_loss: 0.9180 - val_acc: 0.7924
#
# Epoch 00079: val_acc did not improve from 0.88559
# Epoch 80/100
# 940/940 [==============================] - 1s 807us/step - loss: 0.0060 - acc: 0.9979 - val_loss: 1.2862 - val_acc: 0.7076
#
# Epoch 00080: val_acc did not improve from 0.88559
# Epoch 81/100
# 940/940 [==============================] - 1s 824us/step - loss: 0.0024 - acc: 0.9989 - val_loss: 1.2588 - val_acc: 0.7119
#
# Epoch 00081: val_acc did not improve from 0.88559
# Epoch 82/100
# 940/940 [==============================] - 1s 801us/step - loss: 0.0131 - acc: 0.9947 - val_loss: 1.0545 - val_acc: 0.8305
#
# Epoch 00082: val_acc did not improve from 0.88559
# Epoch 83/100
# 940/940 [==============================] - 1s 811us/step - loss: 0.0105 - acc: 0.9936 - val_loss: 0.8607 - val_acc: 0.8559
#
# Epoch 00083: val_acc did not improve from 0.88559
# Epoch 84/100
# 940/940 [==============================] - 1s 822us/step - loss: 0.0225 - acc: 0.9894 - val_loss: 1.2222 - val_acc: 0.7669
#
# Epoch 00084: val_acc did not improve from 0.88559
# Epoch 85/100
# 940/940 [==============================] - 1s 814us/step - loss: 0.0236 - acc: 0.9926 - val_loss: 0.6553 - val_acc: 0.8814
#
# Epoch 00085: val_acc did not improve from 0.88559
# Epoch 86/100
# 940/940 [==============================] - 1s 814us/step - loss: 0.0098 - acc: 0.9968 - val_loss: 0.9346 - val_acc: 0.7966
#
# Epoch 00086: val_acc did not improve from 0.88559
# Epoch 87/100
# 940/940 [==============================] - 1s 800us/step - loss: 0.0041 - acc: 0.9979 - val_loss: 0.7756 - val_acc: 0.8686
#
# Epoch 00087: val_acc did not improve from 0.88559
# Epoch 88/100
# 940/940 [==============================] - 1s 819us/step - loss: 0.0025 - acc: 0.9989 - val_loss: 0.4251 - val_acc: 0.9025
#
# Epoch 00088: val_acc improved from 0.88559 to 0.90254, saving model to weights.traint_400zoom_modelcomplex_avec_crop.hdf5
# Epoch 89/100
# 940/940 [==============================] - 1s 807us/step - loss: 0.0057 - acc: 0.9979 - val_loss: 1.3481 - val_acc: 0.8178
#
# Epoch 00089: val_acc did not improve from 0.90254
# Epoch 90/100
# 940/940 [==============================] - 1s 810us/step - loss: 0.0015 - acc: 1.0000 - val_loss: 0.5084 - val_acc: 0.8983
#
# Epoch 00090: val_acc did not improve from 0.90254
# Epoch 91/100
# 940/940 [==============================] - 1s 809us/step - loss: 0.0016 - acc: 1.0000 - val_loss: 0.4844 - val_acc: 0.8983
#
# Epoch 00091: val_acc did not improve from 0.90254
# Epoch 92/100
# 940/940 [==============================] - 1s 807us/step - loss: 5.6312e-04 - acc: 1.0000 - val_loss: 0.4834 - val_acc: 0.8983
#
# Epoch 00092: val_acc did not improve from 0.90254
# Epoch 93/100
# 940/940 [==============================] - 1s 807us/step - loss: 5.1713e-04 - acc: 1.0000 - val_loss: 0.4814 - val_acc: 0.9068
#
# Epoch 00093: val_acc improved from 0.90254 to 0.90678, saving model to weights.traint_400zoom_modelcomplex_avec_crop.hdf5
# Epoch 94/100
# 940/940 [==============================] - 1s 820us/step - loss: 4.8656e-04 - acc: 1.0000 - val_loss: 0.4695 - val_acc: 0.8941
#
# Epoch 00094: val_acc did not improve from 0.90678
# Epoch 95/100
# 940/940 [==============================] - 1s 806us/step - loss: 5.7804e-04 - acc: 1.0000 - val_loss: 3.1220 - val_acc: 0.7331
#
# Epoch 00095: val_acc did not improve from 0.90678
# Epoch 96/100
# 940/940 [==============================] - 1s 809us/step - loss: 0.0048 - acc: 0.9979 - val_loss: 5.1622 - val_acc: 0.6059
#
# Epoch 00096: val_acc did not improve from 0.90678
# Epoch 97/100
# 940/940 [==============================] - 1s 822us/step - loss: 0.0559 - acc: 0.9862 - val_loss: 2.4951 - val_acc: 0.6864
#
# Epoch 00097: val_acc did not improve from 0.90678
# Epoch 98/100
# 940/940 [==============================] - 1s 803us/step - loss: 0.0545 - acc: 0.9840 - val_loss: 3.8642 - val_acc: 0.7076
#
# Epoch 00098: val_acc did not improve from 0.90678
# Epoch 99/100
# 940/940 [==============================] - 1s 800us/step - loss: 0.0150 - acc: 0.9936 - val_loss: 2.2976 - val_acc: 0.6949
#
# Epoch 00099: val_acc did not improve from 0.90678
# Epoch 100/100
# 940/940 [==============================] - 1s 811us/step - loss: 0.0054 - acc: 0.9979 - val_loss: 2.2361 - val_acc: 0.6695
#
# Epoch 00100: val_acc did not improve from 0.90678
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 50, 50, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 50, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 25, 25, 32)        128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 25, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 12, 12, 64)        256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 86)        49622
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 12, 12, 86)        66650
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 86)          0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 6, 6, 86)          344
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 6, 6, 86)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              3171328
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 3,879,722
# Trainable params: 3,879,358
# Non-trainable params: 364
# _________________________________________________________________
#
# Keras CNN 1 - accuracy: 0.6694915244134806
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.81      0.38      0.52       110
#       IDC(+)       0.63      0.92      0.75       126
#
#    micro avg       0.67      0.67      0.67       236
#    macro avg       0.72      0.65      0.63       236
# weighted avg       0.71      0.67      0.64       236
#
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
